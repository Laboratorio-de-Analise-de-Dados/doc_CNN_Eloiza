# %% [markdown]
# # Vero6

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
pip install util-gfsilveira
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting util-gfsilveira
#   Downloading util_gfsilveira-0.1-py3-none-any.whl (3.1 kB)
# Installing collected packages: util-gfsilveira
# Successfully installed util-gfsilveira-0.1

# %% [markdown]
# # Imports data structuring

# %%
#organização dos arquivos
import os
#salvar/carregar arquivos em diferentes formatos
import joblib
#organizando os arquivos de forma aleatória
import random
#gerar gráfico
import matplotlib
#estruturação dos dados
import numpy as np
#gerar gráfico
import seaborn as sns
#gerar gráfico
import matplotlib.pyplot as plt
#gerar imagem
import matplotlib.image as mpimg

# %% [markdown]
# # CNN template import

# %%
#modelo de revisão redes neurais - cnn
from keras.models import Sequential
from keras.utils.np_utils import to_categorical
#from keras.utils import to_categorical
from util import meus_uteis, timeProcess, mask_corr_graphic, printLis
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report
from keras.layers import Dense, Conv2D, MaxPooling2D, Dropout, Flatten

# %% [markdown]
# Documents from different files will be stored in this directory

# %%
diretorio = '/content/drive/MyDrive/Regressão_imagens_DOC_CNN/results_VERO6' #alimentando a variável com os arquivos da pasta datasets
lista_dados = os.listdir(diretorio) #listando os arquivos dessa pasta
printLis(lista_dados) #printando as diferentes listas
# Out:
# -------------
# -=< Lista >=-
# -------------
# 0 -> lista_img_camp_clar_100_resized_regressao_VERO62022-10-24.gz
# 1 -> lista_rotulo_camp_clar_100_resized_regressao_VERO62022-10-24.gz
# 2 -> lista_img_camp_clar_75_resized_regressao_VERO62022-10-24.gz
# 3 -> lista_rotulo_camp_clar_75_resized_regressao_VERO62022-10-24.gz
# 4 -> lista_img_camp_clar_50_resized_regressao_VERO62022-10-24.gz
# 5 -> lista_rotulo_camp_clar_50_resized_regressao_VERO62022-10-24.gz
# 6 -> lista_img_camp_clar_25_resized_regressao_VERO62022-10-24.gz
# 7 -> lista_rotulo_camp_clar_25_resized_regressao_VERO62022-10-24.gz

# %% [markdown]
# Lists of all images in each file

# %%
#lstando arquivos com as imagens 100%, 75%, 50%, 25%
for k, v in enumerate(lista_dados):
    if k in [0,2,4,6]:
        print(f'{k} -> {v}')
# Out:
# 0 -> lista_img_camp_clar_100_resized_regressao_VERO62022-10-24.gz
# 2 -> lista_img_camp_clar_75_resized_regressao_VERO62022-10-24.gz
# 4 -> lista_img_camp_clar_50_resized_regressao_VERO62022-10-24.gz
# 6 -> lista_img_camp_clar_25_resized_regressao_VERO62022-10-24.gz

# %% [markdown]
# ## x = features/images

# %%
#somando todas as imagens de diferentes tamanho
X_cem = joblib.load(diretorio+ '/' + lista_dados[0])

# 12 -> 00-lista_img_dapi_crop_75_resized_2021-5-12.gz
X_setcin = joblib.load(diretorio+ '/' + lista_dados[2])

# 10 -> 00-lista_img_dapi_crop_50_resized_2021-5-12.gz
X_cinq = joblib.load(diretorio+ '/' + lista_dados[4])

# 8 -> 00-lista_img_dapi_crop_25_resized_2021-5-12.gz
X_vincin = joblib.load(diretorio+ '/' + lista_dados[6])

x = np.asarray(list(X_cem) + list(X_setcin) + list(X_cinq) + list(X_vincin))

x.shape
# Out:
# (1792, 200, 200, 3)

# %% [markdown]
# ## y = labels

# %% [markdown]
# Opening the labels that were saved in the preparation of the images

# %%
for k, v in enumerate(lista_dados):
    if k in [1,3,5,7]:
        print(f'{k} -> {v}')
# Out:
# 1 -> lista_rotulo_camp_clar_100_resized_regressao_VERO62022-10-24.gz
# 3 -> lista_rotulo_camp_clar_75_resized_regressao_VERO62022-10-24.gz
# 5 -> lista_rotulo_camp_clar_50_resized_regressao_VERO62022-10-24.gz
# 7 -> lista_rotulo_camp_clar_25_resized_regressao_VERO62022-10-24.gz

# %%
#somando todos os rótulos de diferentes tamanho
y_cem = joblib.load(diretorio+ '/' + lista_dados[1])

# 12 -> 00-lista_img_dapi_crop_75_resized_2021-5-12.gz
y_setcin = joblib.load(diretorio+ '/' + lista_dados[3])

# 10 -> 00-lista_img_dapi_crop_50_resized_2021-5-12.gz
y_cinq = joblib.load(diretorio+ '/' + lista_dados[5])

# 8 -> 00-lista_img_dapi_crop_25_resized_2021-5-12.gz
y_vincin = joblib.load(diretorio+ '/' + lista_dados[7])

y = np.asarray(list(y_cem) + list(y_setcin) + list(y_cinq) + list(y_vincin))

y.shape
# Out:
# (1792,)

# %%
#Train and test split datasets for CNN model
#função que separa as imagens em teste e treino
from sklearn.model_selection import train_test_split

# %% [markdown]
# #Separando dados de validação

# %%
imagens_teste = x.shape[0] * 0.9 #pegando só das imagens 30% das imagens vai para o teste
imagens_treino = x.shape[0] - imagens_teste #restante das imagens (70%)
print('Data for Modeling: ' + str(imagens_teste))
print('Unseen Data For Predictions: ' + str(imagens_treino))
# Out:
# Data for Modeling: 1612.8
# Unseen Data For Predictions: 179.20000000000005

# %%
zeros = list(np.zeros(1613))
ones = list(np.ones(179))
lista = np.array(zeros + ones)
lista
# Out:
# array([0., 0., 0., ..., 1., 1., 1.])

# %%
random.shuffle(lista)
lista_valida = [True if i == 1 else False for i in lista]
lista_treino_test = [False if i == 1 else True for i in lista]
np.array(lista_valida)
# Out:
# array([False, False, False, ..., False, False, False])

# %%
#imagens
x_valida = x[lista_valida]
x_treino_test = x[lista_treino_test]

print(x_valida.shape)
print(x_treino_test.shape)
# Out:
# (179, 200, 200, 3)
# (1613, 200, 200, 3)

# %%
#rótulos
y_valida = y[lista_valida]
y_treino_test = y[lista_treino_test]

print(y_valida.shape)
print(y_treino_test.shape)
# Out:
# (179,)
# (1613,)

# %%
#imagens_teste = x.shape[0] * 0.9 #pegando só das imagens 30% das imagens vai para o teste
#imagens_treino = x.shape[0] - imagens_teste #restante das imagens (70%)
#print('Data for Modeling: ' + str(imagens_teste))
#print('Unseen Data For Predictions: ' + str(imagens_treino))
# Out:
# Data for Modeling: 1368.0
# Unseen Data For Predictions: 152.0

# %% [markdown]
# Dados restantes 90%

# %%
data = timeProcess()[1]

# %%
#Salvando 10$ das imagens para validação
joblib.dump(x_valida, '/content/drive/MyDrive/Regressão_imagens_DOC_CNN/results_VERO6/imagens_validação_10%_Vero6_'+data+'.gz')
joblib.dump(y_valida, '/content/drive/MyDrive/Regressão_imagens_DOC_CNN/results_VERO6/rótulos_validação_10%_Vero6_'+data+'.gz')
# Out:
# ['/content/drive/MyDrive/Regressão_imagens_DOC_CNN/results_VERO6/rótulos_validação_10%_Vero6_2022-12-15.gz']

# %% [markdown]
# Test and training separation from a library.

# %%
X_train, X_test, y_train, y_test = train_test_split(x_treino_test, y_treino_test, test_size=0.3, random_state=0)
#variáveis recebem o número de imagens para tes e treino
print(f'{X_train.shape} \n{X_test.shape} \n{y_train.shape} \n{y_test.shape}')
# Out:
# (1129, 200, 200, 3)
# (484, 200, 200, 3)
# (1129,)
# (484,)

# %%
#salvando os resultados de treino e teste
joblib.dump(X_train, '/content/drive/MyDrive/Regressão_imagens_DOC_CNN/results_VERO6/1_images_de_X_train_VERO6_melhor_modelo_200_epochs_90%_'+data+'.gz')
joblib.dump(y_train, '/content/drive/MyDrive/Regressão_imagens_DOC_CNN/results_VERO6/2_rotulos_de_y_train_VERO6_melhor_modelo_200_epochs_90%_'+data+'.gz')
joblib.dump(X_test, '/content/drive/MyDrive/Regressão_imagens_DOC_CNN/results_VERO6/3_images_de_X_test_VERO6_melhor_modelo_200_epochs_90%_'+data+'.gz')
joblib.dump(y_test, '/content/drive/MyDrive/Regressão_imagens_DOC_CNN/results_VERO6/4_rotulos_de_y_test_VERO6_melhor_model_200_epochs_90%_'+data+'.gz')
# Out:
# ['/content/drive/MyDrive/Regressão_imagens_DOC_CNN/results_VERO6/4_rotulos_de_y_test_VERO6_melhor_model_200_epochs_90%_2022-12-15.gz']

# %% [markdown]
# ### Model determination

# %%
modelo = Sequential()
modelo.add(Conv2D(32, kernel_size=3, activation='relu', input_shape=X_train[0].shape))
#função de ativação relu é muito utilizado para problemas de regressão
modelo.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2), padding='valid'))
modelo.add(Conv2D(64, kernel_size=3, activation='relu'))
modelo.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2), padding='valid'))
modelo.add(Conv2D(128, kernel_size=3, activation='relu'))
modelo.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2), padding='valid'))
modelo.add(Conv2D(256, kernel_size=3, activation='relu'))
modelo.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2), padding='valid'))
modelo.add(Flatten())
modelo.add(Dropout(0.9))
modelo.add(Dense(1, activation='linear'))
#apenas uma saída e de forma linear
modelo.compile(optimizer='adam', loss='mse', metrics=['mean_squared_error'])
print(modelo.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 198, 198, 32)      896
#
#  max_pooling2d (MaxPooling2D  (None, 99, 99, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 97, 97, 64)        18496
#
#  max_pooling2d_1 (MaxPooling  (None, 48, 48, 64)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 46, 46, 128)       73856
#
#  max_pooling2d_2 (MaxPooling  (None, 23, 23, 128)      0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 21, 21, 256)       295168
#
#  max_pooling2d_3 (MaxPooling  (None, 10, 10, 256)      0
#  2D)
#
#  flatten (Flatten)           (None, 25600)             0
#
#  dropout (Dropout)           (None, 25600)             0
#
#  dense (Dense)               (None, 1)                 25601
#
# =================================================================
# Total params: 414,017
# Trainable params: 414,017
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# # Training and testing epochs

# %%
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.callbacks import ModelCheckpoint

# %%
# simple early stopping
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=18)

# %%
# fit model
history = modelo.fit(X_train,y_train,
                    validation_data=(X_test, y_test), 
                    epochs=200, verbose=2, 
                    callbacks=[es]
                     )
# Out:
# Epoch 1/200
# 36/36 - 11s - loss: 328380.8125 - mean_squared_error: 328380.8125 - val_loss: 143941.4062 - val_mean_squared_error: 143941.4062 - 11s/epoch - 297ms/step
# Epoch 2/200
# 36/36 - 2s - loss: 163260.4375 - mean_squared_error: 163260.4375 - val_loss: 131664.2500 - val_mean_squared_error: 131664.2500 - 2s/epoch - 51ms/step
# Epoch 3/200
# 36/36 - 2s - loss: 106183.3438 - mean_squared_error: 106183.3438 - val_loss: 76930.4609 - val_mean_squared_error: 76930.4609 - 2s/epoch - 50ms/step
# Epoch 4/200
# 36/36 - 2s - loss: 76188.7891 - mean_squared_error: 76188.7891 - val_loss: 61997.9141 - val_mean_squared_error: 61997.9141 - 2s/epoch - 49ms/step
# Epoch 5/200
# 36/36 - 2s - loss: 68755.6719 - mean_squared_error: 68755.6719 - val_loss: 82221.8516 - val_mean_squared_error: 82221.8516 - 2s/epoch - 48ms/step
# Epoch 6/200
# 36/36 - 2s - loss: 77824.3984 - mean_squared_error: 77824.3984 - val_loss: 54240.5938 - val_mean_squared_error: 54240.5938 - 2s/epoch - 49ms/step
# Epoch 7/200
# 36/36 - 2s - loss: 59389.6914 - mean_squared_error: 59389.6914 - val_loss: 103175.4844 - val_mean_squared_error: 103175.4844 - 2s/epoch - 49ms/step
# Epoch 8/200
# 36/36 - 2s - loss: 64650.6367 - mean_squared_error: 64650.6367 - val_loss: 57666.3398 - val_mean_squared_error: 57666.3398 - 2s/epoch - 48ms/step
# Epoch 9/200
# 36/36 - 2s - loss: 54701.3008 - mean_squared_error: 54701.3008 - val_loss: 86762.2578 - val_mean_squared_error: 86762.2578 - 2s/epoch - 49ms/step
# Epoch 10/200
# 36/36 - 2s - loss: 52509.6562 - mean_squared_error: 52509.6562 - val_loss: 59634.4805 - val_mean_squared_error: 59634.4805 - 2s/epoch - 48ms/step
# Epoch 11/200
# 36/36 - 2s - loss: 58470.3633 - mean_squared_error: 58470.3633 - val_loss: 60405.8477 - val_mean_squared_error: 60405.8477 - 2s/epoch - 49ms/step
# Epoch 12/200
# 36/36 - 2s - loss: 51993.7578 - mean_squared_error: 51993.7578 - val_loss: 45699.7344 - val_mean_squared_error: 45699.7344 - 2s/epoch - 48ms/step
# Epoch 13/200
# 36/36 - 2s - loss: 51455.5156 - mean_squared_error: 51455.5156 - val_loss: 45761.2812 - val_mean_squared_error: 45761.2812 - 2s/epoch - 48ms/step
# Epoch 14/200
# 36/36 - 2s - loss: 50746.5703 - mean_squared_error: 50746.5703 - val_loss: 55627.3672 - val_mean_squared_error: 55627.3672 - 2s/epoch - 48ms/step
# Epoch 15/200
# 36/36 - 2s - loss: 47887.2578 - mean_squared_error: 47887.2578 - val_loss: 42950.6523 - val_mean_squared_error: 42950.6523 - 2s/epoch - 48ms/step
# Epoch 16/200
# 36/36 - 2s - loss: 53981.5312 - mean_squared_error: 53981.5312 - val_loss: 62333.1367 - val_mean_squared_error: 62333.1367 - 2s/epoch - 48ms/step
# Epoch 17/200
# 36/36 - 2s - loss: 64492.4062 - mean_squared_error: 64492.4062 - val_loss: 51474.2070 - val_mean_squared_error: 51474.2070 - 2s/epoch - 48ms/step
# Epoch 18/200
# 36/36 - 2s - loss: 58624.1602 - mean_squared_error: 58624.1602 - val_loss: 42291.1953 - val_mean_squared_error: 42291.1953 - 2s/epoch - 48ms/step
# Epoch 19/200
# 36/36 - 2s - loss: 44659.1875 - mean_squared_error: 44659.1875 - val_loss: 44997.9336 - val_mean_squared_error: 44997.9336 - 2s/epoch - 48ms/step
# Epoch 20/200
# 36/36 - 2s - loss: 44072.7773 - mean_squared_error: 44072.7773 - val_loss: 41069.3867 - val_mean_squared_error: 41069.3867 - 2s/epoch - 49ms/step
# Epoch 21/200
# 36/36 - 2s - loss: 42261.7344 - mean_squared_error: 42261.7344 - val_loss: 38963.2305 - val_mean_squared_error: 38963.2305 - 2s/epoch - 48ms/step
# Epoch 22/200
# 36/36 - 2s - loss: 36948.5742 - mean_squared_error: 36948.5742 - val_loss: 35535.3789 - val_mean_squared_error: 35535.3789 - 2s/epoch - 48ms/step
# Epoch 23/200
# 36/36 - 2s - loss: 37245.2344 - mean_squared_error: 37245.2344 - val_loss: 38151.3164 - val_mean_squared_error: 38151.3164 - 2s/epoch - 49ms/step
# Epoch 24/200
# 36/36 - 2s - loss: 35555.0234 - mean_squared_error: 35555.0234 - val_loss: 37715.5078 - val_mean_squared_error: 37715.5078 - 2s/epoch - 48ms/step
# Epoch 25/200
# 36/36 - 2s - loss: 42568.2031 - mean_squared_error: 42568.2031 - val_loss: 58753.2383 - val_mean_squared_error: 58753.2383 - 2s/epoch - 50ms/step
# Epoch 26/200
# 36/36 - 2s - loss: 46560.9023 - mean_squared_error: 46560.9023 - val_loss: 38709.9883 - val_mean_squared_error: 38709.9883 - 2s/epoch - 50ms/step
# Epoch 27/200
# 36/36 - 2s - loss: 44332.0312 - mean_squared_error: 44332.0312 - val_loss: 40293.9375 - val_mean_squared_error: 40293.9375 - 2s/epoch - 49ms/step
# Epoch 28/200
# 36/36 - 2s - loss: 56062.0781 - mean_squared_error: 56062.0781 - val_loss: 38514.5156 - val_mean_squared_error: 38514.5156 - 2s/epoch - 48ms/step
# Epoch 29/200
# 36/36 - 2s - loss: 41489.7969 - mean_squared_error: 41489.7969 - val_loss: 54252.8828 - val_mean_squared_error: 54252.8828 - 2s/epoch - 49ms/step
# Epoch 30/200
# 36/36 - 2s - loss: 38255.7539 - mean_squared_error: 38255.7539 - val_loss: 48117.8789 - val_mean_squared_error: 48117.8789 - 2s/epoch - 49ms/step
# Epoch 31/200
# 36/36 - 2s - loss: 35780.7109 - mean_squared_error: 35780.7109 - val_loss: 50300.3164 - val_mean_squared_error: 50300.3164 - 2s/epoch - 49ms/step
# Epoch 32/200
# 36/36 - 2s - loss: 45684.9258 - mean_squared_error: 45684.9258 - val_loss: 84031.0000 - val_mean_squared_error: 84031.0000 - 2s/epoch - 49ms/step
# Epoch 33/200
# 36/36 - 2s - loss: 49984.9258 - mean_squared_error: 49984.9258 - val_loss: 39450.5898 - val_mean_squared_error: 39450.5898 - 2s/epoch - 48ms/step
# Epoch 34/200
# 36/36 - 2s - loss: 34272.2852 - mean_squared_error: 34272.2852 - val_loss: 53818.8125 - val_mean_squared_error: 53818.8125 - 2s/epoch - 50ms/step
# Epoch 35/200
# 36/36 - 2s - loss: 43223.2188 - mean_squared_error: 43223.2188 - val_loss: 35396.9961 - val_mean_squared_error: 35396.9961 - 2s/epoch - 48ms/step
# Epoch 36/200
# 36/36 - 2s - loss: 30774.9551 - mean_squared_error: 30774.9551 - val_loss: 30955.3633 - val_mean_squared_error: 30955.3633 - 2s/epoch - 49ms/step
# Epoch 37/200
# 36/36 - 2s - loss: 29398.6562 - mean_squared_error: 29398.6562 - val_loss: 33085.5352 - val_mean_squared_error: 33085.5352 - 2s/epoch - 49ms/step
# Epoch 38/200
# 36/36 - 2s - loss: 30046.1465 - mean_squared_error: 30046.1465 - val_loss: 49817.8320 - val_mean_squared_error: 49817.8320 - 2s/epoch - 49ms/step
# Epoch 39/200
# 36/36 - 2s - loss: 31666.2578 - mean_squared_error: 31666.2578 - val_loss: 26864.2812 - val_mean_squared_error: 26864.2812 - 2s/epoch - 49ms/step
# Epoch 40/200
# 36/36 - 2s - loss: 28270.6934 - mean_squared_error: 28270.6934 - val_loss: 60084.9570 - val_mean_squared_error: 60084.9570 - 2s/epoch - 49ms/step
# Epoch 41/200
# 36/36 - 2s - loss: 45146.0469 - mean_squared_error: 45146.0469 - val_loss: 52453.4805 - val_mean_squared_error: 52453.4805 - 2s/epoch - 49ms/step
# Epoch 42/200
# 36/36 - 2s - loss: 28910.2461 - mean_squared_error: 28910.2461 - val_loss: 27882.6484 - val_mean_squared_error: 27882.6484 - 2s/epoch - 49ms/step
# Epoch 43/200
# 36/36 - 2s - loss: 23221.3379 - mean_squared_error: 23221.3379 - val_loss: 30553.5879 - val_mean_squared_error: 30553.5879 - 2s/epoch - 50ms/step
# Epoch 44/200
# 36/36 - 2s - loss: 26317.4043 - mean_squared_error: 26317.4043 - val_loss: 24347.3066 - val_mean_squared_error: 24347.3066 - 2s/epoch - 50ms/step
# Epoch 45/200
# 36/36 - 2s - loss: 21329.3672 - mean_squared_error: 21329.3672 - val_loss: 21943.8145 - val_mean_squared_error: 21943.8145 - 2s/epoch - 49ms/step
# Epoch 46/200
# 36/36 - 2s - loss: 27858.5625 - mean_squared_error: 27858.5625 - val_loss: 24096.1719 - val_mean_squared_error: 24096.1719 - 2s/epoch - 49ms/step
# Epoch 47/200
# 36/36 - 2s - loss: 23156.1895 - mean_squared_error: 23156.1895 - val_loss: 49289.3867 - val_mean_squared_error: 49289.3867 - 2s/epoch - 49ms/step
# Epoch 48/200
# 36/36 - 2s - loss: 26603.4082 - mean_squared_error: 26603.4082 - val_loss: 20679.8945 - val_mean_squared_error: 20679.8945 - 2s/epoch - 49ms/step
# Epoch 49/200
# 36/36 - 2s - loss: 35456.5547 - mean_squared_error: 35456.5547 - val_loss: 42888.3359 - val_mean_squared_error: 42888.3359 - 2s/epoch - 49ms/step
# Epoch 50/200
# 36/36 - 2s - loss: 25785.4199 - mean_squared_error: 25785.4199 - val_loss: 24191.2344 - val_mean_squared_error: 24191.2344 - 2s/epoch - 50ms/step
# Epoch 51/200
# 36/36 - 2s - loss: 22505.5801 - mean_squared_error: 22505.5801 - val_loss: 17804.3926 - val_mean_squared_error: 17804.3926 - 2s/epoch - 49ms/step
# Epoch 52/200
# 36/36 - 2s - loss: 17798.7441 - mean_squared_error: 17798.7441 - val_loss: 21674.0820 - val_mean_squared_error: 21674.0820 - 2s/epoch - 49ms/step
# Epoch 53/200
# 36/36 - 2s - loss: 18426.8086 - mean_squared_error: 18426.8086 - val_loss: 18043.1777 - val_mean_squared_error: 18043.1777 - 2s/epoch - 48ms/step
# Epoch 54/200
# 36/36 - 2s - loss: 26663.2871 - mean_squared_error: 26663.2871 - val_loss: 24277.8066 - val_mean_squared_error: 24277.8066 - 2s/epoch - 48ms/step
# Epoch 55/200
# 36/36 - 2s - loss: 18191.5781 - mean_squared_error: 18191.5781 - val_loss: 16309.0205 - val_mean_squared_error: 16309.0205 - 2s/epoch - 48ms/step
# Epoch 56/200
# 36/36 - 2s - loss: 19886.3828 - mean_squared_error: 19886.3828 - val_loss: 19524.0352 - val_mean_squared_error: 19524.0352 - 2s/epoch - 48ms/step
# Epoch 57/200
# 36/36 - 2s - loss: 19635.4395 - mean_squared_error: 19635.4395 - val_loss: 13906.9541 - val_mean_squared_error: 13906.9541 - 2s/epoch - 49ms/step
# Epoch 58/200
# 36/36 - 2s - loss: 18968.9219 - mean_squared_error: 18968.9219 - val_loss: 19332.4727 - val_mean_squared_error: 19332.4727 - 2s/epoch - 49ms/step
# Epoch 59/200
# 36/36 - 2s - loss: 16352.3965 - mean_squared_error: 16352.3965 - val_loss: 13860.4932 - val_mean_squared_error: 13860.4932 - 2s/epoch - 48ms/step
# Epoch 60/200
# 36/36 - 2s - loss: 14986.1787 - mean_squared_error: 14986.1787 - val_loss: 16576.6992 - val_mean_squared_error: 16576.6992 - 2s/epoch - 48ms/step
# Epoch 61/200
# 36/36 - 2s - loss: 16854.9062 - mean_squared_error: 16854.9062 - val_loss: 11033.2500 - val_mean_squared_error: 11033.2500 - 2s/epoch - 49ms/step
# Epoch 62/200
# 36/36 - 2s - loss: 12577.9727 - mean_squared_error: 12577.9727 - val_loss: 10064.4570 - val_mean_squared_error: 10064.4570 - 2s/epoch - 50ms/step
# Epoch 63/200
# 36/36 - 2s - loss: 15798.3965 - mean_squared_error: 15798.3965 - val_loss: 28223.5137 - val_mean_squared_error: 28223.5137 - 2s/epoch - 49ms/step
# Epoch 64/200
# 36/36 - 2s - loss: 12994.2881 - mean_squared_error: 12994.2881 - val_loss: 10071.4814 - val_mean_squared_error: 10071.4814 - 2s/epoch - 50ms/step
# Epoch 65/200
# 36/36 - 2s - loss: 11559.4512 - mean_squared_error: 11559.4512 - val_loss: 9618.7227 - val_mean_squared_error: 9618.7227 - 2s/epoch - 49ms/step
# Epoch 66/200
# 36/36 - 2s - loss: 11688.8398 - mean_squared_error: 11688.8398 - val_loss: 25783.2539 - val_mean_squared_error: 25783.2539 - 2s/epoch - 50ms/step
# Epoch 67/200
# 36/36 - 2s - loss: 16415.3789 - mean_squared_error: 16415.3789 - val_loss: 12098.0312 - val_mean_squared_error: 12098.0312 - 2s/epoch - 50ms/step
# Epoch 68/200
# 36/36 - 2s - loss: 18927.1719 - mean_squared_error: 18927.1719 - val_loss: 14873.7080 - val_mean_squared_error: 14873.7080 - 2s/epoch - 49ms/step
# Epoch 69/200
# 36/36 - 2s - loss: 11569.7812 - mean_squared_error: 11569.7812 - val_loss: 9472.5234 - val_mean_squared_error: 9472.5234 - 2s/epoch - 49ms/step
# Epoch 70/200
# 36/36 - 2s - loss: 12863.2461 - mean_squared_error: 12863.2461 - val_loss: 9903.1826 - val_mean_squared_error: 9903.1826 - 2s/epoch - 50ms/step
# Epoch 71/200
# 36/36 - 2s - loss: 8924.4941 - mean_squared_error: 8924.4941 - val_loss: 10751.3887 - val_mean_squared_error: 10751.3887 - 2s/epoch - 49ms/step
# Epoch 72/200
# 36/36 - 2s - loss: 10486.7930 - mean_squared_error: 10486.7930 - val_loss: 9304.6211 - val_mean_squared_error: 9304.6211 - 2s/epoch - 49ms/step
# Epoch 73/200
# 36/36 - 2s - loss: 11677.5264 - mean_squared_error: 11677.5264 - val_loss: 14848.1592 - val_mean_squared_error: 14848.1592 - 2s/epoch - 49ms/step
# Epoch 74/200
# 36/36 - 2s - loss: 11198.6123 - mean_squared_error: 11198.6123 - val_loss: 8559.0654 - val_mean_squared_error: 8559.0654 - 2s/epoch - 49ms/step
# Epoch 75/200
# 36/36 - 2s - loss: 9969.8564 - mean_squared_error: 9969.8564 - val_loss: 7006.0000 - val_mean_squared_error: 7006.0000 - 2s/epoch - 49ms/step
# Epoch 76/200
# 36/36 - 2s - loss: 7313.7139 - mean_squared_error: 7313.7139 - val_loss: 5963.1787 - val_mean_squared_error: 5963.1787 - 2s/epoch - 49ms/step
# Epoch 77/200
# 36/36 - 2s - loss: 9067.9131 - mean_squared_error: 9067.9131 - val_loss: 6686.9424 - val_mean_squared_error: 6686.9424 - 2s/epoch - 49ms/step
# Epoch 78/200
# 36/36 - 2s - loss: 7914.0674 - mean_squared_error: 7914.0674 - val_loss: 8476.0898 - val_mean_squared_error: 8476.0898 - 2s/epoch - 49ms/step
# Epoch 79/200
# 36/36 - 2s - loss: 8024.5386 - mean_squared_error: 8024.5386 - val_loss: 6444.2856 - val_mean_squared_error: 6444.2856 - 2s/epoch - 49ms/step
# Epoch 80/200
# 36/36 - 2s - loss: 6776.8052 - mean_squared_error: 6776.8052 - val_loss: 6961.3818 - val_mean_squared_error: 6961.3818 - 2s/epoch - 49ms/step
# Epoch 81/200
# 36/36 - 2s - loss: 7050.8354 - mean_squared_error: 7050.8354 - val_loss: 6317.3096 - val_mean_squared_error: 6317.3096 - 2s/epoch - 49ms/step
# Epoch 82/200
# 36/36 - 2s - loss: 7568.9893 - mean_squared_error: 7568.9893 - val_loss: 6571.6724 - val_mean_squared_error: 6571.6724 - 2s/epoch - 51ms/step
# Epoch 83/200
# 36/36 - 2s - loss: 7007.9150 - mean_squared_error: 7007.9150 - val_loss: 5176.7612 - val_mean_squared_error: 5176.7612 - 2s/epoch - 49ms/step
# Epoch 84/200
# 36/36 - 2s - loss: 8525.4873 - mean_squared_error: 8525.4873 - val_loss: 12373.9980 - val_mean_squared_error: 12373.9980 - 2s/epoch - 50ms/step
# Epoch 85/200
# 36/36 - 2s - loss: 10105.2744 - mean_squared_error: 10105.2744 - val_loss: 7998.2881 - val_mean_squared_error: 7998.2881 - 2s/epoch - 49ms/step
# Epoch 86/200
# 36/36 - 2s - loss: 7002.2856 - mean_squared_error: 7002.2856 - val_loss: 5666.4316 - val_mean_squared_error: 5666.4316 - 2s/epoch - 49ms/step
# Epoch 87/200
# 36/36 - 2s - loss: 6083.7808 - mean_squared_error: 6083.7808 - val_loss: 5698.4839 - val_mean_squared_error: 5698.4839 - 2s/epoch - 50ms/step
# Epoch 88/200
# 36/36 - 2s - loss: 6104.2476 - mean_squared_error: 6104.2476 - val_loss: 10822.8545 - val_mean_squared_error: 10822.8545 - 2s/epoch - 50ms/step
# Epoch 89/200
# 36/36 - 2s - loss: 9884.0000 - mean_squared_error: 9884.0000 - val_loss: 6030.6270 - val_mean_squared_error: 6030.6270 - 2s/epoch - 49ms/step
# Epoch 90/200
# 36/36 - 2s - loss: 7567.4395 - mean_squared_error: 7567.4395 - val_loss: 6108.4121 - val_mean_squared_error: 6108.4121 - 2s/epoch - 50ms/step
# Epoch 91/200
# 36/36 - 2s - loss: 6934.3335 - mean_squared_error: 6934.3335 - val_loss: 7048.0537 - val_mean_squared_error: 7048.0537 - 2s/epoch - 50ms/step
# Epoch 92/200
# 36/36 - 2s - loss: 5697.5107 - mean_squared_error: 5697.5107 - val_loss: 6428.8369 - val_mean_squared_error: 6428.8369 - 2s/epoch - 49ms/step
# Epoch 93/200
# 36/36 - 2s - loss: 6203.3042 - mean_squared_error: 6203.3042 - val_loss: 5023.1079 - val_mean_squared_error: 5023.1079 - 2s/epoch - 50ms/step
# Epoch 94/200
# 36/36 - 2s - loss: 5840.1406 - mean_squared_error: 5840.1406 - val_loss: 8717.1641 - val_mean_squared_error: 8717.1641 - 2s/epoch - 50ms/step
# Epoch 95/200
# 36/36 - 2s - loss: 6290.1929 - mean_squared_error: 6290.1929 - val_loss: 6555.1172 - val_mean_squared_error: 6555.1172 - 2s/epoch - 49ms/step
# Epoch 96/200
# 36/36 - 2s - loss: 5719.6245 - mean_squared_error: 5719.6245 - val_loss: 5368.0986 - val_mean_squared_error: 5368.0986 - 2s/epoch - 50ms/step
# Epoch 97/200
# 36/36 - 2s - loss: 4885.7593 - mean_squared_error: 4885.7593 - val_loss: 5589.9673 - val_mean_squared_error: 5589.9673 - 2s/epoch - 50ms/step
# Epoch 98/200
# 36/36 - 2s - loss: 4660.9512 - mean_squared_error: 4660.9512 - val_loss: 5117.6201 - val_mean_squared_error: 5117.6201 - 2s/epoch - 49ms/step
# Epoch 99/200
# 36/36 - 2s - loss: 5055.2334 - mean_squared_error: 5055.2334 - val_loss: 5122.8921 - val_mean_squared_error: 5122.8921 - 2s/epoch - 50ms/step
# Epoch 100/200
# 36/36 - 2s - loss: 5260.7891 - mean_squared_error: 5260.7891 - val_loss: 4981.4014 - val_mean_squared_error: 4981.4014 - 2s/epoch - 49ms/step
# Epoch 101/200
# 36/36 - 2s - loss: 4658.1870 - mean_squared_error: 4658.1870 - val_loss: 3932.1677 - val_mean_squared_error: 3932.1677 - 2s/epoch - 49ms/step
# Epoch 102/200
# 36/36 - 2s - loss: 4645.0625 - mean_squared_error: 4645.0625 - val_loss: 6368.5791 - val_mean_squared_error: 6368.5791 - 2s/epoch - 50ms/step
# Epoch 103/200
# 36/36 - 2s - loss: 4827.1558 - mean_squared_error: 4827.1558 - val_loss: 4477.3950 - val_mean_squared_error: 4477.3950 - 2s/epoch - 49ms/step
# Epoch 104/200
# 36/36 - 2s - loss: 4399.6392 - mean_squared_error: 4399.6392 - val_loss: 4396.6235 - val_mean_squared_error: 4396.6235 - 2s/epoch - 49ms/step
# Epoch 105/200
# 36/36 - 2s - loss: 5630.2573 - mean_squared_error: 5630.2573 - val_loss: 5297.0996 - val_mean_squared_error: 5297.0996 - 2s/epoch - 49ms/step
# Epoch 106/200
# 36/36 - 2s - loss: 4696.4980 - mean_squared_error: 4696.4980 - val_loss: 5486.3228 - val_mean_squared_error: 5486.3228 - 2s/epoch - 49ms/step
# Epoch 107/200
# 36/36 - 2s - loss: 4662.8511 - mean_squared_error: 4662.8511 - val_loss: 4399.1143 - val_mean_squared_error: 4399.1143 - 2s/epoch - 49ms/step
# Epoch 108/200
# 36/36 - 2s - loss: 4580.5200 - mean_squared_error: 4580.5200 - val_loss: 4485.6436 - val_mean_squared_error: 4485.6436 - 2s/epoch - 50ms/step
# Epoch 109/200
# 36/36 - 2s - loss: 3919.3879 - mean_squared_error: 3919.3879 - val_loss: 5760.9321 - val_mean_squared_error: 5760.9321 - 2s/epoch - 49ms/step
# Epoch 110/200
# 36/36 - 2s - loss: 4220.7788 - mean_squared_error: 4220.7788 - val_loss: 4327.3716 - val_mean_squared_error: 4327.3716 - 2s/epoch - 50ms/step
# Epoch 111/200
# 36/36 - 2s - loss: 4616.6758 - mean_squared_error: 4616.6758 - val_loss: 4289.9639 - val_mean_squared_error: 4289.9639 - 2s/epoch - 50ms/step
# Epoch 112/200
# 36/36 - 2s - loss: 4075.0588 - mean_squared_error: 4075.0588 - val_loss: 4050.1179 - val_mean_squared_error: 4050.1179 - 2s/epoch - 50ms/step
# Epoch 113/200
# 36/36 - 2s - loss: 3787.7874 - mean_squared_error: 3787.7874 - val_loss: 5756.1387 - val_mean_squared_error: 5756.1387 - 2s/epoch - 49ms/step
# Epoch 114/200
# 36/36 - 2s - loss: 3504.5713 - mean_squared_error: 3504.5713 - val_loss: 4141.9082 - val_mean_squared_error: 4141.9082 - 2s/epoch - 50ms/step
# Epoch 115/200
# 36/36 - 2s - loss: 4434.8066 - mean_squared_error: 4434.8066 - val_loss: 6852.4966 - val_mean_squared_error: 6852.4966 - 2s/epoch - 49ms/step
# Epoch 116/200
# 36/36 - 2s - loss: 6005.3325 - mean_squared_error: 6005.3325 - val_loss: 10168.5723 - val_mean_squared_error: 10168.5723 - 2s/epoch - 50ms/step
# Epoch 117/200
# 36/36 - 2s - loss: 3979.9592 - mean_squared_error: 3979.9592 - val_loss: 5592.9102 - val_mean_squared_error: 5592.9102 - 2s/epoch - 49ms/step
# Epoch 118/200
# 36/36 - 2s - loss: 4182.9922 - mean_squared_error: 4182.9922 - val_loss: 3887.6699 - val_mean_squared_error: 3887.6699 - 2s/epoch - 49ms/step
# Epoch 119/200
# 36/36 - 2s - loss: 3508.4199 - mean_squared_error: 3508.4199 - val_loss: 4076.7805 - val_mean_squared_error: 4076.7805 - 2s/epoch - 49ms/step
# Epoch 120/200
# 36/36 - 2s - loss: 3573.2966 - mean_squared_error: 3573.2966 - val_loss: 4810.3276 - val_mean_squared_error: 4810.3276 - 2s/epoch - 50ms/step
# Epoch 121/200
# 36/36 - 2s - loss: 4464.8950 - mean_squared_error: 4464.8950 - val_loss: 7167.6284 - val_mean_squared_error: 7167.6284 - 2s/epoch - 49ms/step
# Epoch 122/200
# 36/36 - 2s - loss: 5456.5327 - mean_squared_error: 5456.5327 - val_loss: 5090.8149 - val_mean_squared_error: 5090.8149 - 2s/epoch - 49ms/step
# Epoch 123/200
# 36/36 - 2s - loss: 3438.0959 - mean_squared_error: 3438.0959 - val_loss: 3924.6157 - val_mean_squared_error: 3924.6157 - 2s/epoch - 49ms/step
# Epoch 124/200
# 36/36 - 2s - loss: 3394.3538 - mean_squared_error: 3394.3538 - val_loss: 4446.9185 - val_mean_squared_error: 4446.9185 - 2s/epoch - 49ms/step
# Epoch 125/200
# 36/36 - 2s - loss: 3541.3684 - mean_squared_error: 3541.3684 - val_loss: 3888.1057 - val_mean_squared_error: 3888.1057 - 2s/epoch - 50ms/step
# Epoch 126/200
# 36/36 - 2s - loss: 3216.8105 - mean_squared_error: 3216.8105 - val_loss: 5244.0352 - val_mean_squared_error: 5244.0352 - 2s/epoch - 49ms/step
# Epoch 127/200
# 36/36 - 2s - loss: 3068.9907 - mean_squared_error: 3068.9907 - val_loss: 4432.4888 - val_mean_squared_error: 4432.4888 - 2s/epoch - 50ms/step
# Epoch 128/200
# 36/36 - 2s - loss: 3679.4131 - mean_squared_error: 3679.4131 - val_loss: 4365.9023 - val_mean_squared_error: 4365.9023 - 2s/epoch - 50ms/step
# Epoch 129/200
# 36/36 - 2s - loss: 3590.5635 - mean_squared_error: 3590.5635 - val_loss: 3896.3840 - val_mean_squared_error: 3896.3840 - 2s/epoch - 51ms/step
# Epoch 130/200
# 36/36 - 2s - loss: 3430.4031 - mean_squared_error: 3430.4031 - val_loss: 6487.0591 - val_mean_squared_error: 6487.0591 - 2s/epoch - 51ms/step
# Epoch 131/200
# 36/36 - 2s - loss: 4372.8169 - mean_squared_error: 4372.8169 - val_loss: 5556.6006 - val_mean_squared_error: 5556.6006 - 2s/epoch - 49ms/step
# Epoch 132/200
# 36/36 - 2s - loss: 5749.6260 - mean_squared_error: 5749.6260 - val_loss: 7245.3467 - val_mean_squared_error: 7245.3467 - 2s/epoch - 49ms/step
# Epoch 133/200
# 36/36 - 2s - loss: 3920.6196 - mean_squared_error: 3920.6196 - val_loss: 4429.6724 - val_mean_squared_error: 4429.6724 - 2s/epoch - 49ms/step
# Epoch 134/200
# 36/36 - 2s - loss: 3384.5032 - mean_squared_error: 3384.5032 - val_loss: 4183.3628 - val_mean_squared_error: 4183.3628 - 2s/epoch - 49ms/step
# Epoch 135/200
# 36/36 - 2s - loss: 4512.5947 - mean_squared_error: 4512.5947 - val_loss: 4646.1079 - val_mean_squared_error: 4646.1079 - 2s/epoch - 50ms/step
# Epoch 136/200
# 36/36 - 2s - loss: 3029.4753 - mean_squared_error: 3029.4753 - val_loss: 3803.1865 - val_mean_squared_error: 3803.1865 - 2s/epoch - 49ms/step
# Epoch 137/200
# 36/36 - 2s - loss: 3091.7739 - mean_squared_error: 3091.7739 - val_loss: 5816.9141 - val_mean_squared_error: 5816.9141 - 2s/epoch - 49ms/step
# Epoch 138/200
# 36/36 - 2s - loss: 4108.8789 - mean_squared_error: 4108.8789 - val_loss: 4834.9146 - val_mean_squared_error: 4834.9146 - 2s/epoch - 49ms/step
# Epoch 139/200
# 36/36 - 2s - loss: 3283.5559 - mean_squared_error: 3283.5559 - val_loss: 7478.0659 - val_mean_squared_error: 7478.0659 - 2s/epoch - 49ms/step
# Epoch 140/200
# 36/36 - 2s - loss: 3500.8823 - mean_squared_error: 3500.8823 - val_loss: 3939.3408 - val_mean_squared_error: 3939.3408 - 2s/epoch - 49ms/step
# Epoch 141/200
# 36/36 - 2s - loss: 2763.3589 - mean_squared_error: 2763.3589 - val_loss: 3868.9241 - val_mean_squared_error: 3868.9241 - 2s/epoch - 49ms/step
# Epoch 142/200
# 36/36 - 2s - loss: 2687.5681 - mean_squared_error: 2687.5681 - val_loss: 4297.6006 - val_mean_squared_error: 4297.6006 - 2s/epoch - 49ms/step
# Epoch 143/200
# 36/36 - 2s - loss: 2899.7920 - mean_squared_error: 2899.7920 - val_loss: 5366.9175 - val_mean_squared_error: 5366.9175 - 2s/epoch - 50ms/step
# Epoch 144/200
# 36/36 - 2s - loss: 3167.5916 - mean_squared_error: 3167.5916 - val_loss: 3977.5901 - val_mean_squared_error: 3977.5901 - 2s/epoch - 49ms/step
# Epoch 145/200
# 36/36 - 2s - loss: 3987.7251 - mean_squared_error: 3987.7251 - val_loss: 4601.2305 - val_mean_squared_error: 4601.2305 - 2s/epoch - 49ms/step
# Epoch 146/200
# 36/36 - 2s - loss: 3498.1133 - mean_squared_error: 3498.1133 - val_loss: 4425.1621 - val_mean_squared_error: 4425.1621 - 2s/epoch - 49ms/step
# Epoch 147/200
# 36/36 - 2s - loss: 3068.3899 - mean_squared_error: 3068.3899 - val_loss: 4283.9399 - val_mean_squared_error: 4283.9399 - 2s/epoch - 49ms/step
# Epoch 148/200
# 36/36 - 2s - loss: 2858.1121 - mean_squared_error: 2858.1121 - val_loss: 5647.9980 - val_mean_squared_error: 5647.9980 - 2s/epoch - 49ms/step
# Epoch 149/200
# 36/36 - 2s - loss: 2934.5771 - mean_squared_error: 2934.5771 - val_loss: 4157.3027 - val_mean_squared_error: 4157.3027 - 2s/epoch - 49ms/step
# Epoch 150/200
# 36/36 - 2s - loss: 4370.1299 - mean_squared_error: 4370.1299 - val_loss: 6260.3613 - val_mean_squared_error: 6260.3613 - 2s/epoch - 49ms/step
# Epoch 151/200
# 36/36 - 2s - loss: 35451.2617 - mean_squared_error: 35451.2617 - val_loss: 61193.8438 - val_mean_squared_error: 61193.8438 - 2s/epoch - 50ms/step
# Epoch 152/200
# 36/36 - 2s - loss: 32262.5195 - mean_squared_error: 32262.5195 - val_loss: 25259.2793 - val_mean_squared_error: 25259.2793 - 2s/epoch - 48ms/step
# Epoch 153/200
# 36/36 - 2s - loss: 20468.2656 - mean_squared_error: 20468.2656 - val_loss: 16645.9043 - val_mean_squared_error: 16645.9043 - 2s/epoch - 50ms/step
# Epoch 154/200
# 36/36 - 2s - loss: 13790.2881 - mean_squared_error: 13790.2881 - val_loss: 13055.4678 - val_mean_squared_error: 13055.4678 - 2s/epoch - 50ms/step
# Epoch 154: early stopping

# %%
#data = timeProcess()[1]
#modelo.save('/content/drive/MyDrive/1_Informações_scripts//model__3T3_regressao_menor_erro_Mean_squared_error_200_epochs_'+data+'.h5')

# %% [markdown]
# ## Accuracy Assessment

# %%
#gráfico avaliando a acurácia a partir de treino e teste
plt.plot(history.history['mean_squared_error'])
plt.plot(history.history['val_mean_squared_error'])
plt.title('Accuracy Metric')
plt.ylabel('MSE')
plt.xlabel('Epochs')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
#avaliando a previsão do modelo com os rótulos
prev = modelo.predict(X_test)
plt.title('Previsão dos valores Operetta')
plt.ylabel('Rótulos')
plt.xlabel('Previsão')
plt.plot(prev)#azul - o que o modelo previu
plt.plot(y_test)#laranja - o que se sabe - observado
plt.show()
# Out:
# 16/16 [==============================] - 0s 19ms/step

# %%
# Qualit model analisys
from sklearn.metrics import r2_score,mean_absolute_error, mean_squared_error, mean_squared_log_error, median_absolute_error

# %%
#buscando pelas métricas
print(f"{round(r2_score(y_test, prev) * 100, 2)}% r2_score") #raíz quadrada
print(f"{round(mean_absolute_error(y_test, prev), 2)} Erro médio absoluto") 
print(f"{round(mean_squared_error(y_test, prev), 2)} Erro médio quadrático") #erro médio quadrático
# print(f"{round(median_absolute_error(y_test, prev), 2)}")#Erro médio absoluto sem %
#print(f"{round(median(y_test, prev), 2)} mediana") #erro médio quadrático
# Out:
# 92.7% r2_score
# 83.18 Erro médio absoluto
# 13055.47 Erro médio quadrático

# %%
# #salvando o modelo
data = timeProcess()[1]
modelo.save('/content/drive/MyDrive/Regressão_imagens_DOC_CNN/results_VERO6/modelo_VERO6_100_75_50_25_'+data+'.h5')
