# %% [markdown]
# # MAYV

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
pip install util-gfsilveira
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting util-gfsilveira
#   Downloading util_gfsilveira-0.1-py3-none-any.whl (3.1 kB)
# Installing collected packages: util-gfsilveira
# Successfully installed util-gfsilveira-0.1

# %% [markdown]
# # Imports data structuring

# %%
#organização dos arquivos
import os
#salvar/carregar arquivos em diferentes formatos
import joblib
#organizando os arquivos de forma aleatória
import random
#gerar gráfico
import matplotlib
#estruturação dos dados
import numpy as np
#gerar gráfico
import seaborn as sns
#gerar gráfico
import matplotlib.pyplot as plt
#gerar imagem
import matplotlib.image as mpimg

# %% [markdown]
# # CNN template import

# %%
#modelo de revisão redes neurais - cnn
from keras.models import Sequential
from keras.utils.np_utils import to_categorical
#from keras.utils import to_categorical
from util import meus_uteis, timeProcess, mask_corr_graphic, printLis
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report
from keras.layers import Dense, Conv2D, MaxPooling2D, Dropout, Flatten

# %% [markdown]
# Documents from different files will be stored in this directory

# %%
diretorio = '/content/drive/MyDrive/Regressão_imagens_DOC_CNN/results_MAYV' #alimentando a variável com os arquivos da pasta datasets
lista_dados = os.listdir(diretorio) #listando os arquivos dessa pasta
printLis(lista_dados) #printando as diferentes listas
# Out:
# -------------
# -=< Lista >=-
# -------------
# 0 -> lista_img_camp_clar_100_resized_regressao_MAYV2022-10-25.gz
# 1 -> lista_rotulo_camp_clar_100_resized_regressao_MAYV2022-10-25.gz
# 2 -> lista_img_camp_clar_75_resized_regressao_MAYV2022-10-25.gz
# 3 -> lista_rotulo_camp_clar_75_resized_regressao_MAYV2022-10-25.gz
# 4 -> lista_img_camp_clar_50_resized_regressao_MAYV2022-10-25.gz
# 5 -> lista_rotulo_camp_clar_50_resized_regressao_MAYV2022-10-25.gz
# 6 -> lista_img_camp_clar_25_resized_regressao_MAYV2022-10-25.gz
# 7 -> lista_rotulo_camp_clar_25_resized_regressao_MAYV2022-10-25.gz

# %% [markdown]
# Lists of all images in each file

# %%
#lstando arquivos com as imagens 100%, 75%, 50%, 25%
for k, v in enumerate(lista_dados):
    if k in [0,2,4,6]:
        print(f'{k} -> {v}')
# Out:
# 0 -> lista_img_camp_clar_100_resized_regressao_MAYV2022-10-25.gz
# 2 -> lista_img_camp_clar_75_resized_regressao_MAYV2022-10-25.gz
# 4 -> lista_img_camp_clar_50_resized_regressao_MAYV2022-10-25.gz
# 6 -> lista_img_camp_clar_25_resized_regressao_MAYV2022-10-25.gz

# %% [markdown]
# ## x = features/images

# %%
#somando todas as imagens de diferentes tamanho
X_cem = joblib.load(diretorio+ '/' + lista_dados[0])

# 12 -> 00-lista_img_dapi_crop_75_resized_2021-5-12.gz
X_setcin = joblib.load(diretorio+ '/' + lista_dados[2])

# 10 -> 00-lista_img_dapi_crop_50_resized_2021-5-12.gz
X_cinq = joblib.load(diretorio+ '/' + lista_dados[4])

# 8 -> 00-lista_img_dapi_crop_25_resized_2021-5-12.gz
X_vincin = joblib.load(diretorio+ '/' + lista_dados[6])

x = np.asarray(list(X_cem) + list(X_setcin) + list(X_cinq) + list(X_vincin))

x.shape
# Out:
# (1280, 200, 200, 3)

# %% [markdown]
# ## y = labels

# %% [markdown]
# Opening the labels that were saved in the preparation of the images

# %%
for k, v in enumerate(lista_dados):
    if k in [1,3,5,7]:
        print(f'{k} -> {v}')
# Out:
# 1 -> lista_rotulo_camp_clar_100_resized_regressao_MAYV2022-10-25.gz
# 3 -> lista_rotulo_camp_clar_75_resized_regressao_MAYV2022-10-25.gz
# 5 -> lista_rotulo_camp_clar_50_resized_regressao_MAYV2022-10-25.gz
# 7 -> lista_rotulo_camp_clar_25_resized_regressao_MAYV2022-10-25.gz

# %%
#somando todos os rótulos de diferentes tamanho
y_cem = joblib.load(diretorio+ '/' + lista_dados[1])

# 12 -> 00-lista_img_dapi_crop_75_resized_2021-5-12.gz
y_setcin = joblib.load(diretorio+ '/' + lista_dados[3])

# 10 -> 00-lista_img_dapi_crop_50_resized_2021-5-12.gz
y_cinq = joblib.load(diretorio+ '/' + lista_dados[5])

# 8 -> 00-lista_img_dapi_crop_25_resized_2021-5-12.gz
y_vincin = joblib.load(diretorio+ '/' + lista_dados[7])

y = np.asarray(list(y_cem) + list(y_setcin) + list(y_cinq) + list(y_vincin))

y.shape
# Out:
# (1280,)

# %%
#Train and test split datasets for CNN model
#função que separa as imagens em teste e treino
from sklearn.model_selection import train_test_split

# %% [markdown]
# #Separando dados de validação

# %%
imagens_teste = x.shape[0] * 0.9 #pegando só das imagens 30% das imagens vai para o teste
imagens_treino = x.shape[0] - imagens_teste #restante das imagens (70%)
print('Data for Modeling: ' + str(imagens_teste))
print('Unseen Data For Predictions: ' + str(imagens_treino))
# Out:
# Data for Modeling: 1152.0
# Unseen Data For Predictions: 128.0

# %%
zeros = list(np.zeros(1152))
ones = list(np.ones(128))
lista = np.array(zeros + ones)
lista
# Out:
# array([0., 0., 0., ..., 1., 1., 1.])

# %%
random.shuffle(lista)
lista_valida = [True if i == 1 else False for i in lista]
lista_treino_test = [False if i == 1 else True for i in lista]
np.array(lista_valida)
# Out:
# array([False, False, False, ..., False, False, False])

# %%
#imagens
x_valida = x[lista_valida]
x_treino_test = x[lista_treino_test]

print(x_valida.shape)
print(x_treino_test.shape)
# Out:
# (128, 200, 200, 3)
# (1152, 200, 200, 3)

# %%
#rótulos
y_valida = y[lista_valida]
y_treino_test = y[lista_treino_test]

print(y_valida.shape)
print(y_treino_test.shape)
# Out:
# (128,)
# (1152,)

# %%
#imagens_teste = x.shape[0] * 0.9 #pegando só das imagens 30% das imagens vai para o teste
#imagens_treino = x.shape[0] - imagens_teste #restante das imagens (70%)
#print('Data for Modeling: ' + str(imagens_teste))
#print('Unseen Data For Predictions: ' + str(imagens_treino))
# Out:
# Data for Modeling: 1368.0
# Unseen Data For Predictions: 152.0

# %% [markdown]
# Dados restantes 90%

# %%
data = timeProcess()[1]

# %%
#Salvando 10$ das imagens para validação
joblib.dump(x_valida, '/content/drive/MyDrive/Regressão_imagens_DOC_CNN/results_MAYV/imagens_validação_10%_SH_MAYV_'+data+'.gz')
joblib.dump(y_valida, '/content/drive/MyDrive/Regressão_imagens_DOC_CNN/results_MAYV/rótulos_validação_10%_SH_MAYV_'+data+'.gz')
# Out:
# ['/content/drive/MyDrive/Regressão_imagens_DOC_CNN/results_MAYV/rótulos_validação_10%_SH_MAYV_2022-12-16.gz']

# %% [markdown]
# Test and training separation from a library.

# %%
X_train, X_test, y_train, y_test = train_test_split(x_treino_test, y_treino_test, test_size=0.3, random_state=0)
#variáveis recebem o número de imagens para tes e treino
print(f'{X_train.shape} \n{X_test.shape} \n{y_train.shape} \n{y_test.shape}')
# Out:
# (806, 200, 200, 3)
# (346, 200, 200, 3)
# (806,)
# (346,)

# %%
#salvando os resultados de treino e teste
joblib.dump(X_train, '/content/drive/MyDrive/Regressão_imagens_DOC_CNN/results_MAYV/1_images_de_X_train_MAYV_melhor_modelo_200_epochs_90%_'+data+'.gz')
joblib.dump(y_train, '/content/drive/MyDrive/Regressão_imagens_DOC_CNN/results_MAYV/2_rotulos_de_y_train_MAYV_melhor_modelo_200_epochs_90%_'+data+'.gz')
joblib.dump(X_test, '/content/drive/MyDrive/Regressão_imagens_DOC_CNN/results_MAYV/3_images_de_X_test_MAYV_melhor_modelo_200_epochs_90%_'+data+'.gz')
joblib.dump(y_test, '/content/drive/MyDrive/Regressão_imagens_DOC_CNN/results_MAYV/4_rotulos_de_y_test_MAYV_melhor_model_200_epochs_90%_'+data+'.gz')
# Out:
# ['/content/drive/MyDrive/Regressão_imagens_DOC_CNN/results_MAYV/4_rotulos_de_y_test_MAYV_melhor_model_200_epochs_90%_2022-12-16.gz']

# %% [markdown]
# ### Model determination

# %%
modelo = Sequential()
modelo.add(Conv2D(32, kernel_size=3, activation='relu', input_shape=X_train[0].shape))
#função de ativação relu é muito utilizado para problemas de regressão
modelo.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2), padding='valid'))
modelo.add(Conv2D(64, kernel_size=3, activation='relu'))
modelo.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2), padding='valid'))
modelo.add(Conv2D(128, kernel_size=3, activation='relu'))
modelo.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2), padding='valid'))
modelo.add(Conv2D(256, kernel_size=3, activation='relu'))
modelo.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2), padding='valid'))
modelo.add(Flatten())
modelo.add(Dropout(0.9))
modelo.add(Dense(1, activation='linear'))
#apenas uma saída e de forma linear
modelo.compile(optimizer='adam', loss='mse', metrics=['mean_squared_error'])
print(modelo.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 198, 198, 32)      896
#
#  max_pooling2d (MaxPooling2D  (None, 99, 99, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 97, 97, 64)        18496
#
#  max_pooling2d_1 (MaxPooling  (None, 48, 48, 64)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 46, 46, 128)       73856
#
#  max_pooling2d_2 (MaxPooling  (None, 23, 23, 128)      0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 21, 21, 256)       295168
#
#  max_pooling2d_3 (MaxPooling  (None, 10, 10, 256)      0
#  2D)
#
#  flatten (Flatten)           (None, 25600)             0
#
#  dropout (Dropout)           (None, 25600)             0
#
#  dense (Dense)               (None, 1)                 25601
#
# =================================================================
# Total params: 414,017
# Trainable params: 414,017
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# # Training and testing epochs

# %%
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.callbacks import ModelCheckpoint

# %%
# simple early stopping
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=18)

# %%
# fit model
history = modelo.fit(X_train,y_train,
                    validation_data=(X_test, y_test), 
                    epochs=200, verbose=2, 
                    callbacks=[es]
                     )
# Out:
# Epoch 1/200
# 26/26 - 11s - loss: 88019.8984 - mean_squared_error: 88019.8984 - val_loss: 43849.9727 - val_mean_squared_error: 43849.9727 - 11s/epoch - 411ms/step
# Epoch 2/200
# 26/26 - 1s - loss: 55194.1445 - mean_squared_error: 55194.1445 - val_loss: 59403.5039 - val_mean_squared_error: 59403.5039 - 1s/epoch - 46ms/step
# Epoch 3/200
# 26/26 - 1s - loss: 53724.8281 - mean_squared_error: 53724.8281 - val_loss: 33610.4961 - val_mean_squared_error: 33610.4961 - 1s/epoch - 45ms/step
# Epoch 4/200
# 26/26 - 1s - loss: 53720.2930 - mean_squared_error: 53720.2930 - val_loss: 35092.6719 - val_mean_squared_error: 35092.6719 - 1s/epoch - 46ms/step
# Epoch 5/200
# 26/26 - 1s - loss: 49304.9922 - mean_squared_error: 49304.9922 - val_loss: 29687.4883 - val_mean_squared_error: 29687.4883 - 1s/epoch - 51ms/step
# Epoch 6/200
# 26/26 - 1s - loss: 40268.6719 - mean_squared_error: 40268.6719 - val_loss: 28735.5312 - val_mean_squared_error: 28735.5312 - 1s/epoch - 46ms/step
# Epoch 7/200
# 26/26 - 1s - loss: 33768.7188 - mean_squared_error: 33768.7188 - val_loss: 21140.2266 - val_mean_squared_error: 21140.2266 - 1s/epoch - 51ms/step
# Epoch 8/200
# 26/26 - 1s - loss: 33311.9922 - mean_squared_error: 33311.9922 - val_loss: 31535.4766 - val_mean_squared_error: 31535.4766 - 1s/epoch - 45ms/step
# Epoch 9/200
# 26/26 - 1s - loss: 34284.7500 - mean_squared_error: 34284.7500 - val_loss: 26062.1445 - val_mean_squared_error: 26062.1445 - 1s/epoch - 51ms/step
# Epoch 10/200
# 26/26 - 1s - loss: 33341.0430 - mean_squared_error: 33341.0430 - val_loss: 18887.1484 - val_mean_squared_error: 18887.1484 - 1s/epoch - 51ms/step
# Epoch 11/200
# 26/26 - 1s - loss: 25739.9746 - mean_squared_error: 25739.9746 - val_loss: 13704.7500 - val_mean_squared_error: 13704.7500 - 1s/epoch - 45ms/step
# Epoch 12/200
# 26/26 - 1s - loss: 22518.5527 - mean_squared_error: 22518.5527 - val_loss: 13454.7490 - val_mean_squared_error: 13454.7490 - 1s/epoch - 51ms/step
# Epoch 13/200
# 26/26 - 1s - loss: 22453.9609 - mean_squared_error: 22453.9609 - val_loss: 11349.9795 - val_mean_squared_error: 11349.9795 - 1s/epoch - 51ms/step
# Epoch 14/200
# 26/26 - 1s - loss: 21681.1738 - mean_squared_error: 21681.1738 - val_loss: 12886.8818 - val_mean_squared_error: 12886.8818 - 1s/epoch - 51ms/step
# Epoch 15/200
# 26/26 - 1s - loss: 21621.2949 - mean_squared_error: 21621.2949 - val_loss: 13891.0264 - val_mean_squared_error: 13891.0264 - 1s/epoch - 45ms/step
# Epoch 16/200
# 26/26 - 1s - loss: 16853.1211 - mean_squared_error: 16853.1211 - val_loss: 14894.1113 - val_mean_squared_error: 14894.1113 - 1s/epoch - 51ms/step
# Epoch 17/200
# 26/26 - 1s - loss: 17487.2539 - mean_squared_error: 17487.2539 - val_loss: 13784.3467 - val_mean_squared_error: 13784.3467 - 1s/epoch - 47ms/step
# Epoch 18/200
# 26/26 - 1s - loss: 15460.7539 - mean_squared_error: 15460.7539 - val_loss: 7485.7441 - val_mean_squared_error: 7485.7441 - 1s/epoch - 52ms/step
# Epoch 19/200
# 26/26 - 1s - loss: 12583.1865 - mean_squared_error: 12583.1865 - val_loss: 16174.0029 - val_mean_squared_error: 16174.0029 - 1s/epoch - 55ms/step
# Epoch 20/200
# 26/26 - 1s - loss: 15929.4326 - mean_squared_error: 15929.4326 - val_loss: 6612.8813 - val_mean_squared_error: 6612.8813 - 1s/epoch - 46ms/step
# Epoch 21/200
# 26/26 - 1s - loss: 11398.5498 - mean_squared_error: 11398.5498 - val_loss: 20859.0137 - val_mean_squared_error: 20859.0137 - 1s/epoch - 51ms/step
# Epoch 22/200
# 26/26 - 1s - loss: 21521.9707 - mean_squared_error: 21521.9707 - val_loss: 14224.4131 - val_mean_squared_error: 14224.4131 - 1s/epoch - 51ms/step
# Epoch 23/200
# 26/26 - 1s - loss: 16941.1836 - mean_squared_error: 16941.1836 - val_loss: 7671.0894 - val_mean_squared_error: 7671.0894 - 1s/epoch - 46ms/step
# Epoch 24/200
# 26/26 - 1s - loss: 14920.2373 - mean_squared_error: 14920.2373 - val_loss: 9315.5898 - val_mean_squared_error: 9315.5898 - 1s/epoch - 51ms/step
# Epoch 25/200
# 26/26 - 1s - loss: 12592.6709 - mean_squared_error: 12592.6709 - val_loss: 4975.4463 - val_mean_squared_error: 4975.4463 - 1s/epoch - 47ms/step
# Epoch 26/200
# 26/26 - 1s - loss: 10801.0557 - mean_squared_error: 10801.0557 - val_loss: 18257.4551 - val_mean_squared_error: 18257.4551 - 1s/epoch - 46ms/step
# Epoch 27/200
# 26/26 - 1s - loss: 13979.4902 - mean_squared_error: 13979.4902 - val_loss: 6353.8945 - val_mean_squared_error: 6353.8945 - 1s/epoch - 46ms/step
# Epoch 28/200
# 26/26 - 1s - loss: 9263.1846 - mean_squared_error: 9263.1846 - val_loss: 4862.2729 - val_mean_squared_error: 4862.2729 - 1s/epoch - 51ms/step
# Epoch 29/200
# 26/26 - 1s - loss: 9176.9023 - mean_squared_error: 9176.9023 - val_loss: 12593.9941 - val_mean_squared_error: 12593.9941 - 1s/epoch - 47ms/step
# Epoch 30/200
# 26/26 - 1s - loss: 10589.5820 - mean_squared_error: 10589.5820 - val_loss: 13238.1562 - val_mean_squared_error: 13238.1562 - 1s/epoch - 47ms/step
# Epoch 31/200
# 26/26 - 1s - loss: 10870.6377 - mean_squared_error: 10870.6377 - val_loss: 8178.8047 - val_mean_squared_error: 8178.8047 - 1s/epoch - 47ms/step
# Epoch 32/200
# 26/26 - 1s - loss: 11409.2764 - mean_squared_error: 11409.2764 - val_loss: 7471.4937 - val_mean_squared_error: 7471.4937 - 1s/epoch - 52ms/step
# Epoch 33/200
# 26/26 - 1s - loss: 11092.3057 - mean_squared_error: 11092.3057 - val_loss: 5826.9297 - val_mean_squared_error: 5826.9297 - 1s/epoch - 51ms/step
# Epoch 34/200
# 26/26 - 1s - loss: 8970.9092 - mean_squared_error: 8970.9092 - val_loss: 4915.5884 - val_mean_squared_error: 4915.5884 - 1s/epoch - 51ms/step
# Epoch 35/200
# 26/26 - 1s - loss: 10974.3721 - mean_squared_error: 10974.3721 - val_loss: 3981.7673 - val_mean_squared_error: 3981.7673 - 1s/epoch - 52ms/step
# Epoch 36/200
# 26/26 - 1s - loss: 12927.2266 - mean_squared_error: 12927.2266 - val_loss: 12296.6123 - val_mean_squared_error: 12296.6123 - 1s/epoch - 51ms/step
# Epoch 37/200
# 26/26 - 1s - loss: 10492.7441 - mean_squared_error: 10492.7441 - val_loss: 5162.9268 - val_mean_squared_error: 5162.9268 - 1s/epoch - 46ms/step
# Epoch 38/200
# 26/26 - 1s - loss: 8907.2422 - mean_squared_error: 8907.2422 - val_loss: 17846.6719 - val_mean_squared_error: 17846.6719 - 1s/epoch - 52ms/step
# Epoch 39/200
# 26/26 - 1s - loss: 17414.0957 - mean_squared_error: 17414.0957 - val_loss: 9215.8350 - val_mean_squared_error: 9215.8350 - 1s/epoch - 52ms/step
# Epoch 40/200
# 26/26 - 1s - loss: 8009.4058 - mean_squared_error: 8009.4058 - val_loss: 8655.0371 - val_mean_squared_error: 8655.0371 - 1s/epoch - 52ms/step
# Epoch 41/200
# 26/26 - 1s - loss: 10081.4141 - mean_squared_error: 10081.4141 - val_loss: 5993.9624 - val_mean_squared_error: 5993.9624 - 1s/epoch - 47ms/step
# Epoch 42/200
# 26/26 - 1s - loss: 7669.4980 - mean_squared_error: 7669.4980 - val_loss: 3577.0308 - val_mean_squared_error: 3577.0308 - 1s/epoch - 52ms/step
# Epoch 43/200
# 26/26 - 1s - loss: 5251.2563 - mean_squared_error: 5251.2563 - val_loss: 10294.2490 - val_mean_squared_error: 10294.2490 - 1s/epoch - 52ms/step
# Epoch 44/200
# 26/26 - 1s - loss: 10048.4443 - mean_squared_error: 10048.4443 - val_loss: 11308.5752 - val_mean_squared_error: 11308.5752 - 1s/epoch - 52ms/step
# Epoch 45/200
# 26/26 - 1s - loss: 6934.3433 - mean_squared_error: 6934.3433 - val_loss: 8885.8525 - val_mean_squared_error: 8885.8525 - 1s/epoch - 47ms/step
# Epoch 46/200
# 26/26 - 1s - loss: 6294.7734 - mean_squared_error: 6294.7734 - val_loss: 3438.1831 - val_mean_squared_error: 3438.1831 - 1s/epoch - 47ms/step
# Epoch 47/200
# 26/26 - 1s - loss: 6583.9404 - mean_squared_error: 6583.9404 - val_loss: 9496.9014 - val_mean_squared_error: 9496.9014 - 1s/epoch - 47ms/step
# Epoch 48/200
# 26/26 - 1s - loss: 8095.6099 - mean_squared_error: 8095.6099 - val_loss: 4771.8281 - val_mean_squared_error: 4771.8281 - 1s/epoch - 52ms/step
# Epoch 49/200
# 26/26 - 1s - loss: 6310.0581 - mean_squared_error: 6310.0581 - val_loss: 3684.8464 - val_mean_squared_error: 3684.8464 - 1s/epoch - 47ms/step
# Epoch 50/200
# 26/26 - 1s - loss: 5299.7446 - mean_squared_error: 5299.7446 - val_loss: 3230.0156 - val_mean_squared_error: 3230.0156 - 1s/epoch - 52ms/step
# Epoch 51/200
# 26/26 - 1s - loss: 5126.4170 - mean_squared_error: 5126.4170 - val_loss: 6208.4082 - val_mean_squared_error: 6208.4082 - 1s/epoch - 47ms/step
# Epoch 52/200
# 26/26 - 1s - loss: 7765.0596 - mean_squared_error: 7765.0596 - val_loss: 5825.8228 - val_mean_squared_error: 5825.8228 - 1s/epoch - 52ms/step
# Epoch 53/200
# 26/26 - 1s - loss: 5969.9980 - mean_squared_error: 5969.9980 - val_loss: 3175.8440 - val_mean_squared_error: 3175.8440 - 1s/epoch - 47ms/step
# Epoch 54/200
# 26/26 - 1s - loss: 5228.0669 - mean_squared_error: 5228.0669 - val_loss: 5107.3145 - val_mean_squared_error: 5107.3145 - 1s/epoch - 47ms/step
# Epoch 55/200
# 26/26 - 1s - loss: 7665.6079 - mean_squared_error: 7665.6079 - val_loss: 4985.3242 - val_mean_squared_error: 4985.3242 - 1s/epoch - 47ms/step
# Epoch 56/200
# 26/26 - 1s - loss: 6184.6782 - mean_squared_error: 6184.6782 - val_loss: 3972.2803 - val_mean_squared_error: 3972.2803 - 1s/epoch - 52ms/step
# Epoch 57/200
# 26/26 - 1s - loss: 13066.2656 - mean_squared_error: 13066.2656 - val_loss: 5419.3794 - val_mean_squared_error: 5419.3794 - 1s/epoch - 51ms/step
# Epoch 58/200
# 26/26 - 1s - loss: 6144.6421 - mean_squared_error: 6144.6421 - val_loss: 4435.2188 - val_mean_squared_error: 4435.2188 - 1s/epoch - 47ms/step
# Epoch 59/200
# 26/26 - 1s - loss: 6879.4224 - mean_squared_error: 6879.4224 - val_loss: 4608.1011 - val_mean_squared_error: 4608.1011 - 1s/epoch - 51ms/step
# Epoch 60/200
# 26/26 - 1s - loss: 5408.2158 - mean_squared_error: 5408.2158 - val_loss: 5676.0244 - val_mean_squared_error: 5676.0244 - 1s/epoch - 52ms/step
# Epoch 61/200
# 26/26 - 1s - loss: 4594.7495 - mean_squared_error: 4594.7495 - val_loss: 2609.6836 - val_mean_squared_error: 2609.6836 - 1s/epoch - 47ms/step
# Epoch 62/200
# 26/26 - 1s - loss: 4440.6602 - mean_squared_error: 4440.6602 - val_loss: 6405.0508 - val_mean_squared_error: 6405.0508 - 1s/epoch - 47ms/step
# Epoch 63/200
# 26/26 - 1s - loss: 4792.8389 - mean_squared_error: 4792.8389 - val_loss: 3200.6240 - val_mean_squared_error: 3200.6240 - 1s/epoch - 47ms/step
# Epoch 64/200
# 26/26 - 1s - loss: 4185.7231 - mean_squared_error: 4185.7231 - val_loss: 4600.1064 - val_mean_squared_error: 4600.1064 - 1s/epoch - 47ms/step
# Epoch 65/200
# 26/26 - 1s - loss: 5072.0259 - mean_squared_error: 5072.0259 - val_loss: 7184.9473 - val_mean_squared_error: 7184.9473 - 1s/epoch - 51ms/step
# Epoch 66/200
# 26/26 - 1s - loss: 5277.3896 - mean_squared_error: 5277.3896 - val_loss: 2898.0725 - val_mean_squared_error: 2898.0725 - 1s/epoch - 46ms/step
# Epoch 67/200
# 26/26 - 1s - loss: 5627.7432 - mean_squared_error: 5627.7432 - val_loss: 7949.5859 - val_mean_squared_error: 7949.5859 - 1s/epoch - 51ms/step
# Epoch 68/200
# 26/26 - 1s - loss: 4365.5000 - mean_squared_error: 4365.5000 - val_loss: 2947.8884 - val_mean_squared_error: 2947.8884 - 1s/epoch - 51ms/step
# Epoch 69/200
# 26/26 - 1s - loss: 5191.3442 - mean_squared_error: 5191.3442 - val_loss: 3247.2124 - val_mean_squared_error: 3247.2124 - 1s/epoch - 51ms/step
# Epoch 70/200
# 26/26 - 1s - loss: 4076.9102 - mean_squared_error: 4076.9102 - val_loss: 3526.4448 - val_mean_squared_error: 3526.4448 - 1s/epoch - 46ms/step
# Epoch 71/200
# 26/26 - 1s - loss: 5478.4038 - mean_squared_error: 5478.4038 - val_loss: 3162.6885 - val_mean_squared_error: 3162.6885 - 1s/epoch - 51ms/step
# Epoch 72/200
# 26/26 - 1s - loss: 6987.6899 - mean_squared_error: 6987.6899 - val_loss: 8658.8984 - val_mean_squared_error: 8658.8984 - 1s/epoch - 46ms/step
# Epoch 73/200
# 26/26 - 1s - loss: 4754.8750 - mean_squared_error: 4754.8750 - val_loss: 3738.6694 - val_mean_squared_error: 3738.6694 - 1s/epoch - 46ms/step
# Epoch 74/200
# 26/26 - 1s - loss: 4303.3110 - mean_squared_error: 4303.3110 - val_loss: 2941.9272 - val_mean_squared_error: 2941.9272 - 1s/epoch - 52ms/step
# Epoch 75/200
# 26/26 - 1s - loss: 4715.9175 - mean_squared_error: 4715.9175 - val_loss: 3203.8970 - val_mean_squared_error: 3203.8970 - 1s/epoch - 51ms/step
# Epoch 76/200
# 26/26 - 1s - loss: 3567.9946 - mean_squared_error: 3567.9946 - val_loss: 6209.0088 - val_mean_squared_error: 6209.0088 - 1s/epoch - 51ms/step
# Epoch 77/200
# 26/26 - 1s - loss: 6154.8643 - mean_squared_error: 6154.8643 - val_loss: 6335.5854 - val_mean_squared_error: 6335.5854 - 1s/epoch - 46ms/step
# Epoch 78/200
# 26/26 - 1s - loss: 4120.4800 - mean_squared_error: 4120.4800 - val_loss: 13003.5459 - val_mean_squared_error: 13003.5459 - 1s/epoch - 51ms/step
# Epoch 79/200
# 26/26 - 1s - loss: 9302.8428 - mean_squared_error: 9302.8428 - val_loss: 4628.0908 - val_mean_squared_error: 4628.0908 - 1s/epoch - 46ms/step
# Epoch 79: early stopping

# %%
#data = timeProcess()[1]
#modelo.save('/content/drive/MyDrive/1_Informações_scripts//model__3T3_regressao_menor_erro_Mean_squared_error_200_epochs_'+data+'.h5')

# %% [markdown]
# ## Accuracy Assessment

# %%
#gráfico avaliando a acurácia a partir de treino e teste
plt.plot(history.history['mean_squared_error'])
plt.plot(history.history['val_mean_squared_error'])
plt.title('Accuracy Metric')
plt.ylabel('MSE')
plt.xlabel('Epochs')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
#avaliando a previsão do modelo com os rótulos
prev = modelo.predict(X_test)
plt.title('Previsão dos valores Operetta')
plt.ylabel('Rótulos')
plt.xlabel('Previsão')
plt.plot(prev)#azul - o que o modelo previu
plt.plot(y_test)#laranja - o que se sabe - observado
plt.show()
# Out:
# 11/11 [==============================] - 0s 19ms/step

# %%
# Qualit model analisys
from sklearn.metrics import r2_score,mean_absolute_error, mean_squared_error, mean_squared_log_error, median_absolute_error

# %%
#buscando pelas métricas
print(f"{round(r2_score(y_test, prev) * 100, 2)}% r2_score") #raíz quadrada
print(f"{round(mean_absolute_error(y_test, prev), 2)} Erro médio absoluto") 
print(f"{round(mean_squared_error(y_test, prev), 2)} Erro médio quadrático") #erro médio quadrático
# print(f"{round(median_absolute_error(y_test, prev), 2)}")#Erro médio absoluto sem %
#print(f"{round(median(y_test, prev), 2)} mediana") #erro médio quadrático
# Out:
# 87.16% r2_score
# 53.38 Erro médio absoluto
# 4628.09 Erro médio quadrático

# %%
# #salvando o modelo
data = timeProcess()[1]
modelo.save('/content/drive/MyDrive/Regressão_imagens_DOC_CNN/results_MAYV/modelo_MAYV_100_75_50_25_'+data+'.h5')
