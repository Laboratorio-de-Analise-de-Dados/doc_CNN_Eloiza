# %% [markdown]
# # THP1

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
pip install util-gfsilveira
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting util-gfsilveira
#   Downloading util_gfsilveira-0.1-py3-none-any.whl (3.1 kB)
# Installing collected packages: util-gfsilveira
# Successfully installed util-gfsilveira-0.1

# %% [markdown]
# # Imports data structuring

# %%
#organização dos arquivos
import os
#salvar/carregar arquivos em diferentes formatos
import joblib
#organizando os arquivos de forma aleatória
import random
#gerar gráfico
import matplotlib
#estruturação dos dados
import numpy as np
#gerar gráfico
import seaborn as sns
#gerar gráfico
import matplotlib.pyplot as plt
#gerar imagem
import matplotlib.image as mpimg

# %% [markdown]
# # CNN template import

# %%
#modelo de revisão redes neurais - cnn
from keras.models import Sequential
from keras.utils.np_utils import to_categorical
#from keras.utils import to_categorical
from util import meus_uteis, timeProcess, mask_corr_graphic, printLis
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report
from keras.layers import Dense, Conv2D, MaxPooling2D, Dropout, Flatten

# %% [markdown]
# Documents from different files will be stored in this directory

# %%
diretorio = '/content/drive/MyDrive/Regressão_imagens_DOC_CNN/results_THP1' #alimentando a variável com os arquivos da pasta datasets
lista_dados = os.listdir(diretorio) #listando os arquivos dessa pasta
printLis(lista_dados) #printando as diferentes listas
# Out:
# -------------
# -=< Lista >=-
# -------------
# 0 -> lista_img_camp_clar_100_resized_regressao_THP12022-10-25.gz
# 1 -> lista_rotulo_camp_clar_100_resized_regressao_THP12022-10-25.gz
# 2 -> lista_img_camp_clar_75_resized_regressao_THP12022-10-25.gz
# 3 -> lista_rotulo_camp_clar_75_resized_regressao_THP12022-10-25.gz
# 4 -> lista_img_camp_clar_50_resized_regressao_THP12022-10-25.gz
# 5 -> lista_rotulo_camp_clar_50_resized_regressao_THP12022-10-25.gz
# 6 -> lista_img_camp_clar_25_resized_regressao_THP12022-10-25.gz
# 7 -> lista_rotulo_camp_clar_25_resized_regressao_THP12022-10-25.gz

# %% [markdown]
# Lists of all images in each file

# %%
#lstando arquivos com as imagens 100%, 75%, 50%, 25%
for k, v in enumerate(lista_dados):
    if k in [0,2,4,6]:
        print(f'{k} -> {v}')
# Out:
# 0 -> lista_img_camp_clar_100_resized_regressao_THP12022-10-25.gz
# 2 -> lista_img_camp_clar_75_resized_regressao_THP12022-10-25.gz
# 4 -> lista_img_camp_clar_50_resized_regressao_THP12022-10-25.gz
# 6 -> lista_img_camp_clar_25_resized_regressao_THP12022-10-25.gz

# %% [markdown]
# ## x = features/images

# %%
#somando todas as imagens de diferentes tamanho
X_cem = joblib.load(diretorio+ '/' + lista_dados[0])

# 12 -> 00-lista_img_dapi_crop_75_resized_2021-5-12.gz
X_setcin = joblib.load(diretorio+ '/' + lista_dados[2])

# 10 -> 00-lista_img_dapi_crop_50_resized_2021-5-12.gz
X_cinq = joblib.load(diretorio+ '/' + lista_dados[4])

# 8 -> 00-lista_img_dapi_crop_25_resized_2021-5-12.gz
X_vincin = joblib.load(diretorio+ '/' + lista_dados[6])

x = np.asarray(list(X_cem) + list(X_setcin) + list(X_cinq) + list(X_vincin))

x.shape
# Out:
# (1696, 200, 200, 3)

# %% [markdown]
# ## y = labels

# %% [markdown]
# Opening the labels that were saved in the preparation of the images

# %%
for k, v in enumerate(lista_dados):
    if k in [1,3,5,7]:
        print(f'{k} -> {v}')
# Out:
# 1 -> lista_rotulo_camp_clar_100_resized_regressao_THP12022-10-25.gz
# 3 -> lista_rotulo_camp_clar_75_resized_regressao_THP12022-10-25.gz
# 5 -> lista_rotulo_camp_clar_50_resized_regressao_THP12022-10-25.gz
# 7 -> lista_rotulo_camp_clar_25_resized_regressao_THP12022-10-25.gz

# %%
#somando todos os rótulos de diferentes tamanho
y_cem = joblib.load(diretorio+ '/' + lista_dados[1])

# 12 -> 00-lista_img_dapi_crop_75_resized_2021-5-12.gz
y_setcin = joblib.load(diretorio+ '/' + lista_dados[3])

# 10 -> 00-lista_img_dapi_crop_50_resized_2021-5-12.gz
y_cinq = joblib.load(diretorio+ '/' + lista_dados[5])

# 8 -> 00-lista_img_dapi_crop_25_resized_2021-5-12.gz
y_vincin = joblib.load(diretorio+ '/' + lista_dados[7])

y = np.asarray(list(y_cem) + list(y_setcin) + list(y_cinq) + list(y_vincin))

y.shape
# Out:
# (1696,)

# %%
#Train and test split datasets for CNN model
#função que separa as imagens em teste e treino
from sklearn.model_selection import train_test_split

# %% [markdown]
# #Separando dados de validação

# %%
imagens_teste = x.shape[0] * 0.9 #pegando só das imagens 30% das imagens vai para o teste
imagens_treino = x.shape[0] - imagens_teste #restante das imagens (70%)
print('Data for Modeling: ' + str(imagens_teste))
print('Unseen Data For Predictions: ' + str(imagens_treino))
# Out:
# Data for Modeling: 1526.4
# Unseen Data For Predictions: 169.5999999999999

# %%
zeros = list(np.zeros(1527))
ones = list(np.ones(169))
lista = np.array(zeros + ones)
lista
# Out:
# array([0., 0., 0., ..., 1., 1., 1.])

# %%
random.shuffle(lista)
lista_valida = [True if i == 1 else False for i in lista]
lista_treino_test = [False if i == 1 else True for i in lista]
np.array(lista_valida)
# Out:
# array([False, False,  True, ..., False, False, False])

# %%
#imagens
x_valida = x[lista_valida]
x_treino_test = x[lista_treino_test]

print(x_valida.shape)
print(x_treino_test.shape)
# Out:
# (169, 200, 200, 3)
# (1527, 200, 200, 3)

# %%
#rótulos
y_valida = y[lista_valida]
y_treino_test = y[lista_treino_test]

print(y_valida.shape)
print(y_treino_test.shape)
# Out:
# (169,)
# (1527,)

# %%
#imagens_teste = x.shape[0] * 0.9 #pegando só das imagens 30% das imagens vai para o teste
#imagens_treino = x.shape[0] - imagens_teste #restante das imagens (70%)
#print('Data for Modeling: ' + str(imagens_teste))
#print('Unseen Data For Predictions: ' + str(imagens_treino))
# Out:
# Data for Modeling: 1368.0
# Unseen Data For Predictions: 152.0

# %% [markdown]
# Dados restantes 90%

# %%
data = timeProcess()[1]

# %%
#Salvando 10$ das imagens para validação
joblib.dump(x_valida, '/content/drive/MyDrive/Regressão_imagens_DOC_CNN/results_THP1/imagens_validação_10%_THP1_'+data+'.gz')
joblib.dump(y_valida, '/content/drive/MyDrive/Regressão_imagens_DOC_CNN/results_THP1/rótulos_validação_10%_THP1_'+data+'.gz')
# Out:
# ['/content/drive/MyDrive/Regressão_imagens_DOC_CNN/results_THP1/rótulos_validação_10%_THP1_2022-12-15.gz']

# %% [markdown]
# Test and training separation from a library.

# %%
X_train, X_test, y_train, y_test = train_test_split(x_treino_test, y_treino_test, test_size=0.3, random_state=0)
#variáveis recebem o número de imagens para tes e treino
print(f'{X_train.shape} \n{X_test.shape} \n{y_train.shape} \n{y_test.shape}')
# Out:
# (1068, 200, 200, 3)
# (459, 200, 200, 3)
# (1068,)
# (459,)

# %%
#salvando os resultados de treino e teste
joblib.dump(X_train, '/content/drive/MyDrive/Regressão_imagens_DOC_CNN/results_THP1/1_images_de_X_train_THP1_melhor_modelo_200_epochs_90%_'+data+'.gz')
joblib.dump(y_train, '/content/drive/MyDrive/Regressão_imagens_DOC_CNN/results_THP1/2_rotulos_de_y_train_THP1_melhor_modelo_200_epochs_90%_'+data+'.gz')
joblib.dump(X_test, '/content/drive/MyDrive/Regressão_imagens_DOC_CNN/results_THP1/3_images_de_X_test_THP1_melhor_modelo_200_epochs_90%_'+data+'.gz')
joblib.dump(y_test, '/content/drive/MyDrive/Regressão_imagens_DOC_CNN/results_THP1/4_rotulos_de_y_test_THP1_melhor_model_200_epochs_90%_'+data+'.gz')
# Out:
# ['/content/drive/MyDrive/Regressão_imagens_DOC_CNN/results_THP1/4_rotulos_de_y_test_THP1_melhor_model_200_epochs_90%_2022-12-15.gz']

# %% [markdown]
# ### Model determination

# %%
modelo = Sequential()
modelo.add(Conv2D(32, kernel_size=3, activation='relu', input_shape=X_train[0].shape))
#função de ativação relu é muito utilizado para problemas de regressão
modelo.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2), padding='valid'))
modelo.add(Conv2D(64, kernel_size=3, activation='relu'))
modelo.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2), padding='valid'))
modelo.add(Conv2D(128, kernel_size=3, activation='relu'))
modelo.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2), padding='valid'))
modelo.add(Conv2D(256, kernel_size=3, activation='relu'))
modelo.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2), padding='valid'))
modelo.add(Flatten())
modelo.add(Dropout(0.9))
modelo.add(Dense(1, activation='linear'))
#apenas uma saída e de forma linear
modelo.compile(optimizer='adam', loss='mse', metrics=['mean_squared_error'])
print(modelo.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 198, 198, 32)      896
#
#  max_pooling2d (MaxPooling2D  (None, 99, 99, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 97, 97, 64)        18496
#
#  max_pooling2d_1 (MaxPooling  (None, 48, 48, 64)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 46, 46, 128)       73856
#
#  max_pooling2d_2 (MaxPooling  (None, 23, 23, 128)      0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 21, 21, 256)       295168
#
#  max_pooling2d_3 (MaxPooling  (None, 10, 10, 256)      0
#  2D)
#
#  flatten (Flatten)           (None, 25600)             0
#
#  dropout (Dropout)           (None, 25600)             0
#
#  dense (Dense)               (None, 1)                 25601
#
# =================================================================
# Total params: 414,017
# Trainable params: 414,017
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# # Training and testing epochs

# %%
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.callbacks import ModelCheckpoint

# %%
# simple early stopping
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=18)

# %%
# fit model
history = modelo.fit(X_train,y_train,
                    validation_data=(X_test, y_test), 
                    epochs=200, verbose=2, 
                    callbacks=[es]
                     )
# Out:
# Epoch 1/200
# 34/34 - 2s - loss: 5750.0000 - mean_squared_error: 5750.0000 - val_loss: 8230.0723 - val_mean_squared_error: 8230.0723 - 2s/epoch - 53ms/step
# Epoch 2/200
# 34/34 - 2s - loss: 5418.0352 - mean_squared_error: 5418.0352 - val_loss: 13988.8193 - val_mean_squared_error: 13988.8193 - 2s/epoch - 48ms/step
# Epoch 3/200
# 34/34 - 2s - loss: 6107.0923 - mean_squared_error: 6107.0923 - val_loss: 5426.4473 - val_mean_squared_error: 5426.4473 - 2s/epoch - 48ms/step
# Epoch 4/200
# 34/34 - 2s - loss: 4388.0635 - mean_squared_error: 4388.0635 - val_loss: 7505.0269 - val_mean_squared_error: 7505.0269 - 2s/epoch - 48ms/step
# Epoch 5/200
# 34/34 - 2s - loss: 4614.0098 - mean_squared_error: 4614.0098 - val_loss: 9312.1562 - val_mean_squared_error: 9312.1562 - 2s/epoch - 48ms/step
# Epoch 6/200
# 34/34 - 2s - loss: 5437.4336 - mean_squared_error: 5437.4336 - val_loss: 7182.9038 - val_mean_squared_error: 7182.9038 - 2s/epoch - 49ms/step
# Epoch 7/200
# 34/34 - 2s - loss: 3843.3354 - mean_squared_error: 3843.3354 - val_loss: 5249.1313 - val_mean_squared_error: 5249.1313 - 2s/epoch - 50ms/step
# Epoch 8/200
# 34/34 - 2s - loss: 3921.7480 - mean_squared_error: 3921.7480 - val_loss: 5479.2695 - val_mean_squared_error: 5479.2695 - 2s/epoch - 50ms/step
# Epoch 9/200
# 34/34 - 2s - loss: 4789.1865 - mean_squared_error: 4789.1865 - val_loss: 5550.9795 - val_mean_squared_error: 5550.9795 - 2s/epoch - 49ms/step
# Epoch 10/200
# 34/34 - 2s - loss: 5938.4917 - mean_squared_error: 5938.4917 - val_loss: 6655.0864 - val_mean_squared_error: 6655.0864 - 2s/epoch - 50ms/step
# Epoch 11/200
# 34/34 - 2s - loss: 4720.7622 - mean_squared_error: 4720.7622 - val_loss: 4956.3096 - val_mean_squared_error: 4956.3096 - 2s/epoch - 48ms/step
# Epoch 12/200
# 34/34 - 2s - loss: 3597.1230 - mean_squared_error: 3597.1230 - val_loss: 4607.3452 - val_mean_squared_error: 4607.3452 - 2s/epoch - 48ms/step
# Epoch 13/200
# 34/34 - 2s - loss: 3576.3003 - mean_squared_error: 3576.3003 - val_loss: 5387.2109 - val_mean_squared_error: 5387.2109 - 2s/epoch - 50ms/step
# Epoch 14/200
# 34/34 - 2s - loss: 3917.2041 - mean_squared_error: 3917.2041 - val_loss: 4325.0103 - val_mean_squared_error: 4325.0103 - 2s/epoch - 50ms/step
# Epoch 15/200
# 34/34 - 2s - loss: 10474.0869 - mean_squared_error: 10474.0869 - val_loss: 10326.4258 - val_mean_squared_error: 10326.4258 - 2s/epoch - 49ms/step
# Epoch 16/200
# 34/34 - 2s - loss: 7386.2598 - mean_squared_error: 7386.2598 - val_loss: 24703.4648 - val_mean_squared_error: 24703.4648 - 2s/epoch - 49ms/step
# Epoch 17/200
# 34/34 - 2s - loss: 7413.3125 - mean_squared_error: 7413.3125 - val_loss: 10160.6924 - val_mean_squared_error: 10160.6924 - 2s/epoch - 49ms/step
# Epoch 18/200
# 34/34 - 2s - loss: 3798.8552 - mean_squared_error: 3798.8552 - val_loss: 4915.8882 - val_mean_squared_error: 4915.8882 - 2s/epoch - 49ms/step
# Epoch 19/200
# 34/34 - 2s - loss: 3342.3633 - mean_squared_error: 3342.3633 - val_loss: 4416.4824 - val_mean_squared_error: 4416.4824 - 2s/epoch - 49ms/step
# Epoch 20/200
# 34/34 - 2s - loss: 3839.1584 - mean_squared_error: 3839.1584 - val_loss: 4402.9473 - val_mean_squared_error: 4402.9473 - 2s/epoch - 51ms/step
# Epoch 21/200
# 34/34 - 2s - loss: 3183.8315 - mean_squared_error: 3183.8315 - val_loss: 4827.4468 - val_mean_squared_error: 4827.4468 - 2s/epoch - 52ms/step
# Epoch 22/200
# 34/34 - 2s - loss: 3332.4988 - mean_squared_error: 3332.4988 - val_loss: 4632.4077 - val_mean_squared_error: 4632.4077 - 2s/epoch - 51ms/step
# Epoch 23/200
# 34/34 - 2s - loss: 3232.5479 - mean_squared_error: 3232.5479 - val_loss: 4277.9648 - val_mean_squared_error: 4277.9648 - 2s/epoch - 49ms/step
# Epoch 24/200
# 34/34 - 2s - loss: 3256.4089 - mean_squared_error: 3256.4089 - val_loss: 6425.1611 - val_mean_squared_error: 6425.1611 - 2s/epoch - 50ms/step
# Epoch 25/200
# 34/34 - 2s - loss: 3222.5593 - mean_squared_error: 3222.5593 - val_loss: 6482.6118 - val_mean_squared_error: 6482.6118 - 2s/epoch - 50ms/step
# Epoch 26/200
# 34/34 - 2s - loss: 3912.8940 - mean_squared_error: 3912.8940 - val_loss: 4754.5566 - val_mean_squared_error: 4754.5566 - 2s/epoch - 50ms/step
# Epoch 27/200
# 34/34 - 2s - loss: 3276.8953 - mean_squared_error: 3276.8953 - val_loss: 4471.4463 - val_mean_squared_error: 4471.4463 - 2s/epoch - 50ms/step
# Epoch 28/200
# 34/34 - 2s - loss: 3801.4250 - mean_squared_error: 3801.4250 - val_loss: 4720.5205 - val_mean_squared_error: 4720.5205 - 2s/epoch - 48ms/step
# Epoch 29/200
# 34/34 - 2s - loss: 2674.1680 - mean_squared_error: 2674.1680 - val_loss: 4604.7817 - val_mean_squared_error: 4604.7817 - 2s/epoch - 50ms/step
# Epoch 30/200
# 34/34 - 2s - loss: 2961.1108 - mean_squared_error: 2961.1108 - val_loss: 4535.0000 - val_mean_squared_error: 4535.0000 - 2s/epoch - 50ms/step
# Epoch 31/200
# 34/34 - 2s - loss: 2869.7131 - mean_squared_error: 2869.7131 - val_loss: 4207.3506 - val_mean_squared_error: 4207.3506 - 2s/epoch - 50ms/step
# Epoch 32/200
# 34/34 - 2s - loss: 3003.2820 - mean_squared_error: 3003.2820 - val_loss: 4788.0605 - val_mean_squared_error: 4788.0605 - 2s/epoch - 49ms/step
# Epoch 33/200
# 34/34 - 2s - loss: 2858.9312 - mean_squared_error: 2858.9312 - val_loss: 4291.1978 - val_mean_squared_error: 4291.1978 - 2s/epoch - 50ms/step
# Epoch 34/200
# 34/34 - 2s - loss: 2899.9290 - mean_squared_error: 2899.9290 - val_loss: 4494.3892 - val_mean_squared_error: 4494.3892 - 2s/epoch - 48ms/step
# Epoch 35/200
# 34/34 - 2s - loss: 6837.8564 - mean_squared_error: 6837.8564 - val_loss: 11960.2705 - val_mean_squared_error: 11960.2705 - 2s/epoch - 48ms/step
# Epoch 36/200
# 34/34 - 2s - loss: 14857.7773 - mean_squared_error: 14857.7773 - val_loss: 7994.4971 - val_mean_squared_error: 7994.4971 - 2s/epoch - 48ms/step
# Epoch 37/200
# 34/34 - 2s - loss: 12694.6133 - mean_squared_error: 12694.6133 - val_loss: 37418.8672 - val_mean_squared_error: 37418.8672 - 2s/epoch - 48ms/step
# Epoch 38/200
# 34/34 - 2s - loss: 27285.1250 - mean_squared_error: 27285.1250 - val_loss: 28317.4512 - val_mean_squared_error: 28317.4512 - 2s/epoch - 48ms/step
# Epoch 39/200
# 34/34 - 2s - loss: 18716.7637 - mean_squared_error: 18716.7637 - val_loss: 16503.9688 - val_mean_squared_error: 16503.9688 - 2s/epoch - 48ms/step
# Epoch 40/200
# 34/34 - 2s - loss: 24440.5898 - mean_squared_error: 24440.5898 - val_loss: 21734.8828 - val_mean_squared_error: 21734.8828 - 2s/epoch - 48ms/step
# Epoch 41/200
# 34/34 - 2s - loss: 14079.9209 - mean_squared_error: 14079.9209 - val_loss: 14243.9805 - val_mean_squared_error: 14243.9805 - 2s/epoch - 49ms/step
# Epoch 42/200
# 34/34 - 2s - loss: 11853.0049 - mean_squared_error: 11853.0049 - val_loss: 16918.0664 - val_mean_squared_error: 16918.0664 - 2s/epoch - 48ms/step
# Epoch 43/200
# 34/34 - 2s - loss: 8937.0801 - mean_squared_error: 8937.0801 - val_loss: 6793.7676 - val_mean_squared_error: 6793.7676 - 2s/epoch - 48ms/step
# Epoch 44/200
# 34/34 - 2s - loss: 6261.7192 - mean_squared_error: 6261.7192 - val_loss: 11847.9521 - val_mean_squared_error: 11847.9521 - 2s/epoch - 48ms/step
# Epoch 45/200
# 34/34 - 2s - loss: 5616.7808 - mean_squared_error: 5616.7808 - val_loss: 5603.5293 - val_mean_squared_error: 5603.5293 - 2s/epoch - 48ms/step
# Epoch 46/200
# 34/34 - 2s - loss: 4785.7480 - mean_squared_error: 4785.7480 - val_loss: 8195.2559 - val_mean_squared_error: 8195.2559 - 2s/epoch - 48ms/step
# Epoch 47/200
# 34/34 - 2s - loss: 5286.4995 - mean_squared_error: 5286.4995 - val_loss: 6620.8535 - val_mean_squared_error: 6620.8535 - 2s/epoch - 49ms/step
# Epoch 48/200
# 34/34 - 2s - loss: 4260.6987 - mean_squared_error: 4260.6987 - val_loss: 4280.5571 - val_mean_squared_error: 4280.5571 - 2s/epoch - 48ms/step
# Epoch 49/200
# 34/34 - 2s - loss: 5647.7983 - mean_squared_error: 5647.7983 - val_loss: 5302.8013 - val_mean_squared_error: 5302.8013 - 2s/epoch - 48ms/step
# Epoch 49: early stopping

# %%
#data = timeProcess()[1]
#modelo.save('/content/drive/MyDrive/1_Informações_scripts//model__3T3_regressao_menor_erro_Mean_squared_error_200_epochs_'+data+'.h5')

# %% [markdown]
# ## Accuracy Assessment

# %%
#gráfico avaliando a acurácia a partir de treino e teste
plt.plot(history.history['mean_squared_error'])
plt.plot(history.history['val_mean_squared_error'])
plt.title('Accuracy Metric')
plt.ylabel('MSE')
plt.xlabel('Epochs')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
#avaliando a previsão do modelo com os rótulos
prev = modelo.predict(X_test)
plt.title('Previsão dos valores Operetta')
plt.ylabel('Rótulos')
plt.xlabel('Previsão')
plt.plot(prev)#azul - o que o modelo previu
plt.plot(y_test)#laranja - o que se sabe - observado
plt.show()
# Out:
# 15/15 [==============================] - 0s 18ms/step

# %%
# Qualit model analisys
from sklearn.metrics import r2_score,mean_absolute_error, mean_squared_error, mean_squared_log_error, median_absolute_error

# %%
#buscando pelas métricas
print(f"{round(r2_score(y_test, prev) * 100, 2)}% r2_score") #raíz quadrada
print(f"{round(mean_absolute_error(y_test, prev), 2)} Erro médio absoluto") 
print(f"{round(mean_squared_error(y_test, prev), 2)} Erro médio quadrático") #erro médio quadrático
# print(f"{round(median_absolute_error(y_test, prev), 2)}")#Erro médio absoluto sem %
#print(f"{round(median(y_test, prev), 2)} mediana") #erro médio quadrático
# Out:
# 84.39% r2_score
# 50.52 Erro médio absoluto
# 5302.8 Erro médio quadrático

# %%
# #salvando o modelo
data = timeProcess()[1]
modelo.save('/content/drive/MyDrive/Regressão_imagens_DOC_CNN/results_THP1/modelo_THP1_100_75_50_25_'+data+'.h5')
