# %% [markdown]
# # A549

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
pip install util-gfsilveira
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting util-gfsilveira
#   Downloading util_gfsilveira-0.1-py3-none-any.whl (3.1 kB)
# Installing collected packages: util-gfsilveira
# Successfully installed util-gfsilveira-0.1

# %% [markdown]
# # Imports data structuring

# %%
#organização dos arquivos
import os
#salvar/carregar arquivos em diferentes formatos
import joblib
#organizando os arquivos de forma aleatória
import random
#gerar gráfico
import matplotlib
#estruturação dos dados
import numpy as np
#gerar gráfico
import seaborn as sns
#gerar gráfico
import matplotlib.pyplot as plt
#gerar imagem
import matplotlib.image as mpimg

# %% [markdown]
# # CNN template import

# %%
#modelo de revisão redes neurais - cnn
from keras.models import Sequential
from keras.utils.np_utils import to_categorical
#from keras.utils import to_categorical
from util import meus_uteis, timeProcess, mask_corr_graphic, printLis
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report
from keras.layers import Dense, Conv2D, MaxPooling2D, Dropout, Flatten

# %% [markdown]
# Documents from different files will be stored in this directory

# %%
diretorio = '/content/drive/MyDrive/Regressão_imagens_DOC_CNN/results_A549' #alimentando a variável com os arquivos da pasta datasets
lista_dados = os.listdir(diretorio) #listando os arquivos dessa pasta
printLis(lista_dados) #printando as diferentes listas
# Out:
# -------------
# -=< Lista >=-
# -------------
# 0 -> 1_lista_img_camp_clar_100_resized_regressao_A5492021-11-9.gz
# 1 -> 2_lista_img_camp_clar_75_resized_regressao_A5492021-11-9.gz
# 2 -> 3_lista_img_camp_clar_50_resized_regressao_A5492021-11-9.gz
# 3 -> 4_lista_img_camp_clar_25_resized_regressao_A5492021-11-9.gz
# 4 -> 5_lista_rotulo_camp_clar_100_resized_regressao_A5492021-11-9.gz
# 5 -> 6_lista_rotulo_camp_clar_75_resized_regressao_A5492021-11-9.gz
# 6 -> 7_lista_rotulo_camp_clar_50_resized_regressao_A5492021-11-9.gz
# 7 -> 8_lista_rotulo_camp_clar_25_resized_regressao_A5492021-11-9.gz
# 8 -> Análises antigas 2021 22

# %% [markdown]
# Lists of all images in each file

# %%
#lstando arquivos com as imagens 100%, 75%, 50%, 25%
for k, v in enumerate(lista_dados):
    if k in [0,1,2,3]:
        print(f'{k} -> {v}')
# Out:
# 0 -> 1_lista_img_camp_clar_100_resized_regressao_A5492021-11-9.gz
# 1 -> 2_lista_img_camp_clar_75_resized_regressao_A5492021-11-9.gz
# 2 -> 3_lista_img_camp_clar_50_resized_regressao_A5492021-11-9.gz
# 3 -> 4_lista_img_camp_clar_25_resized_regressao_A5492021-11-9.gz

# %% [markdown]
# ## x = features/images

# %%
#somando todas as imagens de diferentes tamanho
X_cem = joblib.load(diretorio+ '/' + lista_dados[0])

# 12 -> 00-lista_img_dapi_crop_75_resized_2021-5-12.gz
X_setcin = joblib.load(diretorio+ '/' + lista_dados[1])

# 10 -> 00-lista_img_dapi_crop_50_resized_2021-5-12.gz
X_cinq = joblib.load(diretorio+ '/' + lista_dados[2])

# 8 -> 00-lista_img_dapi_crop_25_resized_2021-5-12.gz
X_vincin = joblib.load(diretorio+ '/' + lista_dados[3])

x = np.asarray(list(X_cem) + list(X_setcin) + list(X_cinq) + list(X_vincin))

x.shape
# Out:
# (1136, 200, 200, 3)

# %% [markdown]
# ## y = labels

# %% [markdown]
# Opening the labels that were saved in the preparation of the images

# %%
for k, v in enumerate(lista_dados):
    if k in [4,5,6,7]:
        print(f'{k} -> {v}')
# Out:
# 4 -> 5_lista_rotulo_camp_clar_100_resized_regressao_A5492021-11-9.gz
# 5 -> 6_lista_rotulo_camp_clar_75_resized_regressao_A5492021-11-9.gz
# 6 -> 7_lista_rotulo_camp_clar_50_resized_regressao_A5492021-11-9.gz
# 7 -> 8_lista_rotulo_camp_clar_25_resized_regressao_A5492021-11-9.gz

# %%
#somando todos os rótulos de diferentes tamanho
y_cem = joblib.load(diretorio+ '/' + lista_dados[4])

# 12 -> 00-lista_img_dapi_crop_75_resized_2021-5-12.gz
y_setcin = joblib.load(diretorio+ '/' + lista_dados[5])

# 10 -> 00-lista_img_dapi_crop_50_resized_2021-5-12.gz
y_cinq = joblib.load(diretorio+ '/' + lista_dados[6])

# 8 -> 00-lista_img_dapi_crop_25_resized_2021-5-12.gz
y_vincin = joblib.load(diretorio+ '/' + lista_dados[7])

y = np.asarray(list(y_cem) + list(y_setcin) + list(y_cinq) + list(y_vincin))

y.shape
# Out:
# (1136,)

# %%
#Train and test split datasets for CNN model
#função que separa as imagens em teste e treino
from sklearn.model_selection import train_test_split

# %% [markdown]
# #Separando dados de validação

# %%
imagens_teste = x.shape[0] * 0.9 #pegando só das imagens 30% das imagens vai para o teste
imagens_treino = x.shape[0] - imagens_teste #restante das imagens (70%)
print('Data for Modeling: ' + str(imagens_teste))
print('Unseen Data For Predictions: ' + str(imagens_treino))
# Out:
# Data for Modeling: 1022.4
# Unseen Data For Predictions: 113.60000000000002

# %%
zeros = list(np.zeros(1023))
ones = list(np.ones(113))
lista = np.array(zeros + ones)
lista
# Out:
# array([0., 0., 0., ..., 1., 1., 1.])

# %%
random.shuffle(lista)
lista_valida = [True if i == 1 else False for i in lista]
lista_treino_test = [False if i == 1 else True for i in lista]
np.array(lista_valida)
# Out:
# array([False, False, False, ..., False, False,  True])

# %%
#imagens
x_valida = x[lista_valida]
x_treino_test = x[lista_treino_test]

print(x_valida.shape)
print(x_treino_test.shape)
# Out:
# (113, 200, 200, 3)
# (1023, 200, 200, 3)

# %%
#rótulos
y_valida = y[lista_valida]
y_treino_test = y[lista_treino_test]

print(y_valida.shape)
print(y_treino_test.shape)
# Out:
# (113,)
# (1023,)

# %%
#imagens_teste = x.shape[0] * 0.9 #pegando só das imagens 30% das imagens vai para o teste
#imagens_treino = x.shape[0] - imagens_teste #restante das imagens (70%)
#print('Data for Modeling: ' + str(imagens_teste))
#print('Unseen Data For Predictions: ' + str(imagens_treino))
# Out:
# Data for Modeling: 1368.0
# Unseen Data For Predictions: 152.0

# %% [markdown]
# Dados restantes 90%

# %%
data = timeProcess()[1]

# %%
#Salvando 10$ das imagens para validação
joblib.dump(x_valida, '/content/drive/MyDrive/Regressão_imagens_DOC_CNN/results_A549/imagens_validação_10%_A549_'+data+'.gz')
joblib.dump(y_valida, '/content/drive/MyDrive/Regressão_imagens_DOC_CNN/results_A549/rótulos_validação_10%_A549_'+data+'.gz')
# Out:
# ['/content/drive/MyDrive/Regressão_imagens_DOC_CNN/results_A549/rótulos_validação_10%_A549_2022-12-16.gz']

# %% [markdown]
# Test and training separation from a library.

# %%
X_train, X_test, y_train, y_test = train_test_split(x_treino_test, y_treino_test, test_size=0.3, random_state=0)
#variáveis recebem o número de imagens para tes e treino
print(f'{X_train.shape} \n{X_test.shape} \n{y_train.shape} \n{y_test.shape}')
# Out:
# (716, 200, 200, 3)
# (307, 200, 200, 3)
# (716,)
# (307,)

# %%
#salvando os resultados de treino e teste
joblib.dump(X_train, '/content/drive/MyDrive/Regressão_imagens_DOC_CNN/results_A549/1_images_de_X_train_A549_melhor_modelo_200_epochs_90%_'+data+'.gz')
joblib.dump(y_train, '/content/drive/MyDrive/Regressão_imagens_DOC_CNN/results_A549/2_rotulos_de_y_train_A549_melhor_modelo_200_epochs_90%_'+data+'.gz')
joblib.dump(X_test, '/content/drive/MyDrive/Regressão_imagens_DOC_CNN/results_A549/3_images_de_X_test_A549_melhor_modelo_200_epochs_90%_'+data+'.gz')
joblib.dump(y_test, '/content/drive/MyDrive/Regressão_imagens_DOC_CNN/results_A549/4_rotulos_de_y_test_A549_melhor_model_200_epochs_90%_'+data+'.gz')
# Out:
# ['/content/drive/MyDrive/Regressão_imagens_DOC_CNN/results_A549/4_rotulos_de_y_test_A549_melhor_model_200_epochs_90%_2022-12-16.gz']

# %% [markdown]
# ### Model determination

# %%
modelo = Sequential()
modelo.add(Conv2D(32, kernel_size=3, activation='relu', input_shape=X_train[0].shape))
#função de ativação relu é muito utilizado para problemas de regressão
modelo.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2), padding='valid'))
modelo.add(Conv2D(64, kernel_size=3, activation='relu'))
modelo.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2), padding='valid'))
modelo.add(Conv2D(128, kernel_size=3, activation='relu'))
modelo.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2), padding='valid'))
modelo.add(Conv2D(256, kernel_size=3, activation='relu'))
modelo.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2), padding='valid'))
modelo.add(Flatten())
modelo.add(Dropout(0.9))
modelo.add(Dense(1, activation='linear'))
#apenas uma saída e de forma linear
modelo.compile(optimizer='adam', loss='mse', metrics=['mean_squared_error'])
print(modelo.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 198, 198, 32)      896
#
#  max_pooling2d (MaxPooling2D  (None, 99, 99, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 97, 97, 64)        18496
#
#  max_pooling2d_1 (MaxPooling  (None, 48, 48, 64)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 46, 46, 128)       73856
#
#  max_pooling2d_2 (MaxPooling  (None, 23, 23, 128)      0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 21, 21, 256)       295168
#
#  max_pooling2d_3 (MaxPooling  (None, 10, 10, 256)      0
#  2D)
#
#  flatten (Flatten)           (None, 25600)             0
#
#  dropout (Dropout)           (None, 25600)             0
#
#  dense (Dense)               (None, 1)                 25601
#
# =================================================================
# Total params: 414,017
# Trainable params: 414,017
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# # Training and testing epochs

# %%
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.callbacks import ModelCheckpoint

# %%
# simple early stopping
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=18)

# %%
# fit model
history = modelo.fit(X_train,y_train,
                    validation_data=(X_test, y_test), 
                    epochs=200, verbose=2, 
                    callbacks=[es]
                     )
# Out:
# Epoch 1/200
# 23/23 - 10s - loss: 190723.7812 - mean_squared_error: 190723.7812 - val_loss: 104576.7891 - val_mean_squared_error: 104576.7891 - 10s/epoch - 455ms/step
# Epoch 2/200
# 23/23 - 1s - loss: 115974.6016 - mean_squared_error: 115974.6016 - val_loss: 82354.3047 - val_mean_squared_error: 82354.3047 - 1s/epoch - 48ms/step
# Epoch 3/200
# 23/23 - 1s - loss: 110551.8516 - mean_squared_error: 110551.8516 - val_loss: 75719.3906 - val_mean_squared_error: 75719.3906 - 1s/epoch - 48ms/step
# Epoch 4/200
# 23/23 - 1s - loss: 81650.1484 - mean_squared_error: 81650.1484 - val_loss: 55183.9531 - val_mean_squared_error: 55183.9531 - 1s/epoch - 48ms/step
# Epoch 5/200
# 23/23 - 1s - loss: 63615.6328 - mean_squared_error: 63615.6328 - val_loss: 42110.4766 - val_mean_squared_error: 42110.4766 - 1s/epoch - 48ms/step
# Epoch 6/200
# 23/23 - 1s - loss: 56098.6406 - mean_squared_error: 56098.6406 - val_loss: 43877.0508 - val_mean_squared_error: 43877.0508 - 1s/epoch - 48ms/step
# Epoch 7/200
# 23/23 - 1s - loss: 46937.9609 - mean_squared_error: 46937.9609 - val_loss: 336221.2500 - val_mean_squared_error: 336221.2500 - 1s/epoch - 48ms/step
# Epoch 8/200
# 23/23 - 1s - loss: 90725.3359 - mean_squared_error: 90725.3359 - val_loss: 52349.2891 - val_mean_squared_error: 52349.2891 - 1s/epoch - 48ms/step
# Epoch 9/200
# 23/23 - 1s - loss: 62427.5586 - mean_squared_error: 62427.5586 - val_loss: 39420.6250 - val_mean_squared_error: 39420.6250 - 1s/epoch - 48ms/step
# Epoch 10/200
# 23/23 - 1s - loss: 45987.6211 - mean_squared_error: 45987.6211 - val_loss: 37882.7344 - val_mean_squared_error: 37882.7344 - 1s/epoch - 48ms/step
# Epoch 11/200
# 23/23 - 1s - loss: 40272.7891 - mean_squared_error: 40272.7891 - val_loss: 31654.3809 - val_mean_squared_error: 31654.3809 - 1s/epoch - 48ms/step
# Epoch 12/200
# 23/23 - 1s - loss: 38019.1797 - mean_squared_error: 38019.1797 - val_loss: 25383.3867 - val_mean_squared_error: 25383.3867 - 1s/epoch - 48ms/step
# Epoch 13/200
# 23/23 - 1s - loss: 38738.7383 - mean_squared_error: 38738.7383 - val_loss: 29501.8379 - val_mean_squared_error: 29501.8379 - 1s/epoch - 48ms/step
# Epoch 14/200
# 23/23 - 1s - loss: 40652.9062 - mean_squared_error: 40652.9062 - val_loss: 25249.2402 - val_mean_squared_error: 25249.2402 - 1s/epoch - 48ms/step
# Epoch 15/200
# 23/23 - 1s - loss: 50430.0508 - mean_squared_error: 50430.0508 - val_loss: 37675.1875 - val_mean_squared_error: 37675.1875 - 1s/epoch - 48ms/step
# Epoch 16/200
# 23/23 - 1s - loss: 36938.1602 - mean_squared_error: 36938.1602 - val_loss: 44766.9336 - val_mean_squared_error: 44766.9336 - 1s/epoch - 48ms/step
# Epoch 17/200
# 23/23 - 1s - loss: 28633.1426 - mean_squared_error: 28633.1426 - val_loss: 28572.0156 - val_mean_squared_error: 28572.0156 - 1s/epoch - 48ms/step
# Epoch 18/200
# 23/23 - 1s - loss: 37318.8203 - mean_squared_error: 37318.8203 - val_loss: 24987.8926 - val_mean_squared_error: 24987.8926 - 1s/epoch - 54ms/step
# Epoch 19/200
# 23/23 - 1s - loss: 36912.0195 - mean_squared_error: 36912.0195 - val_loss: 27744.8086 - val_mean_squared_error: 27744.8086 - 1s/epoch - 48ms/step
# Epoch 20/200
# 23/23 - 1s - loss: 34220.6055 - mean_squared_error: 34220.6055 - val_loss: 26747.9980 - val_mean_squared_error: 26747.9980 - 1s/epoch - 54ms/step
# Epoch 21/200
# 23/23 - 1s - loss: 35585.5352 - mean_squared_error: 35585.5352 - val_loss: 47800.7773 - val_mean_squared_error: 47800.7773 - 1s/epoch - 48ms/step
# Epoch 22/200
# 23/23 - 1s - loss: 29863.4941 - mean_squared_error: 29863.4941 - val_loss: 32652.7266 - val_mean_squared_error: 32652.7266 - 1s/epoch - 48ms/step
# Epoch 23/200
# 23/23 - 1s - loss: 27458.9355 - mean_squared_error: 27458.9355 - val_loss: 29581.9941 - val_mean_squared_error: 29581.9941 - 1s/epoch - 54ms/step
# Epoch 24/200
# 23/23 - 1s - loss: 36951.4375 - mean_squared_error: 36951.4375 - val_loss: 25132.6328 - val_mean_squared_error: 25132.6328 - 1s/epoch - 54ms/step
# Epoch 25/200
# 23/23 - 1s - loss: 31537.2383 - mean_squared_error: 31537.2383 - val_loss: 26860.2793 - val_mean_squared_error: 26860.2793 - 1s/epoch - 48ms/step
# Epoch 26/200
# 23/23 - 1s - loss: 23954.5273 - mean_squared_error: 23954.5273 - val_loss: 24171.5527 - val_mean_squared_error: 24171.5527 - 1s/epoch - 48ms/step
# Epoch 27/200
# 23/23 - 1s - loss: 24891.3496 - mean_squared_error: 24891.3496 - val_loss: 20370.7461 - val_mean_squared_error: 20370.7461 - 1s/epoch - 48ms/step
# Epoch 28/200
# 23/23 - 1s - loss: 24445.8105 - mean_squared_error: 24445.8105 - val_loss: 20112.6016 - val_mean_squared_error: 20112.6016 - 1s/epoch - 54ms/step
# Epoch 29/200
# 23/23 - 1s - loss: 24631.4922 - mean_squared_error: 24631.4922 - val_loss: 55181.9883 - val_mean_squared_error: 55181.9883 - 1s/epoch - 53ms/step
# Epoch 30/200
# 23/23 - 1s - loss: 38472.5742 - mean_squared_error: 38472.5742 - val_loss: 22048.2793 - val_mean_squared_error: 22048.2793 - 1s/epoch - 57ms/step
# Epoch 31/200
# 23/23 - 1s - loss: 26341.2656 - mean_squared_error: 26341.2656 - val_loss: 20149.1699 - val_mean_squared_error: 20149.1699 - 1s/epoch - 51ms/step
# Epoch 32/200
# 23/23 - 1s - loss: 22283.6484 - mean_squared_error: 22283.6484 - val_loss: 18647.8867 - val_mean_squared_error: 18647.8867 - 1s/epoch - 54ms/step
# Epoch 33/200
# 23/23 - 1s - loss: 19783.5332 - mean_squared_error: 19783.5332 - val_loss: 20429.6992 - val_mean_squared_error: 20429.6992 - 1s/epoch - 54ms/step
# Epoch 34/200
# 23/23 - 1s - loss: 26244.2344 - mean_squared_error: 26244.2344 - val_loss: 23432.3926 - val_mean_squared_error: 23432.3926 - 1s/epoch - 48ms/step
# Epoch 35/200
# 23/23 - 1s - loss: 26715.9824 - mean_squared_error: 26715.9824 - val_loss: 70013.7109 - val_mean_squared_error: 70013.7109 - 1s/epoch - 54ms/step
# Epoch 36/200
# 23/23 - 1s - loss: 27513.7285 - mean_squared_error: 27513.7285 - val_loss: 20403.0020 - val_mean_squared_error: 20403.0020 - 1s/epoch - 54ms/step
# Epoch 37/200
# 23/23 - 1s - loss: 24344.4102 - mean_squared_error: 24344.4102 - val_loss: 24774.8203 - val_mean_squared_error: 24774.8203 - 1s/epoch - 48ms/step
# Epoch 38/200
# 23/23 - 1s - loss: 19309.2344 - mean_squared_error: 19309.2344 - val_loss: 29332.8477 - val_mean_squared_error: 29332.8477 - 1s/epoch - 48ms/step
# Epoch 39/200
# 23/23 - 1s - loss: 24731.9727 - mean_squared_error: 24731.9727 - val_loss: 35339.4375 - val_mean_squared_error: 35339.4375 - 1s/epoch - 48ms/step
# Epoch 40/200
# 23/23 - 1s - loss: 21190.8535 - mean_squared_error: 21190.8535 - val_loss: 18151.1133 - val_mean_squared_error: 18151.1133 - 1s/epoch - 48ms/step
# Epoch 41/200
# 23/23 - 1s - loss: 25938.6699 - mean_squared_error: 25938.6699 - val_loss: 19752.5938 - val_mean_squared_error: 19752.5938 - 1s/epoch - 54ms/step
# Epoch 42/200
# 23/23 - 1s - loss: 22428.4785 - mean_squared_error: 22428.4785 - val_loss: 51629.3984 - val_mean_squared_error: 51629.3984 - 1s/epoch - 48ms/step
# Epoch 43/200
# 23/23 - 1s - loss: 35150.6016 - mean_squared_error: 35150.6016 - val_loss: 28445.2480 - val_mean_squared_error: 28445.2480 - 1s/epoch - 48ms/step
# Epoch 44/200
# 23/23 - 1s - loss: 23745.0918 - mean_squared_error: 23745.0918 - val_loss: 18409.0430 - val_mean_squared_error: 18409.0430 - 1s/epoch - 54ms/step
# Epoch 45/200
# 23/23 - 1s - loss: 26239.3574 - mean_squared_error: 26239.3574 - val_loss: 16983.5938 - val_mean_squared_error: 16983.5938 - 1s/epoch - 48ms/step
# Epoch 46/200
# 23/23 - 1s - loss: 18935.6992 - mean_squared_error: 18935.6992 - val_loss: 17629.8164 - val_mean_squared_error: 17629.8164 - 1s/epoch - 54ms/step
# Epoch 47/200
# 23/23 - 1s - loss: 24996.3184 - mean_squared_error: 24996.3184 - val_loss: 32046.5898 - val_mean_squared_error: 32046.5898 - 1s/epoch - 54ms/step
# Epoch 48/200
# 23/23 - 1s - loss: 22396.7480 - mean_squared_error: 22396.7480 - val_loss: 30284.3613 - val_mean_squared_error: 30284.3613 - 1s/epoch - 48ms/step
# Epoch 49/200
# 23/23 - 1s - loss: 30978.5586 - mean_squared_error: 30978.5586 - val_loss: 19434.9844 - val_mean_squared_error: 19434.9844 - 1s/epoch - 48ms/step
# Epoch 50/200
# 23/23 - 1s - loss: 26466.0332 - mean_squared_error: 26466.0332 - val_loss: 20071.3086 - val_mean_squared_error: 20071.3086 - 1s/epoch - 54ms/step
# Epoch 51/200
# 23/23 - 1s - loss: 18907.8496 - mean_squared_error: 18907.8496 - val_loss: 20830.3496 - val_mean_squared_error: 20830.3496 - 1s/epoch - 48ms/step
# Epoch 52/200
# 23/23 - 1s - loss: 18682.6465 - mean_squared_error: 18682.6465 - val_loss: 17236.1328 - val_mean_squared_error: 17236.1328 - 1s/epoch - 48ms/step
# Epoch 53/200
# 23/23 - 1s - loss: 16092.4180 - mean_squared_error: 16092.4180 - val_loss: 13896.2080 - val_mean_squared_error: 13896.2080 - 1s/epoch - 54ms/step
# Epoch 54/200
# 23/23 - 1s - loss: 15635.8809 - mean_squared_error: 15635.8809 - val_loss: 20665.8105 - val_mean_squared_error: 20665.8105 - 1s/epoch - 54ms/step
# Epoch 55/200
# 23/23 - 1s - loss: 18098.1719 - mean_squared_error: 18098.1719 - val_loss: 16289.0811 - val_mean_squared_error: 16289.0811 - 1s/epoch - 48ms/step
# Epoch 56/200
# 23/23 - 1s - loss: 15898.3994 - mean_squared_error: 15898.3994 - val_loss: 14553.5654 - val_mean_squared_error: 14553.5654 - 1s/epoch - 54ms/step
# Epoch 57/200
# 23/23 - 1s - loss: 19224.5176 - mean_squared_error: 19224.5176 - val_loss: 44060.4258 - val_mean_squared_error: 44060.4258 - 1s/epoch - 54ms/step
# Epoch 58/200
# 23/23 - 1s - loss: 20035.1309 - mean_squared_error: 20035.1309 - val_loss: 29739.2598 - val_mean_squared_error: 29739.2598 - 1s/epoch - 54ms/step
# Epoch 59/200
# 23/23 - 1s - loss: 18780.6836 - mean_squared_error: 18780.6836 - val_loss: 14315.9629 - val_mean_squared_error: 14315.9629 - 1s/epoch - 48ms/step
# Epoch 60/200
# 23/23 - 1s - loss: 18328.3398 - mean_squared_error: 18328.3398 - val_loss: 14816.8828 - val_mean_squared_error: 14816.8828 - 1s/epoch - 48ms/step
# Epoch 61/200
# 23/23 - 1s - loss: 14145.4648 - mean_squared_error: 14145.4648 - val_loss: 19659.4512 - val_mean_squared_error: 19659.4512 - 1s/epoch - 54ms/step
# Epoch 62/200
# 23/23 - 1s - loss: 18354.8379 - mean_squared_error: 18354.8379 - val_loss: 12403.3750 - val_mean_squared_error: 12403.3750 - 1s/epoch - 48ms/step
# Epoch 63/200
# 23/23 - 1s - loss: 17620.5020 - mean_squared_error: 17620.5020 - val_loss: 17239.4844 - val_mean_squared_error: 17239.4844 - 1s/epoch - 54ms/step
# Epoch 64/200
# 23/23 - 1s - loss: 18262.1504 - mean_squared_error: 18262.1504 - val_loss: 36964.2109 - val_mean_squared_error: 36964.2109 - 1s/epoch - 48ms/step
# Epoch 65/200
# 23/23 - 1s - loss: 13366.1338 - mean_squared_error: 13366.1338 - val_loss: 15872.6689 - val_mean_squared_error: 15872.6689 - 1s/epoch - 48ms/step
# Epoch 66/200
# 23/23 - 1s - loss: 15990.6826 - mean_squared_error: 15990.6826 - val_loss: 18022.9258 - val_mean_squared_error: 18022.9258 - 1s/epoch - 48ms/step
# Epoch 67/200
# 23/23 - 1s - loss: 17504.4043 - mean_squared_error: 17504.4043 - val_loss: 22541.3438 - val_mean_squared_error: 22541.3438 - 1s/epoch - 54ms/step
# Epoch 68/200
# 23/23 - 1s - loss: 14732.1748 - mean_squared_error: 14732.1748 - val_loss: 14101.0537 - val_mean_squared_error: 14101.0537 - 1s/epoch - 48ms/step
# Epoch 69/200
# 23/23 - 1s - loss: 12061.6553 - mean_squared_error: 12061.6553 - val_loss: 12333.5029 - val_mean_squared_error: 12333.5029 - 1s/epoch - 48ms/step
# Epoch 70/200
# 23/23 - 1s - loss: 10539.7412 - mean_squared_error: 10539.7412 - val_loss: 13377.7510 - val_mean_squared_error: 13377.7510 - 1s/epoch - 48ms/step
# Epoch 71/200
# 23/23 - 1s - loss: 11753.7305 - mean_squared_error: 11753.7305 - val_loss: 14386.5420 - val_mean_squared_error: 14386.5420 - 1s/epoch - 54ms/step
# Epoch 72/200
# 23/23 - 1s - loss: 10989.8936 - mean_squared_error: 10989.8936 - val_loss: 17657.7715 - val_mean_squared_error: 17657.7715 - 1s/epoch - 48ms/step
# Epoch 73/200
# 23/23 - 1s - loss: 12966.0137 - mean_squared_error: 12966.0137 - val_loss: 18735.0723 - val_mean_squared_error: 18735.0723 - 1s/epoch - 48ms/step
# Epoch 74/200
# 23/23 - 1s - loss: 19035.6309 - mean_squared_error: 19035.6309 - val_loss: 14960.9580 - val_mean_squared_error: 14960.9580 - 1s/epoch - 48ms/step
# Epoch 75/200
# 23/23 - 1s - loss: 21835.9629 - mean_squared_error: 21835.9629 - val_loss: 65931.6016 - val_mean_squared_error: 65931.6016 - 1s/epoch - 48ms/step
# Epoch 76/200
# 23/23 - 1s - loss: 26424.9297 - mean_squared_error: 26424.9297 - val_loss: 57806.2227 - val_mean_squared_error: 57806.2227 - 1s/epoch - 48ms/step
# Epoch 77/200
# 23/23 - 1s - loss: 18082.3301 - mean_squared_error: 18082.3301 - val_loss: 15315.8486 - val_mean_squared_error: 15315.8486 - 1s/epoch - 54ms/step
# Epoch 78/200
# 23/23 - 1s - loss: 13149.2783 - mean_squared_error: 13149.2783 - val_loss: 21431.2598 - val_mean_squared_error: 21431.2598 - 1s/epoch - 48ms/step
# Epoch 79/200
# 23/23 - 1s - loss: 11211.0850 - mean_squared_error: 11211.0850 - val_loss: 16640.2383 - val_mean_squared_error: 16640.2383 - 1s/epoch - 48ms/step
# Epoch 80/200
# 23/23 - 1s - loss: 10999.3535 - mean_squared_error: 10999.3535 - val_loss: 11207.6484 - val_mean_squared_error: 11207.6484 - 1s/epoch - 48ms/step
# Epoch 81/200
# 23/23 - 1s - loss: 11791.5898 - mean_squared_error: 11791.5898 - val_loss: 9770.9873 - val_mean_squared_error: 9770.9873 - 1s/epoch - 54ms/step
# Epoch 82/200
# 23/23 - 1s - loss: 17674.3906 - mean_squared_error: 17674.3906 - val_loss: 10251.2354 - val_mean_squared_error: 10251.2354 - 1s/epoch - 48ms/step
# Epoch 83/200
# 23/23 - 1s - loss: 13186.7852 - mean_squared_error: 13186.7852 - val_loss: 9005.6885 - val_mean_squared_error: 9005.6885 - 1s/epoch - 48ms/step
# Epoch 84/200
# 23/23 - 1s - loss: 9948.0137 - mean_squared_error: 9948.0137 - val_loss: 18384.0430 - val_mean_squared_error: 18384.0430 - 1s/epoch - 48ms/step
# Epoch 85/200
# 23/23 - 1s - loss: 15768.8838 - mean_squared_error: 15768.8838 - val_loss: 9973.3799 - val_mean_squared_error: 9973.3799 - 1s/epoch - 54ms/step
# Epoch 86/200
# 23/23 - 1s - loss: 11307.6143 - mean_squared_error: 11307.6143 - val_loss: 15639.4756 - val_mean_squared_error: 15639.4756 - 1s/epoch - 48ms/step
# Epoch 87/200
# 23/23 - 1s - loss: 9121.4053 - mean_squared_error: 9121.4053 - val_loss: 9285.0869 - val_mean_squared_error: 9285.0869 - 1s/epoch - 48ms/step
# Epoch 88/200
# 23/23 - 1s - loss: 12286.5098 - mean_squared_error: 12286.5098 - val_loss: 13466.1279 - val_mean_squared_error: 13466.1279 - 1s/epoch - 54ms/step
# Epoch 89/200
# 23/23 - 1s - loss: 10894.0947 - mean_squared_error: 10894.0947 - val_loss: 10933.2793 - val_mean_squared_error: 10933.2793 - 1s/epoch - 54ms/step
# Epoch 90/200
# 23/23 - 1s - loss: 8532.4502 - mean_squared_error: 8532.4492 - val_loss: 10249.5010 - val_mean_squared_error: 10249.5010 - 1s/epoch - 48ms/step
# Epoch 91/200
# 23/23 - 1s - loss: 8907.0361 - mean_squared_error: 8907.0361 - val_loss: 8869.1592 - val_mean_squared_error: 8869.1592 - 1s/epoch - 54ms/step
# Epoch 92/200
# 23/23 - 1s - loss: 6984.3608 - mean_squared_error: 6984.3608 - val_loss: 10046.2393 - val_mean_squared_error: 10046.2393 - 1s/epoch - 48ms/step
# Epoch 93/200
# 23/23 - 1s - loss: 8351.7881 - mean_squared_error: 8351.7881 - val_loss: 12149.0547 - val_mean_squared_error: 12149.0547 - 1s/epoch - 48ms/step
# Epoch 94/200
# 23/23 - 1s - loss: 9745.4434 - mean_squared_error: 9745.4434 - val_loss: 12934.3564 - val_mean_squared_error: 12934.3564 - 1s/epoch - 48ms/step
# Epoch 95/200
# 23/23 - 1s - loss: 9114.2490 - mean_squared_error: 9114.2490 - val_loss: 8060.1606 - val_mean_squared_error: 8060.1606 - 1s/epoch - 54ms/step
# Epoch 96/200
# 23/23 - 1s - loss: 7447.9058 - mean_squared_error: 7447.9058 - val_loss: 8573.7607 - val_mean_squared_error: 8573.7607 - 1s/epoch - 54ms/step
# Epoch 97/200
# 23/23 - 1s - loss: 9113.4600 - mean_squared_error: 9113.4600 - val_loss: 11880.5703 - val_mean_squared_error: 11880.5703 - 1s/epoch - 48ms/step
# Epoch 98/200
# 23/23 - 1s - loss: 9101.5332 - mean_squared_error: 9101.5332 - val_loss: 7334.4536 - val_mean_squared_error: 7334.4536 - 1s/epoch - 48ms/step
# Epoch 99/200
# 23/23 - 1s - loss: 6858.8008 - mean_squared_error: 6858.8008 - val_loss: 8379.0078 - val_mean_squared_error: 8379.0078 - 1s/epoch - 54ms/step
# Epoch 100/200
# 23/23 - 1s - loss: 8578.0879 - mean_squared_error: 8578.0879 - val_loss: 11203.4893 - val_mean_squared_error: 11203.4893 - 1s/epoch - 54ms/step
# Epoch 101/200
# 23/23 - 1s - loss: 6975.7954 - mean_squared_error: 6975.7954 - val_loss: 9926.0859 - val_mean_squared_error: 9926.0859 - 1s/epoch - 54ms/step
# Epoch 102/200
# 23/23 - 1s - loss: 10655.5635 - mean_squared_error: 10655.5635 - val_loss: 20607.6992 - val_mean_squared_error: 20607.6992 - 1s/epoch - 48ms/step
# Epoch 103/200
# 23/23 - 1s - loss: 10282.0312 - mean_squared_error: 10282.0312 - val_loss: 7841.8281 - val_mean_squared_error: 7841.8281 - 1s/epoch - 54ms/step
# Epoch 104/200
# 23/23 - 1s - loss: 7947.7739 - mean_squared_error: 7947.7739 - val_loss: 8104.6084 - val_mean_squared_error: 8104.6084 - 1s/epoch - 54ms/step
# Epoch 105/200
# 23/23 - 1s - loss: 10499.5176 - mean_squared_error: 10499.5176 - val_loss: 7090.5278 - val_mean_squared_error: 7090.5278 - 1s/epoch - 54ms/step
# Epoch 106/200
# 23/23 - 1s - loss: 6829.0288 - mean_squared_error: 6829.0288 - val_loss: 19118.4688 - val_mean_squared_error: 19118.4688 - 1s/epoch - 48ms/step
# Epoch 107/200
# 23/23 - 1s - loss: 8902.5156 - mean_squared_error: 8902.5156 - val_loss: 12948.7217 - val_mean_squared_error: 12948.7217 - 1s/epoch - 54ms/step
# Epoch 108/200
# 23/23 - 1s - loss: 11021.4160 - mean_squared_error: 11021.4160 - val_loss: 11314.3770 - val_mean_squared_error: 11314.3770 - 1s/epoch - 48ms/step
# Epoch 109/200
# 23/23 - 1s - loss: 6481.5454 - mean_squared_error: 6481.5454 - val_loss: 8102.1016 - val_mean_squared_error: 8102.1016 - 1s/epoch - 48ms/step
# Epoch 110/200
# 23/23 - 1s - loss: 9902.1660 - mean_squared_error: 9902.1660 - val_loss: 33265.7852 - val_mean_squared_error: 33265.7852 - 1s/epoch - 49ms/step
# Epoch 111/200
# 23/23 - 1s - loss: 16231.4473 - mean_squared_error: 16231.4473 - val_loss: 13129.1250 - val_mean_squared_error: 13129.1250 - 1s/epoch - 54ms/step
# Epoch 112/200
# 23/23 - 1s - loss: 9729.1904 - mean_squared_error: 9729.1904 - val_loss: 10023.0986 - val_mean_squared_error: 10023.0986 - 1s/epoch - 54ms/step
# Epoch 113/200
# 23/23 - 1s - loss: 7415.5742 - mean_squared_error: 7415.5742 - val_loss: 6749.6821 - val_mean_squared_error: 6749.6821 - 1s/epoch - 48ms/step
# Epoch 114/200
# 23/23 - 1s - loss: 5691.9858 - mean_squared_error: 5691.9858 - val_loss: 7840.0659 - val_mean_squared_error: 7840.0659 - 1s/epoch - 48ms/step
# Epoch 115/200
# 23/23 - 1s - loss: 6569.9678 - mean_squared_error: 6569.9678 - val_loss: 22464.2051 - val_mean_squared_error: 22464.2051 - 1s/epoch - 54ms/step
# Epoch 116/200
# 23/23 - 1s - loss: 7162.0830 - mean_squared_error: 7162.0830 - val_loss: 7543.2197 - val_mean_squared_error: 7543.2197 - 1s/epoch - 54ms/step
# Epoch 117/200
# 23/23 - 1s - loss: 5794.6553 - mean_squared_error: 5794.6553 - val_loss: 7089.2632 - val_mean_squared_error: 7089.2632 - 1s/epoch - 54ms/step
# Epoch 118/200
# 23/23 - 1s - loss: 5327.9941 - mean_squared_error: 5327.9941 - val_loss: 7343.2905 - val_mean_squared_error: 7343.2905 - 1s/epoch - 48ms/step
# Epoch 119/200
# 23/23 - 1s - loss: 5303.9141 - mean_squared_error: 5303.9141 - val_loss: 21831.6621 - val_mean_squared_error: 21831.6621 - 1s/epoch - 48ms/step
# Epoch 120/200
# 23/23 - 1s - loss: 7212.8345 - mean_squared_error: 7212.8345 - val_loss: 6956.7607 - val_mean_squared_error: 6956.7607 - 1s/epoch - 48ms/step
# Epoch 121/200
# 23/23 - 1s - loss: 10847.4961 - mean_squared_error: 10847.4961 - val_loss: 9265.4990 - val_mean_squared_error: 9265.4990 - 1s/epoch - 48ms/step
# Epoch 122/200
# 23/23 - 1s - loss: 7981.4121 - mean_squared_error: 7981.4121 - val_loss: 7648.0342 - val_mean_squared_error: 7648.0342 - 1s/epoch - 48ms/step
# Epoch 123/200
# 23/23 - 1s - loss: 6679.8423 - mean_squared_error: 6679.8423 - val_loss: 13566.6807 - val_mean_squared_error: 13566.6807 - 1s/epoch - 48ms/step
# Epoch 124/200
# 23/23 - 1s - loss: 8915.9209 - mean_squared_error: 8915.9209 - val_loss: 6754.8838 - val_mean_squared_error: 6754.8838 - 1s/epoch - 54ms/step
# Epoch 125/200
# 23/23 - 1s - loss: 5919.3052 - mean_squared_error: 5919.3052 - val_loss: 6318.3062 - val_mean_squared_error: 6318.3062 - 1s/epoch - 48ms/step
# Epoch 126/200
# 23/23 - 1s - loss: 4838.9185 - mean_squared_error: 4838.9185 - val_loss: 7827.2510 - val_mean_squared_error: 7827.2510 - 1s/epoch - 48ms/step
# Epoch 127/200
# 23/23 - 1s - loss: 4424.9614 - mean_squared_error: 4424.9614 - val_loss: 7399.8486 - val_mean_squared_error: 7399.8486 - 1s/epoch - 54ms/step
# Epoch 128/200
# 23/23 - 1s - loss: 7090.4009 - mean_squared_error: 7090.4009 - val_loss: 9128.9434 - val_mean_squared_error: 9128.9434 - 1s/epoch - 48ms/step
# Epoch 129/200
# 23/23 - 1s - loss: 7305.3086 - mean_squared_error: 7305.3086 - val_loss: 16019.8076 - val_mean_squared_error: 16019.8076 - 1s/epoch - 54ms/step
# Epoch 130/200
# 23/23 - 1s - loss: 13864.2217 - mean_squared_error: 13864.2217 - val_loss: 8482.1162 - val_mean_squared_error: 8482.1162 - 1s/epoch - 54ms/step
# Epoch 131/200
# 23/23 - 1s - loss: 7185.9712 - mean_squared_error: 7185.9712 - val_loss: 7832.5278 - val_mean_squared_error: 7832.5278 - 1s/epoch - 54ms/step
# Epoch 132/200
# 23/23 - 1s - loss: 5472.8120 - mean_squared_error: 5472.8120 - val_loss: 7405.9438 - val_mean_squared_error: 7405.9438 - 1s/epoch - 48ms/step
# Epoch 133/200
# 23/23 - 1s - loss: 4411.0137 - mean_squared_error: 4411.0137 - val_loss: 7764.8560 - val_mean_squared_error: 7764.8560 - 1s/epoch - 49ms/step
# Epoch 134/200
# 23/23 - 1s - loss: 4633.9526 - mean_squared_error: 4633.9526 - val_loss: 12748.2549 - val_mean_squared_error: 12748.2549 - 1s/epoch - 54ms/step
# Epoch 135/200
# 23/23 - 1s - loss: 5525.1440 - mean_squared_error: 5525.1440 - val_loss: 7359.4033 - val_mean_squared_error: 7359.4033 - 1s/epoch - 48ms/step
# Epoch 136/200
# 23/23 - 1s - loss: 6872.2139 - mean_squared_error: 6872.2139 - val_loss: 12325.4971 - val_mean_squared_error: 12325.4971 - 1s/epoch - 48ms/step
# Epoch 137/200
# 23/23 - 1s - loss: 5610.4712 - mean_squared_error: 5610.4712 - val_loss: 7536.5942 - val_mean_squared_error: 7536.5942 - 1s/epoch - 54ms/step
# Epoch 138/200
# 23/23 - 1s - loss: 4829.8096 - mean_squared_error: 4829.8096 - val_loss: 9502.7412 - val_mean_squared_error: 9502.7412 - 1s/epoch - 48ms/step
# Epoch 139/200
# 23/23 - 1s - loss: 4214.1885 - mean_squared_error: 4214.1885 - val_loss: 5622.6714 - val_mean_squared_error: 5622.6714 - 1s/epoch - 48ms/step
# Epoch 140/200
# 23/23 - 1s - loss: 3484.8643 - mean_squared_error: 3484.8643 - val_loss: 6787.7324 - val_mean_squared_error: 6787.7324 - 1s/epoch - 48ms/step
# Epoch 141/200
# 23/23 - 1s - loss: 3776.0737 - mean_squared_error: 3776.0737 - val_loss: 10102.3438 - val_mean_squared_error: 10102.3438 - 1s/epoch - 48ms/step
# Epoch 142/200
# 23/23 - 1s - loss: 4115.3574 - mean_squared_error: 4115.3574 - val_loss: 7004.0063 - val_mean_squared_error: 7004.0063 - 1s/epoch - 48ms/step
# Epoch 143/200
# 23/23 - 1s - loss: 3897.6804 - mean_squared_error: 3897.6804 - val_loss: 6710.2749 - val_mean_squared_error: 6710.2749 - 1s/epoch - 48ms/step
# Epoch 144/200
# 23/23 - 1s - loss: 7993.7017 - mean_squared_error: 7993.7017 - val_loss: 14569.4707 - val_mean_squared_error: 14569.4707 - 1s/epoch - 54ms/step
# Epoch 145/200
# 23/23 - 1s - loss: 9200.9424 - mean_squared_error: 9200.9424 - val_loss: 8818.6855 - val_mean_squared_error: 8818.6855 - 1s/epoch - 48ms/step
# Epoch 146/200
# 23/23 - 1s - loss: 8599.3496 - mean_squared_error: 8599.3496 - val_loss: 9438.2109 - val_mean_squared_error: 9438.2109 - 1s/epoch - 48ms/step
# Epoch 147/200
# 23/23 - 1s - loss: 5828.2744 - mean_squared_error: 5828.2744 - val_loss: 7154.0352 - val_mean_squared_error: 7154.0352 - 1s/epoch - 54ms/step
# Epoch 148/200
# 23/23 - 1s - loss: 3273.0364 - mean_squared_error: 3273.0364 - val_loss: 5642.1230 - val_mean_squared_error: 5642.1230 - 1s/epoch - 48ms/step
# Epoch 149/200
# 23/23 - 1s - loss: 3923.0056 - mean_squared_error: 3923.0056 - val_loss: 6297.5112 - val_mean_squared_error: 6297.5112 - 1s/epoch - 48ms/step
# Epoch 150/200
# 23/23 - 1s - loss: 3953.5500 - mean_squared_error: 3953.5500 - val_loss: 6343.6528 - val_mean_squared_error: 6343.6528 - 1s/epoch - 48ms/step
# Epoch 151/200
# 23/23 - 1s - loss: 3548.9905 - mean_squared_error: 3548.9905 - val_loss: 8533.4873 - val_mean_squared_error: 8533.4873 - 1s/epoch - 48ms/step
# Epoch 152/200
# 23/23 - 1s - loss: 3435.7920 - mean_squared_error: 3435.7920 - val_loss: 6189.1885 - val_mean_squared_error: 6189.1885 - 1s/epoch - 55ms/step
# Epoch 153/200
# 23/23 - 1s - loss: 3073.3425 - mean_squared_error: 3073.3425 - val_loss: 5570.7290 - val_mean_squared_error: 5570.7290 - 1s/epoch - 48ms/step
# Epoch 154/200
# 23/23 - 1s - loss: 3484.5000 - mean_squared_error: 3484.5000 - val_loss: 6413.6963 - val_mean_squared_error: 6413.6963 - 1s/epoch - 48ms/step
# Epoch 155/200
# 23/23 - 1s - loss: 4518.2603 - mean_squared_error: 4518.2603 - val_loss: 11957.7188 - val_mean_squared_error: 11957.7188 - 1s/epoch - 54ms/step
# Epoch 156/200
# 23/23 - 1s - loss: 4523.2070 - mean_squared_error: 4523.2070 - val_loss: 7300.2002 - val_mean_squared_error: 7300.2012 - 1s/epoch - 48ms/step
# Epoch 157/200
# 23/23 - 1s - loss: 4095.4441 - mean_squared_error: 4095.4441 - val_loss: 7004.7979 - val_mean_squared_error: 7004.7979 - 1s/epoch - 49ms/step
# Epoch 158/200
# 23/23 - 1s - loss: 5828.9092 - mean_squared_error: 5828.9092 - val_loss: 11002.5107 - val_mean_squared_error: 11002.5107 - 1s/epoch - 49ms/step
# Epoch 159/200
# 23/23 - 1s - loss: 4553.6611 - mean_squared_error: 4553.6611 - val_loss: 5831.5210 - val_mean_squared_error: 5831.5210 - 1s/epoch - 48ms/step
# Epoch 160/200
# 23/23 - 1s - loss: 3567.2319 - mean_squared_error: 3567.2319 - val_loss: 7774.4951 - val_mean_squared_error: 7774.4951 - 1s/epoch - 49ms/step
# Epoch 161/200
# 23/23 - 1s - loss: 3825.0261 - mean_squared_error: 3825.0261 - val_loss: 5451.2144 - val_mean_squared_error: 5451.2144 - 1s/epoch - 54ms/step
# Epoch 162/200
# 23/23 - 1s - loss: 3704.3359 - mean_squared_error: 3704.3359 - val_loss: 5501.0566 - val_mean_squared_error: 5501.0566 - 1s/epoch - 54ms/step
# Epoch 163/200
# 23/23 - 1s - loss: 3404.4092 - mean_squared_error: 3404.4092 - val_loss: 7775.6426 - val_mean_squared_error: 7775.6426 - 1s/epoch - 49ms/step
# Epoch 164/200
# 23/23 - 1s - loss: 4760.1968 - mean_squared_error: 4760.1968 - val_loss: 7516.3926 - val_mean_squared_error: 7516.3926 - 1s/epoch - 48ms/step
# Epoch 165/200
# 23/23 - 1s - loss: 3411.0413 - mean_squared_error: 3411.0413 - val_loss: 8997.1875 - val_mean_squared_error: 8997.1875 - 1s/epoch - 54ms/step
# Epoch 166/200
# 23/23 - 1s - loss: 3342.4099 - mean_squared_error: 3342.4099 - val_loss: 6601.5708 - val_mean_squared_error: 6601.5708 - 1s/epoch - 49ms/step
# Epoch 167/200
# 23/23 - 1s - loss: 2536.9990 - mean_squared_error: 2536.9990 - val_loss: 5977.5342 - val_mean_squared_error: 5977.5342 - 1s/epoch - 48ms/step
# Epoch 168/200
# 23/23 - 1s - loss: 2577.4312 - mean_squared_error: 2577.4312 - val_loss: 8205.4023 - val_mean_squared_error: 8205.4023 - 1s/epoch - 48ms/step
# Epoch 169/200
# 23/23 - 1s - loss: 3120.0720 - mean_squared_error: 3120.0720 - val_loss: 5822.9702 - val_mean_squared_error: 5822.9702 - 1s/epoch - 48ms/step
# Epoch 170/200
# 23/23 - 1s - loss: 2401.2590 - mean_squared_error: 2401.2590 - val_loss: 5721.2412 - val_mean_squared_error: 5721.2412 - 1s/epoch - 49ms/step
# Epoch 171/200
# 23/23 - 1s - loss: 3230.1917 - mean_squared_error: 3230.1917 - val_loss: 5257.9243 - val_mean_squared_error: 5257.9243 - 1s/epoch - 54ms/step
# Epoch 172/200
# 23/23 - 1s - loss: 2769.9919 - mean_squared_error: 2769.9919 - val_loss: 7087.7710 - val_mean_squared_error: 7087.7710 - 1s/epoch - 51ms/step
# Epoch 173/200
# 23/23 - 1s - loss: 3986.2676 - mean_squared_error: 3986.2676 - val_loss: 6396.9229 - val_mean_squared_error: 6396.9229 - 1s/epoch - 49ms/step
# Epoch 174/200
# 23/23 - 1s - loss: 3085.0195 - mean_squared_error: 3085.0195 - val_loss: 5886.9521 - val_mean_squared_error: 5886.9521 - 1s/epoch - 49ms/step
# Epoch 175/200
# 23/23 - 1s - loss: 2440.7668 - mean_squared_error: 2440.7668 - val_loss: 5185.2266 - val_mean_squared_error: 5185.2266 - 1s/epoch - 55ms/step
# Epoch 176/200
# 23/23 - 1s - loss: 3534.4053 - mean_squared_error: 3534.4053 - val_loss: 5493.8345 - val_mean_squared_error: 5493.8345 - 1s/epoch - 48ms/step
# Epoch 177/200
# 23/23 - 1s - loss: 3498.2922 - mean_squared_error: 3498.2922 - val_loss: 6146.3403 - val_mean_squared_error: 6146.3403 - 1s/epoch - 49ms/step
# Epoch 178/200
# 23/23 - 1s - loss: 2647.0430 - mean_squared_error: 2647.0430 - val_loss: 7305.1484 - val_mean_squared_error: 7305.1484 - 1s/epoch - 55ms/step
# Epoch 179/200
# 23/23 - 1s - loss: 2062.4358 - mean_squared_error: 2062.4358 - val_loss: 7925.8101 - val_mean_squared_error: 7925.8101 - 1s/epoch - 49ms/step
# Epoch 180/200
# 23/23 - 1s - loss: 2853.1230 - mean_squared_error: 2853.1230 - val_loss: 7910.2075 - val_mean_squared_error: 7910.2075 - 1s/epoch - 49ms/step
# Epoch 181/200
# 23/23 - 1s - loss: 2734.8127 - mean_squared_error: 2734.8127 - val_loss: 5056.9907 - val_mean_squared_error: 5056.9907 - 1s/epoch - 49ms/step
# Epoch 182/200
# 23/23 - 1s - loss: 2892.7583 - mean_squared_error: 2892.7583 - val_loss: 12302.8613 - val_mean_squared_error: 12302.8613 - 1s/epoch - 49ms/step
# Epoch 183/200
# 23/23 - 1s - loss: 3074.1809 - mean_squared_error: 3074.1809 - val_loss: 5641.7905 - val_mean_squared_error: 5641.7905 - 1s/epoch - 54ms/step
# Epoch 184/200
# 23/23 - 1s - loss: 2638.8606 - mean_squared_error: 2638.8606 - val_loss: 7169.1914 - val_mean_squared_error: 7169.1914 - 1s/epoch - 54ms/step
# Epoch 185/200
# 23/23 - 1s - loss: 2660.3477 - mean_squared_error: 2660.3477 - val_loss: 6032.2744 - val_mean_squared_error: 6032.2744 - 1s/epoch - 48ms/step
# Epoch 186/200
# 23/23 - 1s - loss: 2242.4795 - mean_squared_error: 2242.4795 - val_loss: 5786.4980 - val_mean_squared_error: 5786.4980 - 1s/epoch - 48ms/step
# Epoch 187/200
# 23/23 - 1s - loss: 1912.4696 - mean_squared_error: 1912.4696 - val_loss: 5348.5903 - val_mean_squared_error: 5348.5903 - 1s/epoch - 54ms/step
# Epoch 188/200
# 23/23 - 1s - loss: 2851.5947 - mean_squared_error: 2851.5947 - val_loss: 9560.4639 - val_mean_squared_error: 9560.4639 - 1s/epoch - 49ms/step
# Epoch 189/200
# 23/23 - 1s - loss: 3118.0188 - mean_squared_error: 3118.0188 - val_loss: 6893.6826 - val_mean_squared_error: 6893.6826 - 1s/epoch - 49ms/step
# Epoch 190/200
# 23/23 - 1s - loss: 3038.9109 - mean_squared_error: 3038.9109 - val_loss: 5797.0713 - val_mean_squared_error: 5797.0713 - 1s/epoch - 48ms/step
# Epoch 191/200
# 23/23 - 1s - loss: 2401.0266 - mean_squared_error: 2401.0266 - val_loss: 5485.2070 - val_mean_squared_error: 5485.2070 - 1s/epoch - 54ms/step
# Epoch 192/200
# 23/23 - 1s - loss: 1669.5784 - mean_squared_error: 1669.5784 - val_loss: 5574.6807 - val_mean_squared_error: 5574.6807 - 1s/epoch - 54ms/step
# Epoch 193/200
# 23/23 - 1s - loss: 1951.6672 - mean_squared_error: 1951.6672 - val_loss: 5266.9712 - val_mean_squared_error: 5266.9712 - 1s/epoch - 48ms/step
# Epoch 194/200
# 23/23 - 1s - loss: 2598.0281 - mean_squared_error: 2598.0281 - val_loss: 4870.9307 - val_mean_squared_error: 4870.9307 - 1s/epoch - 54ms/step
# Epoch 195/200
# 23/23 - 1s - loss: 2561.6167 - mean_squared_error: 2561.6167 - val_loss: 6158.2539 - val_mean_squared_error: 6158.2539 - 1s/epoch - 54ms/step
# Epoch 196/200
# 23/23 - 1s - loss: 2084.2732 - mean_squared_error: 2084.2732 - val_loss: 6398.0293 - val_mean_squared_error: 6398.0293 - 1s/epoch - 55ms/step
# Epoch 197/200
# 23/23 - 1s - loss: 2044.7435 - mean_squared_error: 2044.7435 - val_loss: 6603.0762 - val_mean_squared_error: 6603.0762 - 1s/epoch - 48ms/step
# Epoch 198/200
# 23/23 - 1s - loss: 1655.7784 - mean_squared_error: 1655.7784 - val_loss: 5282.0317 - val_mean_squared_error: 5282.0317 - 1s/epoch - 48ms/step
# Epoch 199/200
# 23/23 - 1s - loss: 2440.6130 - mean_squared_error: 2440.6130 - val_loss: 5875.3740 - val_mean_squared_error: 5875.3740 - 1s/epoch - 54ms/step
# Epoch 200/200
# 23/23 - 1s - loss: 3148.1023 - mean_squared_error: 3148.1023 - val_loss: 5406.5171 - val_mean_squared_error: 5406.5171 - 1s/epoch - 54ms/step

# %%
#data = timeProcess()[1]
#modelo.save('/content/drive/MyDrive/1_Informações_scripts//model__3T3_regressao_menor_erro_Mean_squared_error_200_epochs_'+data+'.h5')

# %% [markdown]
# ## Accuracy Assessment

# %%
#gráfico avaliando a acurácia a partir de treino e teste
plt.plot(history.history['mean_squared_error'])
plt.plot(history.history['val_mean_squared_error'])
plt.title('Accuracy Metric')
plt.ylabel('MSE')
plt.xlabel('Epochs')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
#avaliando a previsão do modelo com os rótulos
prev = modelo.predict(X_test)
plt.title('Previsão dos valores Operetta')
plt.ylabel('Rótulos')
plt.xlabel('Previsão')
plt.plot(prev)#azul - o que o modelo previu
plt.plot(y_test)#laranja - o que se sabe - observado
plt.show()
# Out:
# 10/10 [==============================] - 0s 19ms/step

# %%
# Qualit model analisys
from sklearn.metrics import r2_score,mean_absolute_error, mean_squared_error, mean_squared_log_error, median_absolute_error

# %%
#buscando pelas métricas
print(f"{round(r2_score(y_test, prev) * 100, 2)}% r2_score") #raíz quadrada
print(f"{round(mean_absolute_error(y_test, prev), 2)} Erro médio absoluto") 
print(f"{round(mean_squared_error(y_test, prev), 2)} Erro médio quadrático") #erro médio quadrático
# print(f"{round(median_absolute_error(y_test, prev), 2)}")#Erro médio absoluto sem %
#print(f"{round(median(y_test, prev), 2)} mediana") #erro médio quadrático
# Out:
# 93.01% r2_score
# 56.21 Erro médio absoluto
# 5406.52 Erro médio quadrático

# %%
# #salvando o modelo
data = timeProcess()[1]
modelo.save('/content/drive/MyDrive/Regressão_imagens_DOC_CNN/results_A549/modelo_A549_100_75_50_25_'+data+'.h5')
