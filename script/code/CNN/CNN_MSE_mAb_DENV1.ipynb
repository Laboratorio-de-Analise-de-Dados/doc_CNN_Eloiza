# %% [markdown]
# # mAb_DENV1

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
pip install util-gfsilveira
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: util-gfsilveira in /usr/local/lib/python3.8/dist-packages (0.1)

# %% [markdown]
# # Imports data structuring

# %%
#organização dos arquivos
import os
#salvar/carregar arquivos em diferentes formatos
import joblib
#organizando os arquivos de forma aleatória
import random
#gerar gráfico
import matplotlib
#estruturação dos dados
import numpy as np
#gerar gráfico
import seaborn as sns
#gerar gráfico
import matplotlib.pyplot as plt
#gerar imagem
import matplotlib.image as mpimg

# %% [markdown]
# # CNN template import

# %%
#modelo de revisão redes neurais - cnn
from keras.models import Sequential
from keras.utils.np_utils import to_categorical
#from keras.utils import to_categorical
from util import meus_uteis, timeProcess, mask_corr_graphic, printLis
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report
from keras.layers import Dense, Conv2D, MaxPooling2D, Dropout, Flatten

# %% [markdown]
# Documents from different files will be stored in this directory

# %%
diretorio = '/content/drive/MyDrive/Regressão_imagens_DOC_CNN/results_mAb_DENV1' #alimentando a variável com os arquivos da pasta datasets
lista_dados = os.listdir(diretorio) #listando os arquivos dessa pasta
printLis(lista_dados) #printando as diferentes listas
# Out:
# -------------
# -=< Lista >=-
# -------------
# 0 -> lista_img_camp_clar_100_resized_regressao_mAb_DENV12022-10-25.gz
# 1 -> lista_rotulo_camp_clar_100_resized_regressao_mAb_DENV12022-10-25.gz
# 2 -> lista_img_camp_clar_75_resized_regressao_mAb_DENV12022-10-25.gz
# 3 -> lista_rotulo_camp_clar_75_resized_regressao_mAb_DENV12022-10-25.gz
# 4 -> lista_img_camp_clar_50_resized_regressao_mAb_DENV12022-10-25.gz
# 5 -> lista_rotulo_camp_clar_50_resized_regressao_mAb_DENV12022-10-25.gz
# 6 -> lista_img_camp_clar_25_resized_regressao_mAb_DENV12022-10-25.gz
# 7 -> lista_rotulo_camp_clar_25_resized_regressao_mAb_DENV12022-10-25.gz
# 8 -> 1_images_de_X_train_mab_denv_melhor_modelo_200_epochs_2022-12-14.gz
# 9 -> 2_images_de_y_train_mab_denv_melhor_modelo_200_epochs_2022-12-14.gz
# 10 -> 3_images_de_X_test_mab_denv_melhor_modelo_200_epochs_2022-12-14.gz
# 11 -> 4_images_de_y_test_mab_denv_melhor_model_200_epochs_2022-12-14.gz
# 12 -> modelo_mab_DENV_100_75_50_25_2022-12-14.h5

# %% [markdown]
# Lists of all images in each file

# %%
#lstando arquivos com as imagens 100%, 75%, 50%, 25%
for k, v in enumerate(lista_dados):
    if k in [0,2,4,6]:
        print(f'{k} -> {v}')
# Out:
# 0 -> lista_img_camp_clar_100_resized_regressao_mAb_DENV12022-10-25.gz
# 2 -> lista_img_camp_clar_75_resized_regressao_mAb_DENV12022-10-25.gz
# 4 -> lista_img_camp_clar_50_resized_regressao_mAb_DENV12022-10-25.gz
# 6 -> lista_img_camp_clar_25_resized_regressao_mAb_DENV12022-10-25.gz

# %% [markdown]
# ## x = features/images

# %%
#somando todas as imagens de diferentes tamanho
X_cem = joblib.load(diretorio+ '/' + lista_dados[0])

# 12 -> 00-lista_img_dapi_crop_75_resized_2021-5-12.gz
X_setcin = joblib.load(diretorio+ '/' + lista_dados[2])

# 10 -> 00-lista_img_dapi_crop_50_resized_2021-5-12.gz
X_cinq = joblib.load(diretorio+ '/' + lista_dados[4])

# 8 -> 00-lista_img_dapi_crop_25_resized_2021-5-12.gz
X_vincin = joblib.load(diretorio+ '/' + lista_dados[6])

x = np.asarray(list(X_cem) + list(X_setcin) + list(X_cinq) + list(X_vincin))

x.shape
# Out:
# (1520, 200, 200, 3)

# %% [markdown]
# ## y = labels

# %% [markdown]
# Opening the labels that were saved in the preparation of the images

# %%
for k, v in enumerate(lista_dados):
    if k in [1,3,5,7]:
        print(f'{k} -> {v}')
# Out:
# 1 -> lista_rotulo_camp_clar_100_resized_regressao_mAb_DENV12022-10-25.gz
# 3 -> lista_rotulo_camp_clar_75_resized_regressao_mAb_DENV12022-10-25.gz
# 5 -> lista_rotulo_camp_clar_50_resized_regressao_mAb_DENV12022-10-25.gz
# 7 -> lista_rotulo_camp_clar_25_resized_regressao_mAb_DENV12022-10-25.gz

# %%
#somando todos os rótulos de diferentes tamanho
y_cem = joblib.load(diretorio+ '/' + lista_dados[1])

# 12 -> 00-lista_img_dapi_crop_75_resized_2021-5-12.gz
y_setcin = joblib.load(diretorio+ '/' + lista_dados[3])

# 10 -> 00-lista_img_dapi_crop_50_resized_2021-5-12.gz
y_cinq = joblib.load(diretorio+ '/' + lista_dados[5])

# 8 -> 00-lista_img_dapi_crop_25_resized_2021-5-12.gz
y_vincin = joblib.load(diretorio+ '/' + lista_dados[7])

y = np.asarray(list(y_cem) + list(y_setcin) + list(y_cinq) + list(y_vincin))

y.shape
# Out:
# (1520,)

# %%
#Train and test split datasets for CNN model
#função que separa as imagens em teste e treino
from sklearn.model_selection import train_test_split

# %% [markdown]
# #Separando dados de validação

# %%
#imagens_teste = x.shape[0] * 0.9 #pegando só das imagens 30% das imagens vai para o teste
#imagens_treino = x.shape[0] - imagens_teste #restante das imagens (70%)
#print('Data for Modeling: ' + str(imagens_teste))
#print('Unseen Data For Predictions: ' + str(imagens_treino))

# %%
zeros = list(np.zeros(1368))
ones = list(np.ones(152))
lista = np.array(zeros + ones)
lista
# Out:
# array([0., 0., 0., ..., 1., 1., 1.])

# %%
random.shuffle(lista)
lista_valida = [True if i == 1 else False for i in lista]
lista_treino_test = [False if i == 1 else True for i in lista]
np.array(lista_valida)
# Out:
# array([False, False, False, ..., False, False, False])

# %%
#imagens
x_valida = x[lista_valida]
x_treino_test = x[lista_treino_test]

print(x_valida.shape)
print(x_treino_test.shape)
# Out:
# (152, 200, 200, 3)
# (1368, 200, 200, 3)

# %%
#rótulos
y_valida = y[lista_valida]
y_treino_test = y[lista_treino_test]

print(y_valida.shape)
print(y_treino_test.shape)
# Out:
# (152,)
# (1368,)

# %%
#imagens_teste = x.shape[0] * 0.9 #pegando só das imagens 30% das imagens vai para o teste
#imagens_treino = x.shape[0] - imagens_teste #restante das imagens (70%)
#print('Data for Modeling: ' + str(imagens_teste))
#print('Unseen Data For Predictions: ' + str(imagens_treino))
# Out:
# Data for Modeling: 1368.0
# Unseen Data For Predictions: 152.0

# %% [markdown]
# Dados restantes 90%

# %%
data = timeProcess()[1]

# %%
#Salvando 10$ das imagens para validação
joblib.dump(x_valida, '/content/drive/MyDrive/Regressão_imagens_DOC_CNN/results_mAb_DENV1/imagens_validação_10%_mab_DENV_'+data+'.gz')
joblib.dump(y_valida, '/content/drive/MyDrive/Regressão_imagens_DOC_CNN/results_mAb_DENV1/rótulos_validação_10%_mab_DENV_'+data+'.gz')
# Out:
# ['/content/drive/MyDrive/Regressão_imagens_DOC_CNN/results_mAb_DENV1/rótulos_validação_10%_mab_DENV_2022-12-15.gz']

# %% [markdown]
# Test and training separation from a library.

# %%
X_train, X_test, y_train, y_test = train_test_split(x_treino_test, y_treino_test, test_size=0.3, random_state=0)
#variáveis recebem o número de imagens para tes e treino
print(f'{X_train.shape} \n{X_test.shape} \n{y_train.shape} \n{y_test.shape}')
# Out:
# (957, 200, 200, 3)
# (411, 200, 200, 3)
# (957,)
# (411,)

# %%
#salvando os resultados de treino e teste
joblib.dump(X_train, '/content/drive/MyDrive/Regressão_imagens_DOC_CNN/results_mAb_DENV1/1_images_de_X_train_mab_denv_melhor_modelo_200_epochs_90%_'+data+'.gz')
joblib.dump(y_train, '/content/drive/MyDrive/Regressão_imagens_DOC_CNN/results_mAb_DENV1/2_rotulos_de_y_train_mab_denv_melhor_modelo_200_epochs_90%_'+data+'.gz')
joblib.dump(X_test, '/content/drive/MyDrive/Regressão_imagens_DOC_CNN/results_mAb_DENV1/3_images_de_X_test_mab_denv_melhor_modelo_200_epochs_90%_'+data+'.gz')
joblib.dump(y_test, '/content/drive/MyDrive/Regressão_imagens_DOC_CNN/results_mAb_DENV1/4_rotulos_de_y_test_mab_denv_melhor_model_200_epochs_90%_'+data+'.gz')
# Out:
# ['/content/drive/MyDrive/Regressão_imagens_DOC_CNN/results_mAb_DENV1/4_rotulos_de_y_test_mab_denv_melhor_model_200_epochs_90%_2022-12-15.gz']

# %% [markdown]
# ### Model determination

# %%
modelo = Sequential()
modelo.add(Conv2D(32, kernel_size=3, activation='relu', input_shape=X_train[0].shape))
#função de ativação relu é muito utilizado para problemas de regressão
modelo.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2), padding='valid'))
modelo.add(Conv2D(64, kernel_size=3, activation='relu'))
modelo.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2), padding='valid'))
modelo.add(Conv2D(128, kernel_size=3, activation='relu'))
modelo.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2), padding='valid'))
modelo.add(Conv2D(256, kernel_size=3, activation='relu'))
modelo.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2), padding='valid'))
modelo.add(Flatten())
modelo.add(Dropout(0.9))
modelo.add(Dense(1, activation='linear'))
#apenas uma saída e de forma linear
modelo.compile(optimizer='adam', loss='mse', metrics=['mean_squared_error'])
print(modelo.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 198, 198, 32)      896
#
#  max_pooling2d (MaxPooling2D  (None, 99, 99, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 97, 97, 64)        18496
#
#  max_pooling2d_1 (MaxPooling  (None, 48, 48, 64)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 46, 46, 128)       73856
#
#  max_pooling2d_2 (MaxPooling  (None, 23, 23, 128)      0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 21, 21, 256)       295168
#
#  max_pooling2d_3 (MaxPooling  (None, 10, 10, 256)      0
#  2D)
#
#  flatten (Flatten)           (None, 25600)             0
#
#  dropout (Dropout)           (None, 25600)             0
#
#  dense (Dense)               (None, 1)                 25601
#
# =================================================================
# Total params: 414,017
# Trainable params: 414,017
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# # Training and testing epochs

# %%
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.callbacks import ModelCheckpoint

# %%
# simple early stopping
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=18)

# %%
# fit model
history = modelo.fit(X_train,y_train,
                    validation_data=(X_test, y_test), 
                    epochs=200, verbose=2, 
                    callbacks=[es]
                     )
# Out:
# Epoch 1/200
# 30/30 - 11s - loss: 217458.0469 - mean_squared_error: 217458.0469 - val_loss: 122681.3438 - val_mean_squared_error: 122681.3438 - 11s/epoch - 376ms/step
# Epoch 2/200
# 30/30 - 2s - loss: 123690.0234 - mean_squared_error: 123690.0234 - val_loss: 100820.4375 - val_mean_squared_error: 100820.4375 - 2s/epoch - 52ms/step
# Epoch 3/200
# 30/30 - 1s - loss: 90284.4844 - mean_squared_error: 90284.4844 - val_loss: 66703.9844 - val_mean_squared_error: 66703.9844 - 1s/epoch - 49ms/step
# Epoch 4/200
# 30/30 - 2s - loss: 65323.5117 - mean_squared_error: 65323.5117 - val_loss: 51771.9453 - val_mean_squared_error: 51771.9453 - 2s/epoch - 52ms/step
# Epoch 5/200
# 30/30 - 1s - loss: 51446.7461 - mean_squared_error: 51446.7461 - val_loss: 55948.2734 - val_mean_squared_error: 55948.2734 - 1s/epoch - 49ms/step
# Epoch 6/200
# 30/30 - 1s - loss: 52429.7734 - mean_squared_error: 52429.7734 - val_loss: 46671.9062 - val_mean_squared_error: 46671.9062 - 1s/epoch - 49ms/step
# Epoch 7/200
# 30/30 - 1s - loss: 55499.6914 - mean_squared_error: 55499.6914 - val_loss: 58497.4609 - val_mean_squared_error: 58497.4609 - 1s/epoch - 49ms/step
# Epoch 8/200
# 30/30 - 2s - loss: 54392.9023 - mean_squared_error: 54392.9023 - val_loss: 50153.9258 - val_mean_squared_error: 50153.9258 - 2s/epoch - 52ms/step
# Epoch 9/200
# 30/30 - 1s - loss: 47055.2812 - mean_squared_error: 47055.2812 - val_loss: 51804.8594 - val_mean_squared_error: 51804.8594 - 1s/epoch - 49ms/step
# Epoch 10/200
# 30/30 - 2s - loss: 52142.6797 - mean_squared_error: 52142.6797 - val_loss: 43371.2422 - val_mean_squared_error: 43371.2422 - 2s/epoch - 52ms/step
# Epoch 11/200
# 30/30 - 2s - loss: 57807.6055 - mean_squared_error: 57807.6055 - val_loss: 69802.4453 - val_mean_squared_error: 69802.4453 - 2s/epoch - 52ms/step
# Epoch 12/200
# 30/30 - 1s - loss: 43953.3945 - mean_squared_error: 43953.3945 - val_loss: 70539.6875 - val_mean_squared_error: 70539.6875 - 1s/epoch - 49ms/step
# Epoch 13/200
# 30/30 - 2s - loss: 56479.6211 - mean_squared_error: 56479.6211 - val_loss: 41300.6719 - val_mean_squared_error: 41300.6719 - 2s/epoch - 51ms/step
# Epoch 14/200
# 30/30 - 1s - loss: 41607.9297 - mean_squared_error: 41607.9297 - val_loss: 63435.9727 - val_mean_squared_error: 63435.9727 - 1s/epoch - 50ms/step
# Epoch 15/200
# 30/30 - 1s - loss: 53288.7227 - mean_squared_error: 53288.7227 - val_loss: 40611.3320 - val_mean_squared_error: 40611.3320 - 1s/epoch - 50ms/step
# Epoch 16/200
# 30/30 - 1s - loss: 40950.7891 - mean_squared_error: 40950.7891 - val_loss: 40222.3789 - val_mean_squared_error: 40222.3789 - 1s/epoch - 49ms/step
# Epoch 17/200
# 30/30 - 2s - loss: 42429.0078 - mean_squared_error: 42429.0078 - val_loss: 44252.4180 - val_mean_squared_error: 44252.4180 - 2s/epoch - 52ms/step
# Epoch 18/200
# 30/30 - 1s - loss: 41110.8125 - mean_squared_error: 41110.8125 - val_loss: 44296.5078 - val_mean_squared_error: 44296.5078 - 1s/epoch - 50ms/step
# Epoch 19/200
# 30/30 - 2s - loss: 55371.2227 - mean_squared_error: 55371.2227 - val_loss: 40368.1055 - val_mean_squared_error: 40368.1055 - 2s/epoch - 52ms/step
# Epoch 20/200
# 30/30 - 1s - loss: 40537.8359 - mean_squared_error: 40537.8359 - val_loss: 49960.4219 - val_mean_squared_error: 49960.4219 - 1s/epoch - 49ms/step
# Epoch 21/200
# 30/30 - 2s - loss: 41931.6875 - mean_squared_error: 41931.6875 - val_loss: 36510.8750 - val_mean_squared_error: 36510.8750 - 2s/epoch - 52ms/step
# Epoch 22/200
# 30/30 - 1s - loss: 37855.9609 - mean_squared_error: 37855.9609 - val_loss: 35479.7461 - val_mean_squared_error: 35479.7461 - 1s/epoch - 49ms/step
# Epoch 23/200
# 30/30 - 2s - loss: 37471.2578 - mean_squared_error: 37471.2578 - val_loss: 33381.2266 - val_mean_squared_error: 33381.2266 - 2s/epoch - 52ms/step
# Epoch 24/200
# 30/30 - 1s - loss: 36402.7188 - mean_squared_error: 36402.7188 - val_loss: 43187.8203 - val_mean_squared_error: 43187.8203 - 1s/epoch - 49ms/step
# Epoch 25/200
# 30/30 - 2s - loss: 39289.3398 - mean_squared_error: 39289.3398 - val_loss: 38840.0859 - val_mean_squared_error: 38840.0859 - 2s/epoch - 52ms/step
# Epoch 26/200
# 30/30 - 1s - loss: 37397.7266 - mean_squared_error: 37397.7266 - val_loss: 36217.1641 - val_mean_squared_error: 36217.1641 - 1s/epoch - 49ms/step
# Epoch 27/200
# 30/30 - 2s - loss: 35198.0859 - mean_squared_error: 35198.0859 - val_loss: 31352.0020 - val_mean_squared_error: 31352.0020 - 2s/epoch - 52ms/step
# Epoch 28/200
# 30/30 - 1s - loss: 32636.3770 - mean_squared_error: 32636.3770 - val_loss: 47586.7578 - val_mean_squared_error: 47586.7578 - 1s/epoch - 49ms/step
# Epoch 29/200
# 30/30 - 1s - loss: 50049.3945 - mean_squared_error: 50049.3945 - val_loss: 43753.9180 - val_mean_squared_error: 43753.9180 - 1s/epoch - 50ms/step
# Epoch 30/200
# 30/30 - 1s - loss: 38255.7344 - mean_squared_error: 38255.7344 - val_loss: 34086.4023 - val_mean_squared_error: 34086.4023 - 1s/epoch - 50ms/step
# Epoch 31/200
# 30/30 - 2s - loss: 33394.0586 - mean_squared_error: 33394.0586 - val_loss: 43242.3203 - val_mean_squared_error: 43242.3203 - 2s/epoch - 52ms/step
# Epoch 32/200
# 30/30 - 2s - loss: 31432.4492 - mean_squared_error: 31432.4492 - val_loss: 36395.9922 - val_mean_squared_error: 36395.9922 - 2s/epoch - 52ms/step
# Epoch 33/200
# 30/30 - 1s - loss: 31347.8477 - mean_squared_error: 31347.8477 - val_loss: 33268.7148 - val_mean_squared_error: 33268.7148 - 1s/epoch - 49ms/step
# Epoch 34/200
# 30/30 - 1s - loss: 29288.9844 - mean_squared_error: 29288.9844 - val_loss: 29876.0918 - val_mean_squared_error: 29876.0918 - 1s/epoch - 50ms/step
# Epoch 35/200
# 30/30 - 1s - loss: 30789.5820 - mean_squared_error: 30789.5820 - val_loss: 39965.7070 - val_mean_squared_error: 39965.7070 - 1s/epoch - 49ms/step
# Epoch 36/200
# 30/30 - 1s - loss: 35731.1406 - mean_squared_error: 35731.1406 - val_loss: 30146.0586 - val_mean_squared_error: 30146.0586 - 1s/epoch - 50ms/step
# Epoch 37/200
# 30/30 - 2s - loss: 29830.6191 - mean_squared_error: 29830.6172 - val_loss: 40010.7539 - val_mean_squared_error: 40010.7539 - 2s/epoch - 52ms/step
# Epoch 38/200
# 30/30 - 1s - loss: 27366.6934 - mean_squared_error: 27366.6934 - val_loss: 30377.5176 - val_mean_squared_error: 30377.5176 - 1s/epoch - 49ms/step
# Epoch 39/200
# 30/30 - 1s - loss: 22979.3105 - mean_squared_error: 22979.3105 - val_loss: 18466.8828 - val_mean_squared_error: 18466.8828 - 1s/epoch - 50ms/step
# Epoch 40/200
# 30/30 - 2s - loss: 26217.3516 - mean_squared_error: 26217.3516 - val_loss: 30293.8047 - val_mean_squared_error: 30293.8047 - 2s/epoch - 52ms/step
# Epoch 41/200
# 30/30 - 1s - loss: 25445.5898 - mean_squared_error: 25445.5898 - val_loss: 25335.7520 - val_mean_squared_error: 25335.7520 - 1s/epoch - 50ms/step
# Epoch 42/200
# 30/30 - 2s - loss: 23551.1270 - mean_squared_error: 23551.1270 - val_loss: 26067.9219 - val_mean_squared_error: 26067.9219 - 2s/epoch - 52ms/step
# Epoch 43/200
# 30/30 - 2s - loss: 26351.8633 - mean_squared_error: 26351.8633 - val_loss: 29882.8145 - val_mean_squared_error: 29882.8145 - 2s/epoch - 52ms/step
# Epoch 44/200
# 30/30 - 2s - loss: 25513.1074 - mean_squared_error: 25513.1074 - val_loss: 53463.5586 - val_mean_squared_error: 53463.5586 - 2s/epoch - 52ms/step
# Epoch 45/200
# 30/30 - 2s - loss: 32210.6953 - mean_squared_error: 32210.6953 - val_loss: 25395.9961 - val_mean_squared_error: 25395.9961 - 2s/epoch - 52ms/step
# Epoch 46/200
# 30/30 - 2s - loss: 21132.5840 - mean_squared_error: 21132.5840 - val_loss: 35379.9570 - val_mean_squared_error: 35379.9570 - 2s/epoch - 52ms/step
# Epoch 47/200
# 30/30 - 1s - loss: 25707.1562 - mean_squared_error: 25707.1562 - val_loss: 51081.7383 - val_mean_squared_error: 51081.7383 - 1s/epoch - 50ms/step
# Epoch 48/200
# 30/30 - 2s - loss: 35284.4844 - mean_squared_error: 35284.4844 - val_loss: 26217.4590 - val_mean_squared_error: 26217.4590 - 2s/epoch - 52ms/step
# Epoch 49/200
# 30/30 - 1s - loss: 19895.9746 - mean_squared_error: 19895.9746 - val_loss: 17306.9844 - val_mean_squared_error: 17306.9844 - 1s/epoch - 50ms/step
# Epoch 50/200
# 30/30 - 1s - loss: 17394.8496 - mean_squared_error: 17394.8496 - val_loss: 14862.1152 - val_mean_squared_error: 14862.1152 - 1s/epoch - 50ms/step
# Epoch 51/200
# 30/30 - 1s - loss: 31949.9375 - mean_squared_error: 31949.9375 - val_loss: 26436.4219 - val_mean_squared_error: 26436.4219 - 1s/epoch - 50ms/step
# Epoch 52/200
# 30/30 - 2s - loss: 33522.5156 - mean_squared_error: 33522.5156 - val_loss: 25349.2676 - val_mean_squared_error: 25349.2676 - 2s/epoch - 52ms/step
# Epoch 53/200
# 30/30 - 1s - loss: 25362.4668 - mean_squared_error: 25362.4668 - val_loss: 25090.9316 - val_mean_squared_error: 25090.9316 - 1s/epoch - 50ms/step
# Epoch 54/200
# 30/30 - 1s - loss: 24858.5098 - mean_squared_error: 24858.5098 - val_loss: 28717.1777 - val_mean_squared_error: 28717.1777 - 1s/epoch - 50ms/step
# Epoch 55/200
# 30/30 - 2s - loss: 17262.1895 - mean_squared_error: 17262.1895 - val_loss: 14700.1553 - val_mean_squared_error: 14700.1553 - 2s/epoch - 52ms/step
# Epoch 56/200
# 30/30 - 1s - loss: 16789.1719 - mean_squared_error: 16789.1719 - val_loss: 18480.6055 - val_mean_squared_error: 18480.6055 - 1s/epoch - 50ms/step
# Epoch 57/200
# 30/30 - 1s - loss: 17356.3398 - mean_squared_error: 17356.3398 - val_loss: 15409.2725 - val_mean_squared_error: 15409.2725 - 1s/epoch - 50ms/step
# Epoch 58/200
# 30/30 - 1s - loss: 15134.8242 - mean_squared_error: 15134.8242 - val_loss: 12787.5947 - val_mean_squared_error: 12787.5947 - 1s/epoch - 50ms/step
# Epoch 59/200
# 30/30 - 1s - loss: 14384.3740 - mean_squared_error: 14384.3740 - val_loss: 17459.1797 - val_mean_squared_error: 17459.1797 - 1s/epoch - 49ms/step
# Epoch 60/200
# 30/30 - 2s - loss: 16078.0059 - mean_squared_error: 16078.0059 - val_loss: 17583.0762 - val_mean_squared_error: 17583.0762 - 2s/epoch - 52ms/step
# Epoch 61/200
# 30/30 - 2s - loss: 16116.9473 - mean_squared_error: 16116.9473 - val_loss: 15641.0781 - val_mean_squared_error: 15641.0781 - 2s/epoch - 52ms/step
# Epoch 62/200
# 30/30 - 1s - loss: 13599.8193 - mean_squared_error: 13599.8193 - val_loss: 14355.9521 - val_mean_squared_error: 14355.9521 - 1s/epoch - 50ms/step
# Epoch 63/200
# 30/30 - 2s - loss: 15580.4863 - mean_squared_error: 15580.4863 - val_loss: 15207.5186 - val_mean_squared_error: 15207.5186 - 2s/epoch - 52ms/step
# Epoch 64/200
# 30/30 - 1s - loss: 13081.1631 - mean_squared_error: 13081.1631 - val_loss: 13096.7969 - val_mean_squared_error: 13096.7969 - 1s/epoch - 49ms/step
# Epoch 65/200
# 30/30 - 1s - loss: 16379.8525 - mean_squared_error: 16379.8525 - val_loss: 17257.2090 - val_mean_squared_error: 17257.2090 - 1s/epoch - 49ms/step
# Epoch 66/200
# 30/30 - 2s - loss: 11345.4873 - mean_squared_error: 11345.4873 - val_loss: 12426.8018 - val_mean_squared_error: 12426.8018 - 2s/epoch - 52ms/step
# Epoch 67/200
# 30/30 - 1s - loss: 14667.5557 - mean_squared_error: 14667.5557 - val_loss: 19659.5039 - val_mean_squared_error: 19659.5039 - 1s/epoch - 49ms/step
# Epoch 68/200
# 30/30 - 1s - loss: 14935.7451 - mean_squared_error: 14935.7451 - val_loss: 18987.2871 - val_mean_squared_error: 18987.2871 - 1s/epoch - 50ms/step
# Epoch 69/200
# 30/30 - 2s - loss: 14181.0312 - mean_squared_error: 14181.0312 - val_loss: 14196.4404 - val_mean_squared_error: 14196.4404 - 2s/epoch - 52ms/step
# Epoch 70/200
# 30/30 - 2s - loss: 12946.4912 - mean_squared_error: 12946.4912 - val_loss: 13262.4004 - val_mean_squared_error: 13262.4004 - 2s/epoch - 52ms/step
# Epoch 71/200
# 30/30 - 2s - loss: 10848.7100 - mean_squared_error: 10848.7100 - val_loss: 15760.7344 - val_mean_squared_error: 15760.7344 - 2s/epoch - 52ms/step
# Epoch 72/200
# 30/30 - 1s - loss: 12748.7305 - mean_squared_error: 12748.7305 - val_loss: 16847.5957 - val_mean_squared_error: 16847.5957 - 1s/epoch - 50ms/step
# Epoch 73/200
# 30/30 - 2s - loss: 12418.4111 - mean_squared_error: 12418.4111 - val_loss: 14443.1914 - val_mean_squared_error: 14443.1914 - 2s/epoch - 52ms/step
# Epoch 74/200
# 30/30 - 2s - loss: 11771.1367 - mean_squared_error: 11771.1367 - val_loss: 11555.4346 - val_mean_squared_error: 11555.4346 - 2s/epoch - 50ms/step
# Epoch 75/200
# 30/30 - 2s - loss: 11444.1240 - mean_squared_error: 11444.1240 - val_loss: 11818.9941 - val_mean_squared_error: 11818.9941 - 2s/epoch - 52ms/step
# Epoch 76/200
# 30/30 - 2s - loss: 14958.4199 - mean_squared_error: 14958.4199 - val_loss: 36873.5117 - val_mean_squared_error: 36873.5117 - 2s/epoch - 52ms/step
# Epoch 77/200
# 30/30 - 2s - loss: 16809.4512 - mean_squared_error: 16809.4512 - val_loss: 23427.9082 - val_mean_squared_error: 23427.9082 - 2s/epoch - 53ms/step
# Epoch 78/200
# 30/30 - 1s - loss: 11950.3447 - mean_squared_error: 11950.3447 - val_loss: 13455.3867 - val_mean_squared_error: 13455.3867 - 1s/epoch - 50ms/step
# Epoch 79/200
# 30/30 - 2s - loss: 15774.4736 - mean_squared_error: 15774.4736 - val_loss: 17299.8223 - val_mean_squared_error: 17299.8223 - 2s/epoch - 50ms/step
# Epoch 80/200
# 30/30 - 2s - loss: 12220.5342 - mean_squared_error: 12220.5342 - val_loss: 13904.9248 - val_mean_squared_error: 13904.9248 - 2s/epoch - 50ms/step
# Epoch 81/200
# 30/30 - 2s - loss: 13336.7695 - mean_squared_error: 13336.7695 - val_loss: 14865.3086 - val_mean_squared_error: 14865.3086 - 2s/epoch - 53ms/step
# Epoch 82/200
# 30/30 - 2s - loss: 13462.7812 - mean_squared_error: 13462.7812 - val_loss: 11102.0977 - val_mean_squared_error: 11102.0977 - 2s/epoch - 51ms/step
# Epoch 83/200
# 30/30 - 2s - loss: 11174.9668 - mean_squared_error: 11174.9668 - val_loss: 22943.1504 - val_mean_squared_error: 22943.1504 - 2s/epoch - 53ms/step
# Epoch 84/200
# 30/30 - 2s - loss: 11640.6953 - mean_squared_error: 11640.6953 - val_loss: 11587.9961 - val_mean_squared_error: 11587.9961 - 2s/epoch - 50ms/step
# Epoch 85/200
# 30/30 - 2s - loss: 10253.4033 - mean_squared_error: 10253.4033 - val_loss: 16377.0859 - val_mean_squared_error: 16377.0859 - 2s/epoch - 50ms/step
# Epoch 86/200
# 30/30 - 2s - loss: 11967.2871 - mean_squared_error: 11967.2871 - val_loss: 12704.9414 - val_mean_squared_error: 12704.9414 - 2s/epoch - 52ms/step
# Epoch 87/200
# 30/30 - 2s - loss: 11333.3740 - mean_squared_error: 11333.3740 - val_loss: 20729.9316 - val_mean_squared_error: 20729.9316 - 2s/epoch - 53ms/step
# Epoch 88/200
# 30/30 - 2s - loss: 11569.2207 - mean_squared_error: 11569.2207 - val_loss: 20459.2207 - val_mean_squared_error: 20459.2207 - 2s/epoch - 52ms/step
# Epoch 89/200
# 30/30 - 1s - loss: 11494.9287 - mean_squared_error: 11494.9287 - val_loss: 37276.9727 - val_mean_squared_error: 37276.9727 - 1s/epoch - 50ms/step
# Epoch 90/200
# 30/30 - 1s - loss: 16245.5410 - mean_squared_error: 16245.5410 - val_loss: 14067.0000 - val_mean_squared_error: 14067.0000 - 1s/epoch - 50ms/step
# Epoch 91/200
# 30/30 - 2s - loss: 11578.4863 - mean_squared_error: 11578.4863 - val_loss: 11338.8711 - val_mean_squared_error: 11338.8711 - 2s/epoch - 52ms/step
# Epoch 92/200
# 30/30 - 2s - loss: 11943.7949 - mean_squared_error: 11943.7949 - val_loss: 24199.9570 - val_mean_squared_error: 24199.9570 - 2s/epoch - 52ms/step
# Epoch 93/200
# 30/30 - 2s - loss: 12714.0332 - mean_squared_error: 12714.0332 - val_loss: 14006.5156 - val_mean_squared_error: 14006.5156 - 2s/epoch - 50ms/step
# Epoch 94/200
# 30/30 - 2s - loss: 12039.7725 - mean_squared_error: 12039.7725 - val_loss: 16321.4209 - val_mean_squared_error: 16321.4209 - 2s/epoch - 52ms/step
# Epoch 95/200
# 30/30 - 2s - loss: 10857.1191 - mean_squared_error: 10857.1191 - val_loss: 12344.2197 - val_mean_squared_error: 12344.2197 - 2s/epoch - 53ms/step
# Epoch 96/200
# 30/30 - 2s - loss: 8758.1592 - mean_squared_error: 8758.1592 - val_loss: 10450.0234 - val_mean_squared_error: 10450.0234 - 2s/epoch - 52ms/step
# Epoch 97/200
# 30/30 - 2s - loss: 10387.9619 - mean_squared_error: 10387.9619 - val_loss: 15843.6221 - val_mean_squared_error: 15843.6221 - 2s/epoch - 52ms/step
# Epoch 98/200
# 30/30 - 2s - loss: 11992.4150 - mean_squared_error: 11992.4150 - val_loss: 15902.7109 - val_mean_squared_error: 15902.7109 - 2s/epoch - 50ms/step
# Epoch 99/200
# 30/30 - 1s - loss: 23031.4688 - mean_squared_error: 23031.4688 - val_loss: 15755.0859 - val_mean_squared_error: 15755.0859 - 1s/epoch - 50ms/step
# Epoch 100/200
# 30/30 - 1s - loss: 17086.4414 - mean_squared_error: 17086.4414 - val_loss: 15573.2852 - val_mean_squared_error: 15573.2852 - 1s/epoch - 49ms/step
# Epoch 101/200
# 30/30 - 1s - loss: 11530.3262 - mean_squared_error: 11530.3262 - val_loss: 14069.9766 - val_mean_squared_error: 14069.9766 - 1s/epoch - 49ms/step
# Epoch 102/200
# 30/30 - 1s - loss: 14590.0137 - mean_squared_error: 14590.0137 - val_loss: 17652.7246 - val_mean_squared_error: 17652.7246 - 1s/epoch - 49ms/step
# Epoch 103/200
# 30/30 - 1s - loss: 14640.6055 - mean_squared_error: 14640.6055 - val_loss: 12938.4600 - val_mean_squared_error: 12938.4600 - 1s/epoch - 50ms/step
# Epoch 104/200
# 30/30 - 2s - loss: 10003.7051 - mean_squared_error: 10003.7051 - val_loss: 12481.8955 - val_mean_squared_error: 12481.8955 - 2s/epoch - 52ms/step
# Epoch 105/200
# 30/30 - 2s - loss: 9448.5391 - mean_squared_error: 9448.5391 - val_loss: 12153.8018 - val_mean_squared_error: 12153.8018 - 2s/epoch - 52ms/step
# Epoch 106/200
# 30/30 - 1s - loss: 12639.6826 - mean_squared_error: 12639.6826 - val_loss: 20065.0859 - val_mean_squared_error: 20065.0859 - 1s/epoch - 49ms/step
# Epoch 107/200
# 30/30 - 2s - loss: 10620.5166 - mean_squared_error: 10620.5166 - val_loss: 16795.1113 - val_mean_squared_error: 16795.1113 - 2s/epoch - 52ms/step
# Epoch 108/200
# 30/30 - 2s - loss: 10233.8232 - mean_squared_error: 10233.8232 - val_loss: 12448.1006 - val_mean_squared_error: 12448.1006 - 2s/epoch - 52ms/step
# Epoch 109/200
# 30/30 - 2s - loss: 14615.9375 - mean_squared_error: 14615.9375 - val_loss: 19009.1973 - val_mean_squared_error: 19009.1973 - 2s/epoch - 52ms/step
# Epoch 110/200
# 30/30 - 1s - loss: 10636.9971 - mean_squared_error: 10636.9971 - val_loss: 10583.0293 - val_mean_squared_error: 10583.0293 - 1s/epoch - 50ms/step
# Epoch 111/200
# 30/30 - 1s - loss: 11013.5127 - mean_squared_error: 11013.5127 - val_loss: 14843.5957 - val_mean_squared_error: 14843.5957 - 1s/epoch - 50ms/step
# Epoch 112/200
# 30/30 - 1s - loss: 10475.2578 - mean_squared_error: 10475.2578 - val_loss: 13775.4648 - val_mean_squared_error: 13775.4648 - 1s/epoch - 50ms/step
# Epoch 113/200
# 30/30 - 2s - loss: 13068.1826 - mean_squared_error: 13068.1826 - val_loss: 20531.1113 - val_mean_squared_error: 20531.1113 - 2s/epoch - 52ms/step
# Epoch 114/200
# 30/30 - 1s - loss: 8552.7188 - mean_squared_error: 8552.7188 - val_loss: 12672.8105 - val_mean_squared_error: 12672.8105 - 1s/epoch - 50ms/step
# Epoch 114: early stopping

# %%
#data = timeProcess()[1]
#modelo.save('/content/drive/MyDrive/1_Informações_scripts//model__3T3_regressao_menor_erro_Mean_squared_error_200_epochs_'+data+'.h5')

# %% [markdown]
# ## Accuracy Assessment

# %%
#gráfico avaliando a acurácia a partir de treino e teste
plt.plot(history.history['mean_squared_error'])
plt.plot(history.history['val_mean_squared_error'])
plt.title('Accuracy Metric')
plt.ylabel('MSE')
plt.xlabel('Epochs')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
#avaliando a previsão do modelo com os rótulos
prev = modelo.predict(X_test)
plt.title('Previsão dos valores Operetta')
plt.ylabel('Rótulos')
plt.xlabel('Previsão')
plt.plot(prev)#azul - o que o modelo previu
plt.plot(y_test)#laranja - o que se sabe - observado
plt.show()
# Out:
# 13/13 [==============================] - 0s 19ms/step

# %%
# Qualit model analisys
from sklearn.metrics import r2_score,mean_absolute_error, mean_squared_error, mean_squared_log_error, median_absolute_error

# %%
#buscando pelas métricas
print(f"{round(r2_score(y_test, prev) * 100, 2)}% r2_score") #raíz quadrada
print(f"{round(mean_absolute_error(y_test, prev), 2)} Erro médio absoluto") 
print(f"{round(mean_squared_error(y_test, prev), 2)} Erro médio quadrático") #erro médio quadrático
# print(f"{round(median_absolute_error(y_test, prev), 2)}")#Erro médio absoluto sem %
#print(f"{round(median(y_test, prev), 2)} mediana") #erro médio quadrático
# Out:
# 90.29% r2_score
# 81.28 Erro médio absoluto
# 12672.81 Erro médio quadrático

# %%
# #salvando o modelo
data = timeProcess()[1]
modelo.save('/content/drive/MyDrive/Regressão_imagens_DOC_CNN/results_mAb_DENV1/modelo_mab_DENV_100_75_50_25_'+data+'.h5')
