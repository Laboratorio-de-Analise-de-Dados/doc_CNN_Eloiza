# %% [markdown]
# # A172

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
pip install util-gfsilveira
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting util-gfsilveira
#   Downloading util_gfsilveira-0.1-py3-none-any.whl (3.1 kB)
# Installing collected packages: util-gfsilveira
# Successfully installed util-gfsilveira-0.1

# %% [markdown]
# # Imports data structuring

# %%
#organização dos arquivos
import os
#salvar/carregar arquivos em diferentes formatos
import joblib
#organizando os arquivos de forma aleatória
import random
#gerar gráfico
import matplotlib
#estruturação dos dados
import numpy as np
#gerar gráfico
import seaborn as sns
#gerar gráfico
import matplotlib.pyplot as plt
#gerar imagem
import matplotlib.image as mpimg

# %% [markdown]
# # CNN template import

# %%
#modelo de revisão redes neurais - cnn
from keras.models import Sequential
from keras.utils.np_utils import to_categorical
#from keras.utils import to_categorical
from util import meus_uteis, timeProcess, mask_corr_graphic, printLis
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report
from keras.layers import Dense, Conv2D, MaxPooling2D, Dropout, Flatten

# %% [markdown]
# Documents from different files will be stored in this directory

# %%
diretorio = '/content/drive/MyDrive/Regressão_imagens_DOC_CNN/results_A172' #alimentando a variável com os arquivos da pasta datasets
lista_dados = os.listdir(diretorio) #listando os arquivos dessa pasta
printLis(lista_dados) #printando as diferentes listas
# Out:
# -------------
# -=< Lista >=-
# -------------
# 0 -> lista_img_camp_clar_100_resized_regressao_A1722022-10-25.gz
# 1 -> lista_rotulo_camp_clar_100_resized_regressao_A1722022-10-25.gz
# 2 -> lista_img_camp_clar_75_resized_regressao_A1722022-10-25.gz
# 3 -> lista_rotulo_camp_clar_75_resized_regressao_A1722022-10-25.gz
# 4 -> lista_img_camp_clar_50_resized_regressao_A1722022-10-25.gz
# 5 -> lista_rotulo_camp_clar_50_resized_regressao_A1722022-10-25.gz
# 6 -> lista_img_camp_clar_25_resized_regressao_A1722022-10-25.gz
# 7 -> lista_rotulo_camp_clar_25_resized_regressao_A1722022-10-25.gz

# %% [markdown]
# Lists of all images in each file

# %%
#lstando arquivos com as imagens 100%, 75%, 50%, 25%
for k, v in enumerate(lista_dados):
    if k in [0,2,4,6]:
        print(f'{k} -> {v}')
# Out:
# 0 -> lista_img_camp_clar_100_resized_regressao_A1722022-10-25.gz
# 2 -> lista_img_camp_clar_75_resized_regressao_A1722022-10-25.gz
# 4 -> lista_img_camp_clar_50_resized_regressao_A1722022-10-25.gz
# 6 -> lista_img_camp_clar_25_resized_regressao_A1722022-10-25.gz

# %% [markdown]
# ## x = features/images

# %%
#somando todas as imagens de diferentes tamanho
X_cem = joblib.load(diretorio+ '/' + lista_dados[0])

# 12 -> 00-lista_img_dapi_crop_75_resized_2021-5-12.gz
X_setcin = joblib.load(diretorio+ '/' + lista_dados[2])

# 10 -> 00-lista_img_dapi_crop_50_resized_2021-5-12.gz
X_cinq = joblib.load(diretorio+ '/' + lista_dados[4])

# 8 -> 00-lista_img_dapi_crop_25_resized_2021-5-12.gz
X_vincin = joblib.load(diretorio+ '/' + lista_dados[6])

x = np.asarray(list(X_cem) + list(X_setcin) + list(X_cinq) + list(X_vincin))

x.shape
# Out:
# (1683, 200, 200, 3)

# %% [markdown]
# ## y = labels

# %% [markdown]
# Opening the labels that were saved in the preparation of the images

# %%
for k, v in enumerate(lista_dados):
    if k in [1,3,5,7]:
        print(f'{k} -> {v}')
# Out:
# 1 -> lista_rotulo_camp_clar_100_resized_regressao_A1722022-10-25.gz
# 3 -> lista_rotulo_camp_clar_75_resized_regressao_A1722022-10-25.gz
# 5 -> lista_rotulo_camp_clar_50_resized_regressao_A1722022-10-25.gz
# 7 -> lista_rotulo_camp_clar_25_resized_regressao_A1722022-10-25.gz

# %%
#somando todos os rótulos de diferentes tamanho
y_cem = joblib.load(diretorio+ '/' + lista_dados[1])

# 12 -> 00-lista_img_dapi_crop_75_resized_2021-5-12.gz
y_setcin = joblib.load(diretorio+ '/' + lista_dados[3])

# 10 -> 00-lista_img_dapi_crop_50_resized_2021-5-12.gz
y_cinq = joblib.load(diretorio+ '/' + lista_dados[5])

# 8 -> 00-lista_img_dapi_crop_25_resized_2021-5-12.gz
y_vincin = joblib.load(diretorio+ '/' + lista_dados[7])

y = np.asarray(list(y_cem) + list(y_setcin) + list(y_cinq) + list(y_vincin))

y.shape
# Out:
# (1683,)

# %%
#Train and test split datasets for CNN model
#função que separa as imagens em teste e treino
from sklearn.model_selection import train_test_split

# %% [markdown]
# #Separando dados de validação

# %%
imagens_teste = x.shape[0] * 0.9 #pegando só das imagens 30% das imagens vai para o teste
imagens_treino = x.shape[0] - imagens_teste #restante das imagens (70%)
print('Data for Modeling: ' + str(imagens_teste))
print('Unseen Data For Predictions: ' + str(imagens_treino))
# Out:
# Data for Modeling: 1514.7
# Unseen Data For Predictions: 168.29999999999995

# %%
zeros = list(np.zeros(1515))
ones = list(np.ones(168))
lista = np.array(zeros + ones)
lista
# Out:
# array([0., 0., 0., ..., 1., 1., 1.])

# %%
random.shuffle(lista)
lista_valida = [True if i == 1 else False for i in lista]
lista_treino_test = [False if i == 1 else True for i in lista]
np.array(lista_valida)
# Out:
# array([False, False, False, ..., False,  True,  True])

# %%
#imagens
x_valida = x[lista_valida]
x_treino_test = x[lista_treino_test]

print(x_valida.shape)
print(x_treino_test.shape)
# Out:
# (168, 200, 200, 3)
# (1515, 200, 200, 3)

# %%
#rótulos
y_valida = y[lista_valida]
y_treino_test = y[lista_treino_test]

print(y_valida.shape)
print(y_treino_test.shape)
# Out:
# (168,)
# (1515,)

# %%
#imagens_teste = x.shape[0] * 0.9 #pegando só das imagens 30% das imagens vai para o teste
#imagens_treino = x.shape[0] - imagens_teste #restante das imagens (70%)
#print('Data for Modeling: ' + str(imagens_teste))
#print('Unseen Data For Predictions: ' + str(imagens_treino))
# Out:
# Data for Modeling: 1368.0
# Unseen Data For Predictions: 152.0

# %% [markdown]
# Dados restantes 90%

# %%
data = timeProcess()[1]

# %%
#Salvando 10$ das imagens para validação
joblib.dump(x_valida, '/content/drive/MyDrive/Regressão_imagens_DOC_CNN/results_A172/imagens_validação_10%_SH_A172_'+data+'.gz')
joblib.dump(y_valida, '/content/drive/MyDrive/Regressão_imagens_DOC_CNN/results_A172/rótulos_validação_10%_SH_A172V_'+data+'.gz')
# Out:
# ['/content/drive/MyDrive/Regressão_imagens_DOC_CNN/results_A172/rótulos_validação_10%_SH_A172V_2022-12-16.gz']

# %% [markdown]
# Test and training separation from a library.

# %%
X_train, X_test, y_train, y_test = train_test_split(x_treino_test, y_treino_test, test_size=0.3, random_state=0)
#variáveis recebem o número de imagens para tes e treino
print(f'{X_train.shape} \n{X_test.shape} \n{y_train.shape} \n{y_test.shape}')
# Out:
# (1060, 200, 200, 3)
# (455, 200, 200, 3)
# (1060,)
# (455,)

# %%
#salvando os resultados de treino e teste
joblib.dump(X_train, '/content/drive/MyDrive/Regressão_imagens_DOC_CNN/results_A172/1_images_de_X_train_A172_melhor_modelo_200_epochs_90%_'+data+'.gz')
joblib.dump(y_train, '/content/drive/MyDrive/Regressão_imagens_DOC_CNN/results_A172/2_rotulos_de_y_train_A172_melhor_modelo_200_epochs_90%_'+data+'.gz')
joblib.dump(X_test, '/content/drive/MyDrive/Regressão_imagens_DOC_CNN/results_A172/3_images_de_X_test_A172_melhor_modelo_200_epochs_90%_'+data+'.gz')
joblib.dump(y_test, '/content/drive/MyDrive/Regressão_imagens_DOC_CNN/results_A172/4_rotulos_de_y_test_A172_melhor_model_200_epochs_90%_'+data+'.gz')
# Out:
# ['/content/drive/MyDrive/Regressão_imagens_DOC_CNN/results_A172/4_rotulos_de_y_test_A172_melhor_model_200_epochs_90%_2022-12-16.gz']

# %% [markdown]
# ### Model determination

# %%
modelo = Sequential()
modelo.add(Conv2D(32, kernel_size=3, activation='relu', input_shape=X_train[0].shape))
#função de ativação relu é muito utilizado para problemas de regressão
modelo.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2), padding='valid'))
modelo.add(Conv2D(64, kernel_size=3, activation='relu'))
modelo.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2), padding='valid'))
modelo.add(Conv2D(128, kernel_size=3, activation='relu'))
modelo.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2), padding='valid'))
modelo.add(Conv2D(256, kernel_size=3, activation='relu'))
modelo.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2), padding='valid'))
modelo.add(Flatten())
modelo.add(Dropout(0.9))
modelo.add(Dense(1, activation='linear'))
#apenas uma saída e de forma linear
modelo.compile(optimizer='adam', loss='mse', metrics=['mean_squared_error'])
print(modelo.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 198, 198, 32)      896
#
#  max_pooling2d (MaxPooling2D  (None, 99, 99, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 97, 97, 64)        18496
#
#  max_pooling2d_1 (MaxPooling  (None, 48, 48, 64)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 46, 46, 128)       73856
#
#  max_pooling2d_2 (MaxPooling  (None, 23, 23, 128)      0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 21, 21, 256)       295168
#
#  max_pooling2d_3 (MaxPooling  (None, 10, 10, 256)      0
#  2D)
#
#  flatten (Flatten)           (None, 25600)             0
#
#  dropout (Dropout)           (None, 25600)             0
#
#  dense (Dense)               (None, 1)                 25601
#
# =================================================================
# Total params: 414,017
# Trainable params: 414,017
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# # Training and testing epochs

# %%
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.callbacks import ModelCheckpoint

# %%
# simple early stopping
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=18)

# %%
# fit model
history = modelo.fit(X_train,y_train,
                    validation_data=(X_test, y_test), 
                    epochs=200, verbose=2, 
                    callbacks=[es]
                     )
# Out:
# Epoch 1/200
# 34/34 - 11s - loss: 10651.1367 - mean_squared_error: 10651.1367 - val_loss: 5463.3325 - val_mean_squared_error: 5463.3325 - 11s/epoch - 328ms/step
# Epoch 2/200
# 34/34 - 2s - loss: 3676.9792 - mean_squared_error: 3676.9792 - val_loss: 2655.4861 - val_mean_squared_error: 2655.4861 - 2s/epoch - 51ms/step
# Epoch 3/200
# 34/34 - 2s - loss: 2596.9836 - mean_squared_error: 2596.9836 - val_loss: 2324.9548 - val_mean_squared_error: 2324.9548 - 2s/epoch - 50ms/step
# Epoch 4/200
# 34/34 - 2s - loss: 2544.7393 - mean_squared_error: 2544.7393 - val_loss: 2485.2329 - val_mean_squared_error: 2485.2329 - 2s/epoch - 50ms/step
# Epoch 5/200
# 34/34 - 2s - loss: 2761.8577 - mean_squared_error: 2761.8577 - val_loss: 2410.4160 - val_mean_squared_error: 2410.4160 - 2s/epoch - 51ms/step
# Epoch 6/200
# 34/34 - 2s - loss: 2111.5376 - mean_squared_error: 2111.5376 - val_loss: 2393.4590 - val_mean_squared_error: 2393.4590 - 2s/epoch - 51ms/step
# Epoch 7/200
# 34/34 - 2s - loss: 2046.8733 - mean_squared_error: 2046.8733 - val_loss: 1848.2817 - val_mean_squared_error: 1848.2817 - 2s/epoch - 50ms/step
# Epoch 8/200
# 34/34 - 2s - loss: 2168.7390 - mean_squared_error: 2168.7390 - val_loss: 2402.7354 - val_mean_squared_error: 2402.7354 - 2s/epoch - 50ms/step
# Epoch 9/200
# 34/34 - 2s - loss: 2232.5723 - mean_squared_error: 2232.5723 - val_loss: 1684.9714 - val_mean_squared_error: 1684.9714 - 2s/epoch - 49ms/step
# Epoch 10/200
# 34/34 - 2s - loss: 1881.7004 - mean_squared_error: 1881.7004 - val_loss: 1645.3983 - val_mean_squared_error: 1645.3983 - 2s/epoch - 51ms/step
# Epoch 11/200
# 34/34 - 2s - loss: 2105.9353 - mean_squared_error: 2105.9353 - val_loss: 2179.8909 - val_mean_squared_error: 2179.8909 - 2s/epoch - 51ms/step
# Epoch 12/200
# 34/34 - 2s - loss: 1801.9827 - mean_squared_error: 1801.9827 - val_loss: 2275.2942 - val_mean_squared_error: 2275.2942 - 2s/epoch - 50ms/step
# Epoch 13/200
# 34/34 - 2s - loss: 1658.4958 - mean_squared_error: 1658.4958 - val_loss: 1313.9976 - val_mean_squared_error: 1313.9976 - 2s/epoch - 51ms/step
# Epoch 14/200
# 34/34 - 2s - loss: 1456.0615 - mean_squared_error: 1456.0615 - val_loss: 1379.4159 - val_mean_squared_error: 1379.4159 - 2s/epoch - 51ms/step
# Epoch 15/200
# 34/34 - 2s - loss: 1660.8588 - mean_squared_error: 1660.8588 - val_loss: 2351.1294 - val_mean_squared_error: 2351.1294 - 2s/epoch - 50ms/step
# Epoch 16/200
# 34/34 - 2s - loss: 1480.1843 - mean_squared_error: 1480.1843 - val_loss: 1151.8280 - val_mean_squared_error: 1151.8280 - 2s/epoch - 50ms/step
# Epoch 17/200
# 34/34 - 2s - loss: 1431.8628 - mean_squared_error: 1431.8628 - val_loss: 1159.1528 - val_mean_squared_error: 1159.1528 - 2s/epoch - 51ms/step
# Epoch 18/200
# 34/34 - 2s - loss: 1554.8220 - mean_squared_error: 1554.8220 - val_loss: 2008.5527 - val_mean_squared_error: 2008.5527 - 2s/epoch - 51ms/step
# Epoch 19/200
# 34/34 - 2s - loss: 1430.4501 - mean_squared_error: 1430.4501 - val_loss: 1206.0819 - val_mean_squared_error: 1206.0819 - 2s/epoch - 51ms/step
# Epoch 20/200
# 34/34 - 2s - loss: 1285.2286 - mean_squared_error: 1285.2286 - val_loss: 1164.0848 - val_mean_squared_error: 1164.0848 - 2s/epoch - 51ms/step
# Epoch 21/200
# 34/34 - 2s - loss: 1261.2477 - mean_squared_error: 1261.2477 - val_loss: 1084.1174 - val_mean_squared_error: 1084.1174 - 2s/epoch - 51ms/step
# Epoch 22/200
# 34/34 - 2s - loss: 1236.8455 - mean_squared_error: 1236.8455 - val_loss: 2131.4399 - val_mean_squared_error: 2131.4399 - 2s/epoch - 50ms/step
# Epoch 23/200
# 34/34 - 2s - loss: 1266.5043 - mean_squared_error: 1266.5043 - val_loss: 916.9534 - val_mean_squared_error: 916.9534 - 2s/epoch - 50ms/step
# Epoch 24/200
# 34/34 - 2s - loss: 1271.9398 - mean_squared_error: 1271.9398 - val_loss: 1069.5903 - val_mean_squared_error: 1069.5903 - 2s/epoch - 51ms/step
# Epoch 25/200
# 34/34 - 2s - loss: 1267.8490 - mean_squared_error: 1267.8490 - val_loss: 1338.2975 - val_mean_squared_error: 1338.2975 - 2s/epoch - 51ms/step
# Epoch 26/200
# 34/34 - 2s - loss: 1611.4779 - mean_squared_error: 1611.4779 - val_loss: 1124.8950 - val_mean_squared_error: 1124.8950 - 2s/epoch - 51ms/step
# Epoch 27/200
# 34/34 - 2s - loss: 1059.7034 - mean_squared_error: 1059.7034 - val_loss: 1018.1632 - val_mean_squared_error: 1018.1632 - 2s/epoch - 49ms/step
# Epoch 28/200
# 34/34 - 2s - loss: 1118.9781 - mean_squared_error: 1118.9781 - val_loss: 1596.1217 - val_mean_squared_error: 1596.1217 - 2s/epoch - 51ms/step
# Epoch 29/200
# 34/34 - 2s - loss: 1358.6654 - mean_squared_error: 1358.6654 - val_loss: 863.4414 - val_mean_squared_error: 863.4414 - 2s/epoch - 51ms/step
# Epoch 30/200
# 34/34 - 2s - loss: 1154.1034 - mean_squared_error: 1154.1034 - val_loss: 869.5941 - val_mean_squared_error: 869.5941 - 2s/epoch - 50ms/step
# Epoch 31/200
# 34/34 - 2s - loss: 1198.0936 - mean_squared_error: 1198.0936 - val_loss: 864.8693 - val_mean_squared_error: 864.8693 - 2s/epoch - 49ms/step
# Epoch 32/200
# 34/34 - 2s - loss: 1132.1693 - mean_squared_error: 1132.1693 - val_loss: 801.5699 - val_mean_squared_error: 801.5699 - 2s/epoch - 49ms/step
# Epoch 33/200
# 34/34 - 2s - loss: 1019.8030 - mean_squared_error: 1019.8030 - val_loss: 923.1929 - val_mean_squared_error: 923.1929 - 2s/epoch - 49ms/step
# Epoch 34/200
# 34/34 - 2s - loss: 1130.8912 - mean_squared_error: 1130.8912 - val_loss: 862.0565 - val_mean_squared_error: 862.0565 - 2s/epoch - 50ms/step
# Epoch 35/200
# 34/34 - 2s - loss: 885.3573 - mean_squared_error: 885.3573 - val_loss: 766.5361 - val_mean_squared_error: 766.5361 - 2s/epoch - 51ms/step
# Epoch 36/200
# 34/34 - 2s - loss: 955.0828 - mean_squared_error: 955.0828 - val_loss: 834.6540 - val_mean_squared_error: 834.6540 - 2s/epoch - 49ms/step
# Epoch 37/200
# 34/34 - 2s - loss: 800.0251 - mean_squared_error: 800.0251 - val_loss: 635.9319 - val_mean_squared_error: 635.9319 - 2s/epoch - 49ms/step
# Epoch 38/200
# 34/34 - 2s - loss: 857.6802 - mean_squared_error: 857.6802 - val_loss: 1452.1205 - val_mean_squared_error: 1452.1205 - 2s/epoch - 50ms/step
# Epoch 39/200
# 34/34 - 2s - loss: 1050.2014 - mean_squared_error: 1050.2014 - val_loss: 700.4778 - val_mean_squared_error: 700.4778 - 2s/epoch - 51ms/step
# Epoch 40/200
# 34/34 - 2s - loss: 882.0869 - mean_squared_error: 882.0869 - val_loss: 829.3585 - val_mean_squared_error: 829.3585 - 2s/epoch - 50ms/step
# Epoch 41/200
# 34/34 - 2s - loss: 830.9596 - mean_squared_error: 830.9596 - val_loss: 1775.0546 - val_mean_squared_error: 1775.0546 - 2s/epoch - 50ms/step
# Epoch 42/200
# 34/34 - 2s - loss: 920.6118 - mean_squared_error: 920.6118 - val_loss: 827.7798 - val_mean_squared_error: 827.7798 - 2s/epoch - 51ms/step
# Epoch 43/200
# 34/34 - 2s - loss: 1017.5672 - mean_squared_error: 1017.5672 - val_loss: 651.8933 - val_mean_squared_error: 651.8933 - 2s/epoch - 49ms/step
# Epoch 44/200
# 34/34 - 2s - loss: 713.7504 - mean_squared_error: 713.7504 - val_loss: 916.9501 - val_mean_squared_error: 916.9501 - 2s/epoch - 51ms/step
# Epoch 45/200
# 34/34 - 2s - loss: 772.6832 - mean_squared_error: 772.6832 - val_loss: 996.3560 - val_mean_squared_error: 996.3560 - 2s/epoch - 50ms/step
# Epoch 46/200
# 34/34 - 2s - loss: 736.0858 - mean_squared_error: 736.0858 - val_loss: 725.0123 - val_mean_squared_error: 725.0123 - 2s/epoch - 51ms/step
# Epoch 47/200
# 34/34 - 2s - loss: 780.6760 - mean_squared_error: 780.6760 - val_loss: 779.5004 - val_mean_squared_error: 779.5004 - 2s/epoch - 49ms/step
# Epoch 48/200
# 34/34 - 2s - loss: 772.7299 - mean_squared_error: 772.7299 - val_loss: 822.9305 - val_mean_squared_error: 822.9305 - 2s/epoch - 49ms/step
# Epoch 49/200
# 34/34 - 2s - loss: 993.0705 - mean_squared_error: 993.0705 - val_loss: 783.5931 - val_mean_squared_error: 783.5931 - 2s/epoch - 50ms/step
# Epoch 50/200
# 34/34 - 2s - loss: 788.7545 - mean_squared_error: 788.7545 - val_loss: 843.7374 - val_mean_squared_error: 843.7374 - 2s/epoch - 51ms/step
# Epoch 51/200
# 34/34 - 2s - loss: 825.0557 - mean_squared_error: 825.0557 - val_loss: 704.2994 - val_mean_squared_error: 704.2994 - 2s/epoch - 50ms/step
# Epoch 52/200
# 34/34 - 2s - loss: 973.0430 - mean_squared_error: 973.0430 - val_loss: 955.7168 - val_mean_squared_error: 955.7168 - 2s/epoch - 49ms/step
# Epoch 53/200
# 34/34 - 2s - loss: 731.6085 - mean_squared_error: 731.6085 - val_loss: 575.7221 - val_mean_squared_error: 575.7221 - 2s/epoch - 49ms/step
# Epoch 54/200
# 34/34 - 2s - loss: 686.6074 - mean_squared_error: 686.6074 - val_loss: 566.5887 - val_mean_squared_error: 566.5887 - 2s/epoch - 49ms/step
# Epoch 55/200
# 34/34 - 2s - loss: 722.3698 - mean_squared_error: 722.3698 - val_loss: 669.0530 - val_mean_squared_error: 669.0530 - 2s/epoch - 49ms/step
# Epoch 56/200
# 34/34 - 2s - loss: 690.1657 - mean_squared_error: 690.1657 - val_loss: 672.3312 - val_mean_squared_error: 672.3312 - 2s/epoch - 51ms/step
# Epoch 57/200
# 34/34 - 2s - loss: 694.1225 - mean_squared_error: 694.1225 - val_loss: 613.7615 - val_mean_squared_error: 613.7615 - 2s/epoch - 49ms/step
# Epoch 58/200
# 34/34 - 2s - loss: 865.9970 - mean_squared_error: 865.9970 - val_loss: 594.5253 - val_mean_squared_error: 594.5253 - 2s/epoch - 51ms/step
# Epoch 59/200
# 34/34 - 2s - loss: 579.9275 - mean_squared_error: 579.9275 - val_loss: 747.8102 - val_mean_squared_error: 747.8102 - 2s/epoch - 51ms/step
# Epoch 60/200
# 34/34 - 2s - loss: 648.1401 - mean_squared_error: 648.1401 - val_loss: 673.4020 - val_mean_squared_error: 673.4020 - 2s/epoch - 50ms/step
# Epoch 61/200
# 34/34 - 2s - loss: 577.2445 - mean_squared_error: 577.2445 - val_loss: 528.0566 - val_mean_squared_error: 528.0566 - 2s/epoch - 50ms/step
# Epoch 62/200
# 34/34 - 2s - loss: 543.6650 - mean_squared_error: 543.6650 - val_loss: 620.4557 - val_mean_squared_error: 620.4557 - 2s/epoch - 51ms/step
# Epoch 63/200
# 34/34 - 2s - loss: 636.7994 - mean_squared_error: 636.7994 - val_loss: 879.3916 - val_mean_squared_error: 879.3916 - 2s/epoch - 52ms/step
# Epoch 64/200
# 34/34 - 2s - loss: 577.5240 - mean_squared_error: 577.5240 - val_loss: 526.2638 - val_mean_squared_error: 526.2638 - 2s/epoch - 51ms/step
# Epoch 65/200
# 34/34 - 2s - loss: 480.5770 - mean_squared_error: 480.5770 - val_loss: 484.2163 - val_mean_squared_error: 484.2163 - 2s/epoch - 50ms/step
# Epoch 66/200
# 34/34 - 2s - loss: 519.8176 - mean_squared_error: 519.8176 - val_loss: 506.6920 - val_mean_squared_error: 506.6920 - 2s/epoch - 49ms/step
# Epoch 67/200
# 34/34 - 2s - loss: 495.5886 - mean_squared_error: 495.5886 - val_loss: 689.4714 - val_mean_squared_error: 689.4714 - 2s/epoch - 50ms/step
# Epoch 68/200
# 34/34 - 2s - loss: 509.4190 - mean_squared_error: 509.4190 - val_loss: 483.8181 - val_mean_squared_error: 483.8181 - 2s/epoch - 50ms/step
# Epoch 69/200
# 34/34 - 2s - loss: 474.1303 - mean_squared_error: 474.1303 - val_loss: 971.3885 - val_mean_squared_error: 971.3885 - 2s/epoch - 51ms/step
# Epoch 70/200
# 34/34 - 2s - loss: 676.5137 - mean_squared_error: 676.5137 - val_loss: 594.7446 - val_mean_squared_error: 594.7446 - 2s/epoch - 50ms/step
# Epoch 71/200
# 34/34 - 2s - loss: 605.5337 - mean_squared_error: 605.5337 - val_loss: 502.3413 - val_mean_squared_error: 502.3413 - 2s/epoch - 51ms/step
# Epoch 72/200
# 34/34 - 2s - loss: 597.4124 - mean_squared_error: 597.4124 - val_loss: 545.7540 - val_mean_squared_error: 545.7540 - 2s/epoch - 50ms/step
# Epoch 73/200
# 34/34 - 2s - loss: 568.7642 - mean_squared_error: 568.7642 - val_loss: 751.9469 - val_mean_squared_error: 751.9469 - 2s/epoch - 49ms/step
# Epoch 74/200
# 34/34 - 2s - loss: 609.6841 - mean_squared_error: 609.6841 - val_loss: 566.9256 - val_mean_squared_error: 566.9256 - 2s/epoch - 49ms/step
# Epoch 75/200
# 34/34 - 2s - loss: 522.6657 - mean_squared_error: 522.6657 - val_loss: 829.0063 - val_mean_squared_error: 829.0063 - 2s/epoch - 51ms/step
# Epoch 76/200
# 34/34 - 2s - loss: 489.2754 - mean_squared_error: 489.2754 - val_loss: 457.2630 - val_mean_squared_error: 457.2630 - 2s/epoch - 50ms/step
# Epoch 77/200
# 34/34 - 2s - loss: 389.3801 - mean_squared_error: 389.3801 - val_loss: 466.9198 - val_mean_squared_error: 466.9198 - 2s/epoch - 49ms/step
# Epoch 78/200
# 34/34 - 2s - loss: 424.8291 - mean_squared_error: 424.8291 - val_loss: 438.8572 - val_mean_squared_error: 438.8572 - 2s/epoch - 50ms/step
# Epoch 79/200
# 34/34 - 2s - loss: 380.1559 - mean_squared_error: 380.1559 - val_loss: 520.6922 - val_mean_squared_error: 520.6922 - 2s/epoch - 51ms/step
# Epoch 80/200
# 34/34 - 2s - loss: 478.3798 - mean_squared_error: 478.3798 - val_loss: 552.1040 - val_mean_squared_error: 552.1040 - 2s/epoch - 49ms/step
# Epoch 81/200
# 34/34 - 2s - loss: 387.6182 - mean_squared_error: 387.6182 - val_loss: 427.3675 - val_mean_squared_error: 427.3675 - 2s/epoch - 49ms/step
# Epoch 82/200
# 34/34 - 2s - loss: 351.9238 - mean_squared_error: 351.9238 - val_loss: 693.7039 - val_mean_squared_error: 693.7039 - 2s/epoch - 50ms/step
# Epoch 83/200
# 34/34 - 2s - loss: 380.9103 - mean_squared_error: 380.9103 - val_loss: 519.1655 - val_mean_squared_error: 519.1655 - 2s/epoch - 50ms/step
# Epoch 84/200
# 34/34 - 2s - loss: 389.5077 - mean_squared_error: 389.5077 - val_loss: 995.1561 - val_mean_squared_error: 995.1561 - 2s/epoch - 51ms/step
# Epoch 85/200
# 34/34 - 2s - loss: 419.6721 - mean_squared_error: 419.6721 - val_loss: 436.2648 - val_mean_squared_error: 436.2648 - 2s/epoch - 51ms/step
# Epoch 86/200
# 34/34 - 2s - loss: 360.2473 - mean_squared_error: 360.2473 - val_loss: 618.3267 - val_mean_squared_error: 618.3267 - 2s/epoch - 49ms/step
# Epoch 87/200
# 34/34 - 2s - loss: 456.1257 - mean_squared_error: 456.1257 - val_loss: 460.7672 - val_mean_squared_error: 460.7672 - 2s/epoch - 49ms/step
# Epoch 88/200
# 34/34 - 2s - loss: 438.2925 - mean_squared_error: 438.2925 - val_loss: 424.8953 - val_mean_squared_error: 424.8953 - 2s/epoch - 50ms/step
# Epoch 89/200
# 34/34 - 2s - loss: 328.9595 - mean_squared_error: 328.9595 - val_loss: 449.7761 - val_mean_squared_error: 449.7761 - 2s/epoch - 50ms/step
# Epoch 90/200
# 34/34 - 2s - loss: 337.2051 - mean_squared_error: 337.2051 - val_loss: 396.2961 - val_mean_squared_error: 396.2961 - 2s/epoch - 49ms/step
# Epoch 91/200
# 34/34 - 2s - loss: 387.9493 - mean_squared_error: 387.9493 - val_loss: 422.9286 - val_mean_squared_error: 422.9286 - 2s/epoch - 49ms/step
# Epoch 92/200
# 34/34 - 2s - loss: 338.8517 - mean_squared_error: 338.8517 - val_loss: 487.5730 - val_mean_squared_error: 487.5730 - 2s/epoch - 51ms/step
# Epoch 93/200
# 34/34 - 2s - loss: 358.2203 - mean_squared_error: 358.2203 - val_loss: 510.5915 - val_mean_squared_error: 510.5915 - 2s/epoch - 49ms/step
# Epoch 94/200
# 34/34 - 2s - loss: 346.6942 - mean_squared_error: 346.6942 - val_loss: 784.2896 - val_mean_squared_error: 784.2896 - 2s/epoch - 51ms/step
# Epoch 95/200
# 34/34 - 2s - loss: 362.8671 - mean_squared_error: 362.8671 - val_loss: 479.1705 - val_mean_squared_error: 479.1705 - 2s/epoch - 50ms/step
# Epoch 96/200
# 34/34 - 2s - loss: 408.4852 - mean_squared_error: 408.4852 - val_loss: 925.5915 - val_mean_squared_error: 925.5915 - 2s/epoch - 50ms/step
# Epoch 97/200
# 34/34 - 2s - loss: 383.5402 - mean_squared_error: 383.5402 - val_loss: 386.4380 - val_mean_squared_error: 386.4380 - 2s/epoch - 51ms/step
# Epoch 98/200
# 34/34 - 2s - loss: 319.9019 - mean_squared_error: 319.9019 - val_loss: 652.0016 - val_mean_squared_error: 652.0016 - 2s/epoch - 49ms/step
# Epoch 99/200
# 34/34 - 2s - loss: 539.3317 - mean_squared_error: 539.3317 - val_loss: 529.9514 - val_mean_squared_error: 529.9514 - 2s/epoch - 51ms/step
# Epoch 100/200
# 34/34 - 2s - loss: 403.1331 - mean_squared_error: 403.1331 - val_loss: 410.4073 - val_mean_squared_error: 410.4073 - 2s/epoch - 51ms/step
# Epoch 101/200
# 34/34 - 2s - loss: 320.9324 - mean_squared_error: 320.9324 - val_loss: 564.3467 - val_mean_squared_error: 564.3467 - 2s/epoch - 51ms/step
# Epoch 102/200
# 34/34 - 2s - loss: 361.3278 - mean_squared_error: 361.3278 - val_loss: 503.6349 - val_mean_squared_error: 503.6349 - 2s/epoch - 50ms/step
# Epoch 103/200
# 34/34 - 2s - loss: 352.9793 - mean_squared_error: 352.9793 - val_loss: 404.4358 - val_mean_squared_error: 404.4358 - 2s/epoch - 51ms/step
# Epoch 104/200
# 34/34 - 2s - loss: 295.2720 - mean_squared_error: 295.2720 - val_loss: 403.6618 - val_mean_squared_error: 403.6618 - 2s/epoch - 50ms/step
# Epoch 105/200
# 34/34 - 2s - loss: 271.4853 - mean_squared_error: 271.4853 - val_loss: 443.8514 - val_mean_squared_error: 443.8514 - 2s/epoch - 49ms/step
# Epoch 106/200
# 34/34 - 2s - loss: 328.0904 - mean_squared_error: 328.0904 - val_loss: 822.8619 - val_mean_squared_error: 822.8619 - 2s/epoch - 50ms/step
# Epoch 107/200
# 34/34 - 2s - loss: 320.4341 - mean_squared_error: 320.4341 - val_loss: 370.0871 - val_mean_squared_error: 370.0871 - 2s/epoch - 51ms/step
# Epoch 108/200
# 34/34 - 2s - loss: 243.5126 - mean_squared_error: 243.5126 - val_loss: 391.4396 - val_mean_squared_error: 391.4396 - 2s/epoch - 51ms/step
# Epoch 109/200
# 34/34 - 2s - loss: 348.8792 - mean_squared_error: 348.8792 - val_loss: 409.3550 - val_mean_squared_error: 409.3550 - 2s/epoch - 51ms/step
# Epoch 110/200
# 34/34 - 2s - loss: 286.9069 - mean_squared_error: 286.9069 - val_loss: 374.6217 - val_mean_squared_error: 374.6217 - 2s/epoch - 49ms/step
# Epoch 111/200
# 34/34 - 2s - loss: 236.3084 - mean_squared_error: 236.3084 - val_loss: 381.8748 - val_mean_squared_error: 381.8748 - 2s/epoch - 49ms/step
# Epoch 112/200
# 34/34 - 2s - loss: 283.6871 - mean_squared_error: 283.6871 - val_loss: 914.8807 - val_mean_squared_error: 914.8807 - 2s/epoch - 51ms/step
# Epoch 113/200
# 34/34 - 2s - loss: 410.9657 - mean_squared_error: 410.9657 - val_loss: 923.6265 - val_mean_squared_error: 923.6265 - 2s/epoch - 51ms/step
# Epoch 114/200
# 34/34 - 2s - loss: 421.3878 - mean_squared_error: 421.3878 - val_loss: 610.6350 - val_mean_squared_error: 610.6350 - 2s/epoch - 50ms/step
# Epoch 115/200
# 34/34 - 2s - loss: 360.1697 - mean_squared_error: 360.1697 - val_loss: 405.8623 - val_mean_squared_error: 405.8623 - 2s/epoch - 49ms/step
# Epoch 116/200
# 34/34 - 2s - loss: 301.6965 - mean_squared_error: 301.6965 - val_loss: 602.3772 - val_mean_squared_error: 602.3772 - 2s/epoch - 50ms/step
# Epoch 117/200
# 34/34 - 2s - loss: 376.9234 - mean_squared_error: 376.9234 - val_loss: 472.9382 - val_mean_squared_error: 472.9382 - 2s/epoch - 51ms/step
# Epoch 118/200
# 34/34 - 2s - loss: 360.3650 - mean_squared_error: 360.3650 - val_loss: 495.6296 - val_mean_squared_error: 495.6296 - 2s/epoch - 51ms/step
# Epoch 119/200
# 34/34 - 2s - loss: 249.9644 - mean_squared_error: 249.9644 - val_loss: 429.2482 - val_mean_squared_error: 429.2482 - 2s/epoch - 49ms/step
# Epoch 120/200
# 34/34 - 2s - loss: 238.6185 - mean_squared_error: 238.6185 - val_loss: 359.9495 - val_mean_squared_error: 359.9495 - 2s/epoch - 50ms/step
# Epoch 121/200
# 34/34 - 2s - loss: 209.0652 - mean_squared_error: 209.0652 - val_loss: 355.8518 - val_mean_squared_error: 355.8518 - 2s/epoch - 50ms/step
# Epoch 122/200
# 34/34 - 2s - loss: 237.1270 - mean_squared_error: 237.1270 - val_loss: 368.0056 - val_mean_squared_error: 368.0056 - 2s/epoch - 50ms/step
# Epoch 123/200
# 34/34 - 2s - loss: 190.4206 - mean_squared_error: 190.4206 - val_loss: 419.3343 - val_mean_squared_error: 419.3343 - 2s/epoch - 50ms/step
# Epoch 124/200
# 34/34 - 2s - loss: 203.8777 - mean_squared_error: 203.8777 - val_loss: 550.2422 - val_mean_squared_error: 550.2422 - 2s/epoch - 51ms/step
# Epoch 125/200
# 34/34 - 2s - loss: 494.6036 - mean_squared_error: 494.6036 - val_loss: 698.8201 - val_mean_squared_error: 698.8201 - 2s/epoch - 51ms/step
# Epoch 126/200
# 34/34 - 2s - loss: 348.3668 - mean_squared_error: 348.3668 - val_loss: 485.4989 - val_mean_squared_error: 485.4989 - 2s/epoch - 49ms/step
# Epoch 127/200
# 34/34 - 2s - loss: 232.1556 - mean_squared_error: 232.1556 - val_loss: 626.0301 - val_mean_squared_error: 626.0301 - 2s/epoch - 50ms/step
# Epoch 128/200
# 34/34 - 2s - loss: 312.5256 - mean_squared_error: 312.5256 - val_loss: 415.5740 - val_mean_squared_error: 415.5740 - 2s/epoch - 49ms/step
# Epoch 129/200
# 34/34 - 2s - loss: 253.7356 - mean_squared_error: 253.7356 - val_loss: 412.2942 - val_mean_squared_error: 412.2942 - 2s/epoch - 51ms/step
# Epoch 130/200
# 34/34 - 2s - loss: 247.7164 - mean_squared_error: 247.7164 - val_loss: 357.5519 - val_mean_squared_error: 357.5519 - 2s/epoch - 50ms/step
# Epoch 131/200
# 34/34 - 2s - loss: 232.2441 - mean_squared_error: 232.2441 - val_loss: 460.5128 - val_mean_squared_error: 460.5128 - 2s/epoch - 51ms/step
# Epoch 132/200
# 34/34 - 2s - loss: 234.4875 - mean_squared_error: 234.4875 - val_loss: 744.5466 - val_mean_squared_error: 744.5466 - 2s/epoch - 50ms/step
# Epoch 133/200
# 34/34 - 2s - loss: 260.7106 - mean_squared_error: 260.7106 - val_loss: 438.4439 - val_mean_squared_error: 438.4439 - 2s/epoch - 51ms/step
# Epoch 134/200
# 34/34 - 2s - loss: 207.2832 - mean_squared_error: 207.2832 - val_loss: 394.9463 - val_mean_squared_error: 394.9463 - 2s/epoch - 49ms/step
# Epoch 135/200
# 34/34 - 2s - loss: 187.0716 - mean_squared_error: 187.0716 - val_loss: 359.8194 - val_mean_squared_error: 359.8194 - 2s/epoch - 49ms/step
# Epoch 136/200
# 34/34 - 2s - loss: 181.1797 - mean_squared_error: 181.1797 - val_loss: 348.6659 - val_mean_squared_error: 348.6659 - 2s/epoch - 51ms/step
# Epoch 137/200
# 34/34 - 2s - loss: 224.9850 - mean_squared_error: 224.9850 - val_loss: 372.2430 - val_mean_squared_error: 372.2430 - 2s/epoch - 50ms/step
# Epoch 138/200
# 34/34 - 2s - loss: 162.8999 - mean_squared_error: 162.8999 - val_loss: 467.2686 - val_mean_squared_error: 467.2686 - 2s/epoch - 49ms/step
# Epoch 139/200
# 34/34 - 2s - loss: 209.4879 - mean_squared_error: 209.4879 - val_loss: 357.0452 - val_mean_squared_error: 357.0452 - 2s/epoch - 50ms/step
# Epoch 140/200
# 34/34 - 2s - loss: 177.9100 - mean_squared_error: 177.9100 - val_loss: 325.3955 - val_mean_squared_error: 325.3955 - 2s/epoch - 50ms/step
# Epoch 141/200
# 34/34 - 2s - loss: 151.1948 - mean_squared_error: 151.1948 - val_loss: 368.2538 - val_mean_squared_error: 368.2538 - 2s/epoch - 51ms/step
# Epoch 142/200
# 34/34 - 2s - loss: 162.0776 - mean_squared_error: 162.0776 - val_loss: 332.5949 - val_mean_squared_error: 332.5949 - 2s/epoch - 49ms/step
# Epoch 143/200
# 34/34 - 2s - loss: 176.8754 - mean_squared_error: 176.8754 - val_loss: 385.0307 - val_mean_squared_error: 385.0307 - 2s/epoch - 51ms/step
# Epoch 144/200
# 34/34 - 2s - loss: 143.7724 - mean_squared_error: 143.7724 - val_loss: 331.6440 - val_mean_squared_error: 331.6440 - 2s/epoch - 51ms/step
# Epoch 145/200
# 34/34 - 2s - loss: 159.1243 - mean_squared_error: 159.1243 - val_loss: 425.1252 - val_mean_squared_error: 425.1252 - 2s/epoch - 51ms/step
# Epoch 146/200
# 34/34 - 2s - loss: 228.9595 - mean_squared_error: 228.9595 - val_loss: 439.8939 - val_mean_squared_error: 439.8939 - 2s/epoch - 50ms/step
# Epoch 147/200
# 34/34 - 2s - loss: 215.2725 - mean_squared_error: 215.2725 - val_loss: 437.2444 - val_mean_squared_error: 437.2444 - 2s/epoch - 51ms/step
# Epoch 148/200
# 34/34 - 2s - loss: 242.3424 - mean_squared_error: 242.3424 - val_loss: 612.0712 - val_mean_squared_error: 612.0712 - 2s/epoch - 51ms/step
# Epoch 149/200
# 34/34 - 2s - loss: 234.7507 - mean_squared_error: 234.7507 - val_loss: 404.6404 - val_mean_squared_error: 404.6404 - 2s/epoch - 51ms/step
# Epoch 150/200
# 34/34 - 2s - loss: 216.6378 - mean_squared_error: 216.6378 - val_loss: 392.4774 - val_mean_squared_error: 392.4774 - 2s/epoch - 50ms/step
# Epoch 151/200
# 34/34 - 2s - loss: 201.2139 - mean_squared_error: 201.2139 - val_loss: 367.2807 - val_mean_squared_error: 367.2807 - 2s/epoch - 49ms/step
# Epoch 152/200
# 34/34 - 2s - loss: 208.2846 - mean_squared_error: 208.2846 - val_loss: 602.1049 - val_mean_squared_error: 602.1049 - 2s/epoch - 49ms/step
# Epoch 153/200
# 34/34 - 2s - loss: 203.7290 - mean_squared_error: 203.7290 - val_loss: 355.1264 - val_mean_squared_error: 355.1264 - 2s/epoch - 50ms/step
# Epoch 154/200
# 34/34 - 2s - loss: 193.7439 - mean_squared_error: 193.7439 - val_loss: 542.9305 - val_mean_squared_error: 542.9305 - 2s/epoch - 51ms/step
# Epoch 155/200
# 34/34 - 2s - loss: 224.1548 - mean_squared_error: 224.1548 - val_loss: 1409.9155 - val_mean_squared_error: 1409.9155 - 2s/epoch - 49ms/step
# Epoch 156/200
# 34/34 - 2s - loss: 376.3767 - mean_squared_error: 376.3767 - val_loss: 593.3075 - val_mean_squared_error: 593.3075 - 2s/epoch - 50ms/step
# Epoch 157/200
# 34/34 - 2s - loss: 268.3327 - mean_squared_error: 268.3327 - val_loss: 464.4830 - val_mean_squared_error: 464.4830 - 2s/epoch - 50ms/step
# Epoch 158/200
# 34/34 - 2s - loss: 235.3941 - mean_squared_error: 235.3941 - val_loss: 493.9278 - val_mean_squared_error: 493.9278 - 2s/epoch - 50ms/step
# Epoch 158: early stopping

# %%
#data = timeProcess()[1]
#modelo.save('/content/drive/MyDrive/1_Informações_scripts//model__3T3_regressao_menor_erro_Mean_squared_error_200_epochs_'+data+'.h5')

# %% [markdown]
# ## Accuracy Assessment

# %%
#gráfico avaliando a acurácia a partir de treino e teste
plt.plot(history.history['mean_squared_error'])
plt.plot(history.history['val_mean_squared_error'])
plt.title('Accuracy Metric')
plt.ylabel('MSE')
plt.xlabel('Epochs')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
#avaliando a previsão do modelo com os rótulos
prev = modelo.predict(X_test)
plt.title('Previsão dos valores Operetta')
plt.ylabel('Rótulos')
plt.xlabel('Previsão')
plt.plot(prev)#azul - o que o modelo previu
plt.plot(y_test)#laranja - o que se sabe - observado
plt.show()
# Out:
# 15/15 [==============================] - 0s 18ms/step

# %%
# Qualit model analisys
from sklearn.metrics import r2_score,mean_absolute_error, mean_squared_error, mean_squared_log_error, median_absolute_error

# %%
#buscando pelas métricas
print(f"{round(r2_score(y_test, prev) * 100, 2)}% r2_score") #raíz quadrada
print(f"{round(mean_absolute_error(y_test, prev), 2)} Erro médio absoluto") 
print(f"{round(mean_squared_error(y_test, prev), 2)} Erro médio quadrático") #erro médio quadrático
# print(f"{round(median_absolute_error(y_test, prev), 2)}")#Erro médio absoluto sem %
#print(f"{round(median(y_test, prev), 2)} mediana") #erro médio quadrático
# Out:
# 87.8% r2_score
# 16.79 Erro médio absoluto
# 493.93 Erro médio quadrático

# %%
# #salvando o modelo
data = timeProcess()[1]
modelo.save('/content/drive/MyDrive/Regressão_imagens_DOC_CNN/results_A172/modelo_A172_100_75_50_25_'+data+'.h5')
